# %%
import sys
sys.path.append("../../smsl")

# %%
from smsl.graphBigtraj import BigTrajGraphAgent
from smsl.graph import PR0

import warnings; warnings.filterwarnings("ignore")
import numpy as np

# %%
## 見論文表B.7
n_mode=90         ## $\alpha_c$
vlv_threshold=0.2 ## $\nu_{\text{c}}$
pe_threshold=0.5  ## $\kappa_{\text{c}}$

# %%
b_agent = BigTrajGraphAgent(PR0)
# Out:
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/dsdna/d.fluctmatch/bigtraj_fluctmatch/0000_0500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/dsdna/d.fluctmatch/bigtraj_fluctmatch/0250_0750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/dsdna/d.fluctmatch/bigtraj_fluctmatch/0500_1000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/dsdna/d.fluctmatch/bigtraj_fluctmatch/0750_1250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/dsdna/d.fluctmatch/bigtraj_fluctmatch/1000_1500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/dsdna/d.fluctmatch/bigtraj_fluctmatch/1250_1750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/dsdna/d.fluctmatch/bigtraj_fluctmatch/1500_2000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/dsdna/d.fluctmatch/bigtraj_fluctmatch/1750_2250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/dsdna/d.fluctmatch/bigtraj_fluctmatch/2000_2500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/dsdna/d.fluctmatch/bigtraj_fluctmatch/2250_2750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/dsdna/d.fluctmatch/bigtraj_fluctmatch/2500_3000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/dsdna/d.fluctmatch/bigtraj_fluctmatch/2750_3250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/dsdna/d.fluctmatch/bigtraj_fluctmatch/3000_3500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/dsdna/d.fluctmatch/bigtraj_fluctmatch/3250_3750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/dsdna/d.fluctmatch/bigtraj_fluctmatch/3500_4000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/dsdna/d.fluctmatch/bigtraj_fluctmatch/3750_4250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/dsdna/d.fluctmatch/bigtraj_fluctmatch/4000_4500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/dsdna/d.fluctmatch/bigtraj_fluctmatch/4250_4750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/dsdna/d.fluctmatch/bigtraj_fluctmatch/4500_5000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/dsdna/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/pairtypes_k_b0_cutoff_5.00.csv

# %%
b_agent.spectral_decomposition()
b_agent.set_mean_r_alpha_array()
b_agent.t_agent.mean.GetEigenvectorEigenvectorT()
# Out:
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.

# %%
## 論文 圖5.24(B)
b_agent.plot_prominent_modes_and_identify_atom_with_interactive(strandid=None)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=239, min=1), Output()), _dom_classes=('w…

# %%
b_agent.plot_prominent_modes_and_get_identify_pair_with_interactive(\
        strandid=None, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, filter=True)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=239, min=1), Output()), _dom_classes=('w…

# %%
b_agent.t_agent.mean.get_modes_info(strandid=None, n_mode=n_mode, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, is_return=False)
# Out:
# 100%|██████████| 90/90 [00:00<00:00, 145.85it/s]

# %%
## 論文 圖5.24(C)
b_agent.t_agent.mean.display_df_info_by_resid(save=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#     </tr>
#     <tr>
#       <th>Residue Pair</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A1</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{6}$=35.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{6}$:<br>C5'C2'(A1A1)<br>C5'C1'(A1A1)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{36}$=23.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{36}$:<br>O5'C3'(A1A1)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{48}$=14.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{48}$:<br>O4'O3'(A1A1)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G2</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{2}$=38.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{2}$:<br>O1PC5'(G2G2)<br>C5'C2'(G2G2)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{12}$=31.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{12}$:<br>O5'O4'(G2G2)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G3</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{9}$=34.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{9}$:<br>C5'C1'(G3G3)<br>O1PC5'(G3G3)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{23}$=26.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{23}$:<br>O5'O4'(G3G3)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{67}$=10.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{67}$:<br>PC3'(G3G3)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G4</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{37}$=22.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{37}$:<br>O5'O4'(G4G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{39}$=21.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{39}$:<br>C5'C1'(G4G4)<br>O1PC5'(G4G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{66}$=11.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{66}$:<br>O1PC4'(G4G4)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T5</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{20}$=27.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{20}$:<br>O1PC5'(T5T5)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{42}$=18.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{42}$:<br>O5'O4'(T5T5)<br>O5'C3'(T5T5)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{73}$=10.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{73}$:<br>PC3'(T5T5)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T6</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{5}$=36.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{5}$:<br>O1PC5'(T6T6)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{34}$=23.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{34}$:<br>O5'O4'(T6T6)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{49}$=14.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{49}$:<br>PC3'(T6T6)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A7</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{15}$=30.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{15}$:<br>O1PC5'(A7A7)<br>C5'C2'(A7A7)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{25}$=25.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{25}$:<br>O5'O4'(A7A7)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{64}$=11.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{64}$:<br>PC3'(A7A7)<br>O5'C3'(A7A7)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{69}$=10.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{69}$:<br>O1PC4'(A7A7)</td>
#     </tr>
#     <tr>
#       <th>G8</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{10}$=33.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{10}$:<br>O1PC5'(G8G8)<br>C5'C2'(G8G8)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{18}$=29.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{18}$:<br>O5'O4'(G8G8)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{50}$=13.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{50}$:<br>PC3'(G8G8)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{53}$=13.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{53}$:<br>O1PC4'(G8G8)</td>
#     </tr>
#     <tr>
#       <th>G9</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{13}$=30.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{13}$:<br>C5'C1'(G9G9)<br>O1PC5'(G9G9)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{32}$=24.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{32}$:<br>O5'O4'(G9G9)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{59}$=11.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{59}$:<br>O1PC4'(G9G9)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{71}$=10.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{71}$:<br>PC3'(G9G9)</td>
#     </tr>
#     <tr>
#       <th>G10</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{43}$=16.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{43}$:<br>O5'O4'(G10G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{54}$=12.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{54}$:<br>C5'C1'(G10G10)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T11</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{24}$=25.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{24}$:<br>O1PC5'(T11T11)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{31}$=24.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{31}$:<br>O5'O4'(T11T11)<br>O5'C3'(T11T11)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{84}$=9.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{84}$:<br>O1PC4'(T11T11)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T12</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{1}$=38.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{1}$:<br>O1PC5'(T12T12)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{21}$=26.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{21}$:<br>O5'O4'(T12T12)<br>O5'C3'(T12T12)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{51}$=13.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{51}$:<br>PC3'(T12T12)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A13</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{7}$=34.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{7}$:<br>O1PC5'(A13A13)<br>C5'C2'(A13A13)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{26}$=25.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{26}$:<br>O5'O4'(A13A13)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{62}$=11.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{62}$:<br>PC3'(A13A13)<br>O5'C3'(A13A13)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G14</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{4}$=37.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{4}$:<br>O1PC5'(G14G14)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{14}$=30.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{14}$:<br>O5'O4'(G14G14)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{44}$=15.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{44}$:<br>PC3'(G14G14)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G15</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{8}$=34.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{8}$:<br>C5'C1'(G15G15)<br>O1PC5'(G15G15)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{28}$=25.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{28}$:<br>O5'O4'(G15G15)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{52}$=13.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{52}$:<br>PC3'(G15G15)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G16</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{40}$=21.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{40}$:<br>O5'O4'(G16G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{41}$=19.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{41}$:<br>O1PC5'(G16G16)<br>C5'C1'(G16G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{78}$=9.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{78}$:<br>PC3'(G16G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{87}$=8.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{87}$:<br>O1PC4'(G16G16)</td>
#     </tr>
#     <tr>
#       <th>T17</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{29}$=25.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{29}$:<br>O1PC5'(T17T17)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{38}$=22.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{38}$:<br>O5'O4'(T17T17)<br>O5'C3'(T17T17)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{76}$=10.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{76}$:<br>O1PC4'(T17T17)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T18</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{3}$=38.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{3}$:<br>O1PC5'(T18T18)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{27}$=25.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{27}$:<br>O5'O4'(T18T18)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{47}$=14.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{47}$:<br>PC3'(T18T18)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A19</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{11}$=31.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{11}$:<br>O1PC5'(A19A19)<br>C5'C2'(A19A19)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{22}$=26.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{22}$:<br>O5'O4'(A19A19)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{58}$=12.2, ${\{
# Write /home/user/workfolder/g4dna_protocol_demo/dsdna/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/bdna+bdna_PR0.csv

# %%
b_agent.t_agent.mean.df_m.sort_values(by='k', ascending=False)
# Out:
#        Enm_i Strand_i  Resid_i Atomname_i  Atomid_i Enm_j Strand_j  Resid_j  \
# PairID
# 6997    A360  STRAND1       18        O1P       360  A363  STRAND1       18
# 4495    A233  STRAND1       12        O1P       233  A236  STRAND1       12
# 2078    A106  STRAND1        6        O1P       106  A109  STRAND1        6
# 5273    A274  STRAND1       14        O1P       274  A277  STRAND1       14
# 411      A20  STRAND1        2        O1P        20   A23  STRAND1        2
# ...      ...      ...      ...        ...       ...   ...      ...      ...
# 6644    A339  STRAND1       17          P       339  A357  STRAND1       17
# 2843    A146  STRAND1        8          P       146  A152  STRAND1        8
# 6649    A340  STRAND1       17        O1P       340  A356  STRAND1       17
# 6651    A341  STRAND1       17        O2P       341  A343  STRAND1       17
# 8726    A451  STRAND1       22        C1'       451  A465  STRAND1       22
#
#        Atomname_j  Atomid_j          k        b0 Category
# PairID
# 6997          C5'       363  16.733626  2.968942      pr0
# 4495          C5'       236  16.579916  2.968900      pr0
# 2078          C5'       109  15.630495  2.968763      pr0
# 5273          C5'       277  13.486268  2.965532      pr0
# 411           C5'        23  13.235374  2.974211      pr0
# ...           ...       ...        ...       ...      ...
# 6644          C2'       357   0.000000  4.920705      pr0
# 2843          O4'       152   0.000000  4.283763      pr0
# 6649          C3'       356   0.000000  4.851837      pr0
# 6651          C5'       343   0.000000  3.807342      pr0
# 8726          O3'       465   0.000000  2.983147      pr0
#
# [520 rows x 13 columns]

# %%
import sys
sys.path.append("../../smsl")

# %%
from smsl.graphBigtraj import BigTrajGraphAgent
from smsl.graph import PR0

import warnings; warnings.filterwarnings("ignore")
import numpy as np

# %%
## 見論文表B.7
n_mode=90         ## $\alpha_c$
vlv_threshold=0.2 ## $\nu_{\text{c}}$
pe_threshold=0.5  ## $\kappa_{\text{c}}$

# %%
b_agent = BigTrajGraphAgent(PR0)
# Out:
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/0000_0500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/0250_0750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/0500_1000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/0750_1250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/1000_1500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/1250_1750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/1500_2000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/1750_2250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/2000_2500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/2250_2750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/2500_3000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/2750_3250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/3000_3500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/3250_3750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/3500_4000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/3750_4250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/4000_4500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/4250_4750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/4500_5000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/pairtypes_k_b0_cutoff_5.00.csv

# %%
b_agent.spectral_decomposition()
b_agent.set_mean_r_alpha_array()
b_agent.t_agent.mean.GetEigenvectorEigenvectorT()
# Out:
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.

# %%
## 論文 圖5.24(B)
b_agent.plot_prominent_modes_and_identify_atom_with_interactive(strandid=None)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=239, min=1), Output()), _dom_classes=('w…

# %%
b_agent.plot_prominent_modes_and_get_identify_pair_with_interactive(\
        strandid=None, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, filter=True)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=239, min=1), Output()), _dom_classes=('w…

# %%
b_agent.t_agent.mean.get_modes_info(strandid=None, n_mode=n_mode, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, is_return=False)
# Out:
# 100%|██████████| 90/90 [00:00<00:00, 135.77it/s]

# %%
## 論文 圖5.24(C)
b_agent.t_agent.mean.display_df_info_by_resid(save=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#     </tr>
#     <tr>
#       <th>Residue Pair</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A1</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{11}$=42.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{11}$:<br>O5'C3'(A1A1)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{13}$=40.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{13}$:<br>C5'C2'(A1A1)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{38}$=27.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{38}$:<br>O4'O3'(A1A1)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{83}$=11.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{83}$:<br>C1'O3'(A1A1)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G2</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{26}$=33.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{26}$:<br>C1'O3'(G2G2)<br>C5'C1'(G2G2)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{46}$=24.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{46}$:<br>O5'O4'(G2G2)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{67}$=16.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{67}$:<br>C5'C2'(G2G2)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G3</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{7}$=45.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{7}$:<br>O1PC5'(G3G3)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{19}$=37.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{19}$:<br>O5'C3'(G3G3)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{43}$=25.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{43}$:<br>O4'O3'(G3G3)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G4</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{6}$=47.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{6}$:<br>C5'C2'(G4G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{17}$=38.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{17}$:<br>O5'O4'(G4G4)<br>O4'O3'(G4G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{47}$=23.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{47}$:<br>C1'O3'(G4G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{64}$=17.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{64}$:<br>O1PC4'(G4G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{73}$=14.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{73}$:<br>O5'C1'(G4G4)</td>
#     </tr>
#     <tr>
#       <th>T5</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{1}$=60.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{1}$:<br>C5'C2'(T5T5)<br>O1PC5'(T5T5)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{25}$=33.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{25}$:<br>O4'O3'(T5T5)<br>O5'O4'(T5T5)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T6</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{3}$=50.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{3}$:<br>O1PC5'(T6T6)<br>C5'C2'(T6T6)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{12}$=41.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{12}$:<br>O5'O4'(T6T6)<br>O5'C3'(T6T6)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{57}$=19.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{57}$:<br>C1'O3'(T6T6)<br>O4'O3'(T6T6)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A7</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{28}$=32.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{28}$:<br>O5'C3'(A7A7)<br>O5'O4'(A7A7)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{42}$=25.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{42}$:<br>O1PC5'(A7A7)<br>C5'C2'(A7A7)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{55}$=20.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{55}$:<br>O4'O3'(A7A7)<br>C1'O3'(A7A7)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{71}$=14.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{71}$:<br>O1PC4'(A7A7)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G8</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{34}$=30.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{34}$:<br>O4'O3'(G8G8)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{49}$=22.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{49}$:<br>O5'O4'(G8G8)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{70}$=16.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{70}$:<br>O2PC3'(G8G8)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G9</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{21}$=35.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{21}$:<br>O1PC5'(G9G9)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{23}$=34.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{23}$:<br>O5'O4'(G9G9)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{60}$=18.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{60}$:<br>O4'O3'(G9G9)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{85}$=11.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{85}$:<br>C1'O3'(G9G9)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G10</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{5}$=47.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{5}$:<br>O1PC5'(G10G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{10}$=42.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{10}$:<br>O4'O3'(G10G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{44}$=24.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{44}$:<br>O4'O3'(G10G10)<br>O5'C3'(G10G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{81}$=12.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{81}$:<br>C1'O3'(G10G10)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T11</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{2}$=57.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{2}$:<br>C5'C2'(T11T11)<br>O1PC5'(T11T11)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{31}$=31.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{31}$:<br>C1'O3'(T11T11)<br>O4'O3'(T11T11)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{35}$=28.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{35}$:<br>O5'C3'(T11T11)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T12</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{15}$=39.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{15}$:<br>C5'C2'(T12T12)<br>O1PC5'(T12T12)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{16}$=39.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{16}$:<br>O5'C3'(T12T12)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{41}$=26.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{41}$:<br>O4'O3'(T12T12)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A13</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{24}$=33.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{24}$:<br>O5'C3'(A13A13)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{45}$=24.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{45}$:<br>O1PC5'(A13A13)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{56}$=19.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{56}$:<br>O4'O3'(A13A13)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G14</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{22}$=34.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{22}$:<br>C5'C1'(G14G14)<br>C5'C2'(G14G14)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{36}$=28.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{36}$:<br>O4'O3'(G14G14)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{50}$=22.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{50}$:<br>PO4'(G14G14)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{62}$=17.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{62}$:<br>O5'C3'(G14G14)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{63}$=17.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{63}$:<br>O2PC4'(G14G14)</td>
#     </tr>
#     <tr>
#       <th>G15</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{8}$=43.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{8}$:<br>O1PC5'(G15G15)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{18}$=37.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{18}$:<br>O5'O4'(G15G15)<br>O5'C3'(G15G15)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{51}$=22.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{51}$:<br>O4'O3'(G15G15)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{88}$=11.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{88}$:<br>C1'O3'(G15G15)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G16</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{14}$=40.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{14}$:<br>C5'C2'(G16G16)<br>O1PC5'(G16G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{32}$=31.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{32}$:<br>O5'O4'(G16G16)<br>O4'O3'(G16G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{59}$=19.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{59}$:<br>C1'O3'(G16G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{82}$=12.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{82}$:<br>O5'C1'(G16G16)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T17</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{40}$=26.5, ${\{\r
# Write /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/hybrid-ii_ewv_PR0.csv

# %%
b_agent.t_agent.mean.df_m.sort_values(by='k', ascending=False)
# Out:
#        Enm_i Strand_i  Resid_i Atomname_i  Atomid_i Enm_j Strand_j  Resid_j  \
# PairID
# 8371    A423  STRAND1       21        O1P       423  A426  STRAND1       21
# 4725    A235  STRAND1       12        O5'       235  A249  STRAND1       12
# 3949    A191  STRAND1       10        O1P       191  A194  STRAND1       10
# 4338    A216  STRAND1       11        C5'       216  A230  STRAND1       11
# 5906    A296  STRAND1       15        O1P       296  A299  STRAND1       15
# ...      ...      ...      ...        ...       ...   ...      ...      ...
# 6814    A339  STRAND1       17          P       339  A346  STRAND1       17
# 6819    A339  STRAND1       17          P       339  A358  STRAND1       17
# 6822    A340  STRAND1       17        O1P       340  A343  STRAND1       17
# 4317    A214  STRAND1       11        O2P       214  A216  STRAND1       11
# 4726    A235  STRAND1       12        O5'       235  A250  STRAND1       12
#
#        Atomname_j  Atomid_j          k        b0 Category
# PairID
# 8371          C5'       426  19.436442  2.973011      pr0
# 4725          C3'       249  19.410400  2.973489      pr0
# 3949          C5'       194  19.368874  2.979921      pr0
# 4338          C2'       230  19.192605  3.134274      pr0
# 5906          C5'       299  19.119300  2.972505      pr0
# ...           ...       ...        ...       ...      ...
# 6814          C1'       346   0.000000  5.258984      pr0
# 6819          O3'       358   0.000000  5.833647      pr0
# 6822          C5'       343   0.000000  3.060489      pr0
# 4317          C5'       216   0.000000  3.809768      pr0
# 4726          C2'       250   0.000000  3.842958      pr0
#
# [505 rows x 13 columns]

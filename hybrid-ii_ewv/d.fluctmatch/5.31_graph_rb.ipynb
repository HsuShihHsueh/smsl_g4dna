# %%
import sys
sys.path.append("../../smsl")

# %%
from smsl.graphBigtraj import BigTrajGraphAgent
from smsl.graph import RB

import warnings; warnings.filterwarnings("ignore")
import numpy as np

# %%
## 見論文表B.7
n_mode=45         ## $\alpha_c$
vlv_threshold=0.2 ## $\nu_{\text{c}}$
pe_threshold=0.55 ## $\kappa_{\text{c}}$

# %%
b_agent = BigTrajGraphAgent(RB)
# Out:
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/0000_0500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/0250_0750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/0500_1000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/0750_1250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/1000_1500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/1250_1750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/1500_2000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/1750_2250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/2000_2500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/2250_2750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/2500_3000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/2750_3250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/3000_3500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/3250_3750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/3500_4000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/3750_4250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/4000_4500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/4250_4750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/4500_5000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/pairtypes_k_b0_cutoff_5.00.csv

# %%
b_agent.spectral_decomposition()
b_agent.set_mean_r_alpha_array()
b_agent.t_agent.mean.GetEigenvectorEigenvectorT()
# Out:
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.

# %%
## 論文 圖5.23(A)
b_agent.plot_prominent_modes_and_identify_atom_with_interactive(strandid=None)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=465, min=1), Output()), _dom_classes=('w…

# %%
b_agent.plot_prominent_modes_and_get_identify_pair_with_interactive(\
        strandid=None, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, filter=True)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=465, min=1), Output()), _dom_classes=('w…

# %%
b_agent.t_agent.mean.get_modes_info(strandid=None, n_mode=n_mode, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, is_return=False)
# Out:
# 100%|██████████| 45/45 [00:00<00:00, 64.19it/s]

# %%
## 論文 圖5.23(C)
b_agent.t_agent.mean.display_df_info_by_resid(save=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#     <tr>
#       <th>Residue Pair</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A1</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{1}$=113.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{1}$:<br>C4C2'(A1A1)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{36}$=52.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{36}$:<br>C1'N3(A1A1)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G2</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{5}$=89.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{5}$:<br>C4C2'(G2G2)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{35}$=52.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{35}$:<br>C1'N3(G2G2)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G3</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{22}$=67.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{22}$:<br>C8C2'(G3G3)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G4</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{8}$=81.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{8}$:<br>C8C2'(G4G4)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{42}$=46.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{42}$:<br>C1'N3(G4G4)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T5</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{10}$=78.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{10}$:<br>C6C2'(T5T5)<br>O4'C6(T5T5)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{24}$=63.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{24}$:<br>C1'O2(T5T5)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T6</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{6}$=89.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{6}$:<br>C6C2'(T6T6)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{14}$=71.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{14}$:<br>C1'O2(T6T6)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A7</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{18}$=67.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{18}$:<br>C8C2'(A7A7)<br>N7C2'(A7A7)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{39}$=48.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{39}$:<br>C1'N3(A7A7)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G8</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{2}$=101.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{2}$:<br>C4C2'(G8G8)<br>N3C2'(G8G8)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{25}$=63.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{25}$:<br>C1'N3(G8G8)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{37}$=50.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{37}$:<br>O4'C8(G8G8)</td>
#     </tr>
#     <tr>
#       <th>G9</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{19}$=67.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{19}$:<br>C4C2'(G9G9)<br>O4'C4(G9G9)<br>C8C2'(G9G9)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{29}$=57.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{29}$:<br>C1'N3(G9G9)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G10</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{27}$=60.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{27}$:<br>C8C2'(G10G10)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T11</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{3}$=92.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{3}$:<br>C2C2'(T11T11)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{30}$=55.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{30}$:<br>C1'O2(T11T11)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{43}$=46.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{43}$:<br>O4'C6(T11T11)</td>
#     </tr>
#     <tr>
#       <th>T12</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{4}$=91.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{4}$:<br>C1'O2(T12T12)<br>C1'N3(T12T12)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{16}$=69.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{16}$:<br>C4C2'(T12T12)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{32}$=53.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{32}$:<br>C6C3'(T12T12)<br>C2C3'(T12T12)</td>
#     </tr>
#     <tr>
#       <th>A13</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{20}$=67.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{20}$:<br>N7C2'(A13A13)<br>C8C2'(A13A13)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{44}$=44.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{44}$:<br>C1'N3(A13A13)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G14</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{9}$=80.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{9}$:<br>C4C2'(G14G14)<br>N3C2'(G14G14)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{41}$=47.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{41}$:<br>C1'N3(G14G14)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G15</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{23}$=65.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{23}$:<br>C8C2'(G15G15)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G16</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{12}$=75.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{12}$:<br>C8C2'(G16G16)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T17</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{13}$=73.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{13}$:<br>C1'O2(T17T17)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{17}$=68.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{17}$:<br>C1'O2(T17T17)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T18</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{7}$=87.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{7}$:<br>C6C2'(T18T18)<br>C5C2'(T18T18)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{28}$=60.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{28}$:<br>C1'O2(T18T18)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A19</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{26}$=62.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{26}$:<br>C5C2'(A19A19)<br>O4'C5(A19A19)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{34}$=52.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{34}$:<br>C1'N3(A19A19)<br>C1'C6(A19A19)<br>C1'N1(A19A19)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G20</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{15}$=70.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{15}$:<br>C4C2'(G20G20)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{45}$=44.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{45}$:<br>C1'N3(G20G20)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G21</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{31}$=55.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{31}$:<br>C8C2'(G21G21)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G22</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{40}$=47.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{40}$:<br>C1'N3(G22G22)</td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# Write /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_ewv/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/hybrid-ii_ewv_RB.csv

# %%
b_agent.t_agent.mean.df_m.sort_values(by='k', ascending=False)
# Out:
#        Enm_i Strand_i  Resid_i Atomname_i  Atomid_i Enm_j Strand_j  Resid_j  \
# PairID
# 2348    A112  STRAND1        6        C1'       112  A121  STRAND1        6
# 4776    A239  STRAND1       12        C1'       239  A248  STRAND1       12
# 6936    A346  STRAND1       17        C1'       346  A355  STRAND1       17
# 2046     A92  STRAND1        5        C1'        92  A101  STRAND1        5
# 4602    A227  STRAND1       11         C2       227  A230  STRAND1       11
# ...      ...      ...      ...        ...       ...   ...      ...      ...
# 5400    A279  STRAND1       14        O4'       279  A391  STRAND1       19
# 5399    A279  STRAND1       14        O4'       279  A390  STRAND1       19
# 5398    A279  STRAND1       14        O4'       279  A389  STRAND1       19
# 5397    A279  STRAND1       14        O4'       279  A388  STRAND1       19
# 4371    A218  STRAND1       11        O4'       218  A228  STRAND1       11
#
#        Atomname_j  Atomid_j          k        b0 Category
# PairID
# 2348           O2       121  33.623274  2.804753       rb
# 4776           O2       248  31.713789  2.807411       rb
# 6936           O2       355  30.862984  2.803763       rb
# 2046           O2       101  29.723632  2.798605       rb
# 4602          C2'       230  29.677184  3.077789       rb
# ...           ...       ...        ...       ...      ...
# 5400           C6       391   0.000000  7.134005       rb
# 5399           C5       390   0.000000  7.689453       rb
# 5398           N7       389   0.000000  8.183689       rb
# 5397           C8       388   0.000000  8.809063       rb
# 4371           O2       228   0.000000  4.214042       rb
#
# [2083 rows x 13 columns]

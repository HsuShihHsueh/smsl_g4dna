# %%
import sys
sys.path.append("../../smsl")

# %%
from smsl.graphBigtraj import BigTrajGraphAgent
from smsl.graph import RB

import warnings; warnings.filterwarnings("ignore")
import numpy as np

# %%
## 見論文表B.7
n_mode=45         ## $\alpha_c$
vlv_threshold=0.2 ## $\nu_{\text{c}}$
pe_threshold=0.55 ## $\kappa_{\text{c}}$

# %%
b_agent = BigTrajGraphAgent(RB)
# Out:
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/0000_0500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/0250_0750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/0500_1000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/0750_1250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/1000_1500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/1250_1750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/1500_2000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/1750_2250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/2000_2500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/2250_2750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/2500_3000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/2750_3250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/3000_3500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/3250_3750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/3500_4000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/3750_4250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/4000_4500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/4250_4750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/4500_5000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/pairtypes_k_b0_cutoff_5.00.csv

# %%
b_agent.spectral_decomposition()
b_agent.set_mean_r_alpha_array()
b_agent.t_agent.mean.GetEigenvectorEigenvectorT()
# Out:
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.

# %%
## 論文 圖5.23(A)
b_agent.plot_prominent_modes_and_identify_atom_with_interactive(strandid=None)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=545, min=1), Output()), _dom_classes=('w…

# %%
b_agent.plot_prominent_modes_and_get_identify_pair_with_interactive(\
        strandid=None, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, filter=True)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=545, min=1), Output()), _dom_classes=('w…

# %%
b_agent.t_agent.mean.get_modes_info(strandid=None, n_mode=n_mode, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, is_return=False)
# Out:
# 100%|██████████| 45/45 [00:01<00:00, 38.45it/s]

# %%
## 論文 圖5.23(C)
b_agent.t_agent.mean.display_df_info_by_resid(save=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#     <tr>
#       <th>Residue Pair</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>T1</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{17}$=69.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{17}$:<br>C1'O2(T1T1)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T2</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{6}$=81.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{6}$:<br>C1'O2(T2T2)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{40}$=51.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{40}$:<br>C5C2'(T2T2)<br>C6C2'(T2T2)<br>O4'C5(T2T2)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A3</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{21}$=64.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{21}$:<br>C8C2'(A3A3)<br>O4'C8(A3A3)<br>N7C2'(A3A3)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G4</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{22}$=64.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{22}$:<br>C4C2'(G4G4)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{38}$=53.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{38}$:<br>C1'N3(G4G4)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G5</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{31}$=58.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{31}$:<br>C8C2'(G5G5)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T7</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{9}$=77.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{9}$:<br>C6C2'(T7T7)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{19}$=69.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{19}$:<br>C1'O2(T7T7)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T8</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{4}$=84.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{4}$:<br>C6C2'(T8T8)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{12}$=75.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{12}$:<br>C1'O2(T8T8)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G10</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{1}$=90.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{1}$:<br>C4C2'(G10G10)<br>C8C2'(G10G10)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{27}$=62.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{27}$:<br>C1'N3(G10G10)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{37}$=53.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{37}$:<br>O4'C8(G10G10)</td>
#     </tr>
#     <tr>
#       <th>G11</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{7}$=80.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{7}$:<br>C4C2'(G11G11)<br>C8C2'(G11G11)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{39}$=51.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{39}$:<br>C1'N3(G11G11)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{43}$=48.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{43}$:<br>O4'C8(G11G11)</td>
#     </tr>
#     <tr>
#       <th>G12</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{28}$=62.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{28}$:<br>C8C2'(G12G12)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T13</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{2}$=87.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{2}$:<br>C6C2'(T13T13)<br>C5C2'(T13T13)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{10}$=77.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{10}$:<br>C1'O2(T13T13)<br>C1'C5M(T13T13)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T14</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{20}$=66.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{20}$:<br>C1'O2(T14T14)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A15</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{25}$=64.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{25}$:<br>O4'N7(A15A15)<br>O4'C5(A15A15)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{36}$=54.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{36}$:<br>C1'N3(A15A15)<br>C1'C6(A15A15)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G16</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{29}$=61.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{29}$:<br>C4C2'(G16G16)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{42}$=50.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{42}$:<br>C1'N3(G16G16)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G18</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{35}$=55.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{35}$:<br>C8C2'(G18G18)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T19</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{15}$=72.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{15}$:<br>C1'O2(T19T19)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{18}$=69.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{18}$:<br>C1'O2(T19T19)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T20</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{3}$=85.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{3}$:<br>C6C2'(T20T20)<br>C5C2'(T20T20)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{32}$=58.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{32}$:<br>C1'O2(T20T20)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A21</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{26}$=63.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{26}$:<br>C1'N3(A21A21)<br>C1'N1(A21A21)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G22</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{5}$=81.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{5}$:<br>C4C2'(G22G22)<br>C8C2'(G22G22)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G24</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{30}$=59.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{30}$:<br>C8C2'(G24G24)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T25</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{8}$=78.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{8}$:<br>C6C2'(T25T25)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{13}$=74.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{13}$:<br>C1'O2(T25T25)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T26</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{16}$=70.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{16}$:<br>C6C2'(T26T26)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{23}$=64.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{23}$:<br>C1'O2(T26T26)</td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# Write /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/hybrid-ii_poh_RB.csv

# %%
b_agent.t_agent.mean.df_m.sort_values(by='k', ascending=False)
# Out:
#        Enm_i Strand_i  Resid_i Atomname_i  Atomid_i Enm_j Strand_j  Resid_j  \
# PairID
# 4001    A152  STRAND1        8        C1'       152  A161  STRAND1        8
# 755      A25  STRAND1        2        C1'        25   A34  STRAND1        2
# 9087    A386  STRAND1       19        C1'       386  A395  STRAND1       19
# 141       A5  STRAND1        1        C1'         5   A14  STRAND1        1
# 4064    A154  STRAND1        8         C6       154  A163  STRAND1        8
# ...      ...      ...      ...        ...       ...   ...      ...      ...
# 4411    A168  STRAND1        9        O5'       168  A176  STRAND1        9
# 4410    A168  STRAND1        9        O5'       168  A175  STRAND1        9
# 4400    A167  STRAND1        9        O2P       167  A542  STRAND1       26
# 4362    A165  STRAND1        9          P       165  A175  STRAND1        9
# 5361    A204  STRAND1       10         C4       204  A215  STRAND1       11
#
#        Atomname_j  Atomid_j          k        b0 Category
# PairID
# 4001           O2       161  34.976784  2.799232       rb
# 755            O2        34  34.325589  2.802753       rb
# 9087           O2       395  31.529984  2.803837       rb
# 141            O2        14  30.482595  2.806121       rb
# 4064          C2'       163  30.163153  3.097442       rb
# ...           ...       ...        ...       ...      ...
# 4411           C5       176   0.000000  6.431532       rb
# 4410           N7       175   0.000000  5.808726       rb
# 4400           O2       542   0.000000  6.694358       rb
# 4362           N7       175   0.000000  6.835874       rb
# 5361          C1'       215   0.000000  6.085279       rb
#
# [2855 rows x 13 columns]

# %%
import sys
sys.path.append("../../smsl")

# %%
from smsl.graphBigtraj import BigTrajGraphAgent
from smsl.graph import PR0

import warnings; warnings.filterwarnings("ignore")
import numpy as np

# %%
## 見論文表B.7
n_mode=90         ## $\alpha_c$
vlv_threshold=0.2 ## $\nu_{\text{c}}$
pe_threshold=0.5  ## $\kappa_{\text{c}}$

# %%
b_agent = BigTrajGraphAgent(PR0)
# Out:
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/0000_0500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/0250_0750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/0500_1000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/0750_1250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/1000_1500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/1250_1750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/1500_2000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/1750_2250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/2000_2500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/2250_2750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/2500_3000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/2750_3250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/3000_3500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/3250_3750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/3500_4000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/3750_4250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/4000_4500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/4250_4750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/4500_5000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/pairtypes_k_b0_cutoff_5.00.csv

# %%
b_agent.spectral_decomposition()
b_agent.set_mean_r_alpha_array()
b_agent.t_agent.mean.GetEigenvectorEigenvectorT()
# Out:
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.

# %%
## 論文 圖5.24(B)
b_agent.plot_prominent_modes_and_identify_atom_with_interactive(strandid=None)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=283, min=1), Output()), _dom_classes=('w…

# %%
b_agent.plot_prominent_modes_and_get_identify_pair_with_interactive(\
        strandid=None, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, filter=True)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=283, min=1), Output()), _dom_classes=('w…

# %%
b_agent.t_agent.mean.get_modes_info(strandid=None, n_mode=n_mode, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, is_return=False)
# Out:
# 100%|██████████| 90/90 [00:00<00:00, 112.32it/s]

# %%
## 論文 圖5.24(C)
b_agent.t_agent.mean.display_df_info_by_resid(save=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#     </tr>
#     <tr>
#       <th>Residue Pair</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>T1</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{52}$=19.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{52}$:<br>C5'C2'(T1T1)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{69}$=14.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{69}$:<br>O4'O3'(T1T1)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{83}$=10.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{83}$:<br>O5'C3'(T1T1)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T2</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{34}$=26.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{34}$:<br>C5'C2'(T2T2)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{40}$=23.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{40}$:<br>O4'O3'(T2T2)<br>O5'O4'(T2T2)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{66}$=16.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{66}$:<br>O5'C3'(T2T2)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A3</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{4}$=44.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{4}$:<br>O1PC5'(A3A3)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{16}$=35.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{16}$:<br>O5'O4'(A3A3)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{43}$=22.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{43}$:<br>C1'O3'(A3A3)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G4</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{41}$=23.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{41}$:<br>C1'O3'(G4G4)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G5</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{6}$=41.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{6}$:<br>O1PC5'(G5G5)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{17}$=35.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{17}$:<br>O5'O4'(G5G5)<br>O5'C3'(G5G5)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{62}$=16.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{62}$:<br>O4'O3'(G5G5)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G6</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{3}$=44.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{3}$:<br>O1PC5'(G6G6)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{30}$=28.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{30}$:<br>O5'O4'(G6G6)<br>O4'O3'(G6G6)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{57}$=17.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{57}$:<br>PC4'(G6G6)<br>PC3'(G6G6)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{76}$=12.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{76}$:<br>C1'O3'(G6G6)</td>
#     </tr>
#     <tr>
#       <th>T7</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{46}$=20.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{46}$:<br>C5'C2'(T7T7)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{68}$=15.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{68}$:<br>C1'O3'(T7T7)<br>O4'O3'(T7T7)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T8</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{23}$=33.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{23}$:<br>C5'C2'(T8T8)<br>O1PC5'(T8T8)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{26}$=31.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{26}$:<br>O5'C3'(T8T8)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{48}$=19.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{48}$:<br>O4'O3'(T8T8)<br>C1'O3'(T8T8)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A9</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{10}$=39.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{10}$:<br>O5'O4'(A9A9)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{11}$=38.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{11}$:<br>O1PC5'(A9A9)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{47}$=20.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{47}$:<br>O4'O3'(A9A9)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{75}$=13.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{75}$:<br>C1'O3'(A9A9)</td>
#     </tr>
#     <tr>
#       <th>G10</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{21}$=33.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{21}$:<br>C1'O3'(G10G10)<br>C5'C1'(G10G10)<br>O4'O3'(G10G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{37}$=24.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{37}$:<br>O5'O4'(G10G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{84}$=10.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{84}$:<br>O2PC4'(G10G10)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G11</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{65}$=16.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{65}$:<br>O5'C3'(G11G11)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G12</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{5}$=43.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{5}$:<br>O1PC5'(G12G12)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{12}$=37.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{12}$:<br>O5'O4'(G12G12)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{51}$=19.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{51}$:<br>O4'O3'(G12G12)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{87}$=10.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{87}$:<br>C1'O3'(G12G12)</td>
#     </tr>
#     <tr>
#       <th>T13</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{25}$=31.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{25}$:<br>C5'C2'(T13T13)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{45}$=20.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{45}$:<br>O4'O3'(T13T13)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{60}$=17.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{60}$:<br>O5'C3'(T13T13)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T14</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{39}$=24.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{39}$:<br>O5'C3'(T14T14)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{53}$=18.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{53}$:<br>C5'C2'(T14T14)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{78}$=12.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{78}$:<br>O4'O3'(T14T14)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A15</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{20}$=33.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{20}$:<br>O5'C3'(A15A15)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{22}$=33.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{22}$:<br>O1PC5'(A15A15)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{50}$=19.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{50}$:<br>C1'O3'(A15A15)<br>O4'O3'(A15A15)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G16</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{55}$=18.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{55}$:<br>O1PC5'(G16G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{64}$=16.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{64}$:<br>O5'O4'(G16G16)<br>O4'O3'(G16G16)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G17</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{2}$=45.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{2}$:<br>O1PC5'(G17G17)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{31}$=28.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{31}$:<br>O5'O4'(G17G17)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{63}$=16.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{63}$:<br>PC3'(G17G17)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G18</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{13}$=37.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{13}$:<br>C5'C2'(G18G18)<br>O1PC5'(G18G18)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{27}$=30.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{27}$:<br>O4'O3'(G18G18)<br>O5'O4'(G18G18)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{44}$=20.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{44}$:<br>C1'O3'(G18G18)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T19</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{38}$=24.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{38}$:<br>O5'O4'(T19T19)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{61}$=16.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{61}$:<br>C5'C2'(T19T19)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{89}$=10.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{89}$:<br>O5'C3'(T19T19)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T20</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{9}$=40.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{9}$:<br>O5'C3'(T20T20)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{35}$=25.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{35}$:<br>C5'C2'(T20T20)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{56}$=17.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{56}$:<br>O4'O3'(T20T20)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A21</th>
#       <td>
# Write /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_poh/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/hybrid-ii_poh_PR0.csv

# %%
b_agent.t_agent.mean.df_m.sort_values(by='k', ascending=False)
# Out:
#        Enm_i Strand_i  Resid_i Atomname_i  Atomid_i Enm_j Strand_j  Resid_j  \
# PairID
# 9511    A402  STRAND1       20        O5'       402  A416  STRAND1       20
# 2392     A82  STRAND1        5        O1P        82   A85  STRAND1        5
# 8028    A336  STRAND1       17        O1P       336  A339  STRAND1       17
# 5822    A231  STRAND1       12        O1P       231  A234  STRAND1       12
# 10650   A463  STRAND1       23        O1P       463  A466  STRAND1       23
# ...      ...      ...      ...        ...       ...   ...      ...      ...
# 1770     A60  STRAND1        4        O1P        60   A80  STRAND1        4
# 3896    A146  STRAND1        8        O1P       146  A150  STRAND1        8
# 10122   A443  STRAND1       22        O5'       443  A446  STRAND1       22
# 10111   A442  STRAND1       22        O2P       442  A461  STRAND1       22
# 8561    A359  STRAND1       18        O2P       359  A361  STRAND1       18
#
#        Atomname_j  Atomid_j          k        b0 Category
# PairID
# 9511          C3'       416  19.461053  2.999816      pr0
# 2392          C5'        85  19.212316  2.974353      pr0
# 8028          C5'       339  18.972674  2.951816      pr0
# 5822          C5'       234  18.309758  2.972442      pr0
# 10650         C5'       466  18.238584  2.971363      pr0
# ...           ...       ...        ...       ...      ...
# 1770          O3'        80   0.000000  6.099637      pr0
# 3896          C4'       150   0.000000  4.417879      pr0
# 10122         O4'       446   0.000000  3.681995      pr0
# 10111         O3'       461   0.000000  4.180900      pr0
# 8561          C5'       361   0.000000  3.803705      pr0
#
# [631 rows x 13 columns]

# %%
import sys
sys.path.append("../../smsl")

# %%
from smsl.graphBigtraj import BigTrajGraphAgent
from smsl.graph import PR0

import warnings; warnings.filterwarnings("ignore")
import numpy as np

# %%
## 見論文表B.7
n_mode=90         ## $\alpha_c$
vlv_threshold=0.2 ## $\nu_{\text{c}}$
pe_threshold=0.5  ## $\kappa_{\text{c}}$

# %%
b_agent = BigTrajGraphAgent(PR0)
# Out:
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/0000_0500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/0250_0750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/0500_1000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/0750_1250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/1000_1500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/1250_1750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/1500_2000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/1750_2250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/2000_2500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/2250_2750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/2500_3000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/2750_3250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/3000_3500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/3250_3750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/3500_4000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/3750_4250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/4000_4500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/4250_4750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/4500_5000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/pairtypes_k_b0_cutoff_5.00.csv

# %%
b_agent.spectral_decomposition()
b_agent.set_mean_r_alpha_array()
b_agent.t_agent.mean.GetEigenvectorEigenvectorT()
# Out:
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.

# %%
## 論文 圖5.24(B)
b_agent.plot_prominent_modes_and_identify_atom_with_interactive(strandid=None)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=239, min=1), Output()), _dom_classes=('w…

# %%
b_agent.plot_prominent_modes_and_get_identify_pair_with_interactive(\
        strandid=None, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, filter=True)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=239, min=1), Output()), _dom_classes=('w…

# %%
b_agent.t_agent.mean.get_modes_info(strandid=None, n_mode=n_mode, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, is_return=False)
# Out:
# 100%|██████████| 90/90 [00:00<00:00, 186.04it/s]

# %%
## 論文 圖5.24(C)
b_agent.t_agent.mean.display_df_info_by_resid(save=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#     </tr>
#     <tr>
#       <th>Residue Pair</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A1</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{43}$=22.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{43}$:<br>C5'C1'(A1A1)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{78}$=11.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{78}$:<br>O5'C3'(A1A1)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G2</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{26}$=32.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{26}$:<br>C5'O3'(G2G2)<br>C1'O3'(G2G2)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{39}$=25.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{39}$:<br>O5'O4'(G2G2)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{64}$=14.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{64}$:<br>C5'C2'(G2G2)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G3</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{15}$=36.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{15}$:<br>O1PC5'(G3G3)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{27}$=32.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{27}$:<br>O5'C3'(G3G3)<br>O5'O4'(G3G3)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G4</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{7}$=40.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{7}$:<br>O1PC5'(G4G4)<br>C5'C2'(G4G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{30}$=31.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{30}$:<br>O5'O4'(G4G4)<br>O4'O3'(G4G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{55}$=17.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{55}$:<br>C1'O3'(G4G4)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T5</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{1}$=53.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{1}$:<br>C5'C2'(T5T5)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{21}$=34.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{21}$:<br>O4'O3'(T5T5)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{52}$=18.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{52}$:<br>O5'O4'(T5T5)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T6</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{9}$=39.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{9}$:<br>O5'C3'(T6T6)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{12}$=38.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{12}$:<br>O1PC5'(T6T6)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{53}$=17.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{53}$:<br>O4'O3'(T6T6)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A7</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{22}$=34.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{22}$:<br>O5'C3'(A7A7)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{42}$=23.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{42}$:<br>C5'C2'(A7A7)<br>O1PC5'(A7A7)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{44}$=22.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{44}$:<br>C1'O3'(A7A7)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{70}$=12.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{70}$:<br>O1PC4'(A7A7)</td>
#     </tr>
#     <tr>
#       <th>G8</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{11}$=38.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{11}$:<br>C1'O3'(G8G8)<br>O4'O3'(G8G8)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{38}$=26.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{38}$:<br>C5'C2'(G8G8)<br>O2PC5'(G8G8)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{45}$=21.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{45}$:<br>O5'O4'(G8G8)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{81}$=11.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{81}$:<br>O2PC4'(G8G8)</td>
#     </tr>
#     <tr>
#       <th>G9</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{46}$=21.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{46}$:<br>O5'C3'(G9G9)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{72}$=12.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{72}$:<br>O2PO4'(G9G9)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G10</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{5}$=42.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{5}$:<br>O1PC5'(G10G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{19}$=34.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{19}$:<br>O5'C3'(G10G10)<br>O5'O4'(G10G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{58}$=15.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{58}$:<br>O4'O3'(G10G10)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T11</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{10}$=39.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{10}$:<br>O5'O4'(T11T11)<br>O4'O3'(T11T11)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{23}$=33.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{23}$:<br>O1PC5'(T11T11)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T12</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{14}$=37.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{14}$:<br>O5'C3'(T12T12)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{16}$=36.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{16}$:<br>C5'C2'(T12T12)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{32}$=29.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{32}$:<br>O4'O3'(T12T12)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A13</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{2}$=52.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{2}$:<br>C5'C2'(A13A13)<br>O1PC5'(A13A13)<br>C5'C1'(A13A13)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{33}$=28.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{33}$:<br>C1'O3'(A13A13)<br>O4'O3'(A13A13)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{63}$=14.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{63}$:<br>O5'C3'(A13A13)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{73}$=12.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{73}$:<br>PC4'(A13A13)</td>
#     </tr>
#     <tr>
#       <th>G14</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{25}$=32.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{25}$:<br>O5'O4'(G14G14)<br>O4'O3'(G14G14)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{34}$=28.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{34}$:<br>O1PC5'(G14G14)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{65}$=13.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{65}$:<br>C1'O3'(G14G14)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G15</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{6}$=41.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{6}$:<br>O1PC5'(G15G15)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{36}$=27.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{36}$:<br>O5'O4'(G15G15)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{60}$=14.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{60}$:<br>PC3'(G15G15)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G16</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{28}$=32.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{28}$:<br>O4'O3'(G16G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{37}$=27.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{37}$:<br>C5'C2'(G16G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{62}$=14.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{62}$:<br>O5'O4'(G16G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{66}$=13.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{66}$:<br>O1PC4'(G16G16)</td>
#     </tr>
#     <tr>
#       <th>T17</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{4}$=47.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{4}$:<br>C5'C2'(T17T17)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{35}$=27.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{35}$:<br>O4'O3'(T17T17)<br>C1'O3'(T17T17)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{48}$=19.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{48}$:<br>O5'C3'(T17T17)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T18</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{13}$=37.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{13}$:<br>O1PC5'(T18T18)<br>C5'C2'(T18T18)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{20}$=34.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{20}$:<br>O5'C3'(T18T18)<br>O5'O4'(T18T18)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{56}$=16.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{56}$:<br>O4'O3'(T18T18)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A19</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{18}$=35.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{18}$:<br>C5'C2'(A19A19)<br>C5'C1'(A19A19)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{31}$=29.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{31}$:<br>O5'C3'(A19A19)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{41}$=24.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{41}$:<br>O4'O3'(A19A19)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G20</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{3}$=
# Write /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/hybrid-ii_PR0.csv

# %%
b_agent.t_agent.mean.df_m.sort_values(by='k', ascending=False)
# Out:
#        Enm_i Strand_i  Resid_i Atomname_i  Atomid_i Enm_j Strand_j  Resid_j  \
# PairID
# 2224     A89  STRAND1        5        C5'        89  A103  STRAND1        5
# 8131    A423  STRAND1       21        O1P       423  A426  STRAND1       21
# 6180    A296  STRAND1       15        O1P       296  A299  STRAND1       15
# 1082     A42  STRAND1        3        O1P        42   A45  STRAND1        3
# 5019    A235  STRAND1       12        O5'       235  A249  STRAND1       12
# ...      ...      ...      ...        ...       ...   ...      ...      ...
# 2948    A125  STRAND1        7          P       125  A132  STRAND1        7
# 2947    A125  STRAND1        7          P       125  A131  STRAND1        7
# 2946    A125  STRAND1        7          P       125  A130  STRAND1        7
# 2543    A109  STRAND1        6        C5'       109  A124  STRAND1        6
# 8525    A451  STRAND1       22        C1'       451  A465  STRAND1       22
#
#        Atomname_j  Atomid_j          k        b0 Category
# PairID
# 2224          C2'       103  19.702837  3.269558      pr0
# 8131          C5'       426  19.434074  2.966511      pr0
# 6180          C5'       299  19.011584  2.972184      pr0
# 1082          C5'        45  18.337068  2.980032      pr0
# 5019          C3'       249  18.165579  3.021237      pr0
# ...           ...       ...        ...       ...      ...
# 2948          C1'       132   0.000000  4.993853      pr0
# 2947          O4'       131   0.000000  4.322768      pr0
# 2946          C4'       130   0.000000  3.937700      pr0
# 2543          O3'       124   0.000000  3.666968      pr0
# 8525          O3'       465   0.000000  2.980326      pr0
#
# [510 rows x 13 columns]

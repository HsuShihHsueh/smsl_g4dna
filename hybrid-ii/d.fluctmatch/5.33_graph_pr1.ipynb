# %%
import sys
sys.path.append("../../smsl")

# %%
from smsl.graphBigtraj import BigTrajGraphAgent
from smsl.graph import PR1

import warnings; warnings.filterwarnings("ignore")
import numpy as np

# %%
## 見論文表B.7
n_mode=90         ## $\alpha_c$
vlv_threshold=0.2 ## $\nu_{\text{c}}$
pe_threshold=0.5  ## $\kappa_{\text{c}}$

# %%
b_agent = BigTrajGraphAgent(PR1)
# Out:
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/0000_0500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/0250_0750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/0500_1000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/0750_1250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/1000_1500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/1250_1750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/1500_2000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/1750_2250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/2000_2500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/2250_2750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/2500_3000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/2750_3250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/3000_3500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/3250_3750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/3500_4000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/3750_4250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/4000_4500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/4250_4750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/4500_5000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/pairtypes_k_b0_cutoff_5.00.csv

# %%
b_agent.spectral_decomposition()
b_agent.set_mean_r_alpha_array()
b_agent.t_agent.mean.GetEigenvectorEigenvectorT()
# Out:
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.

# %%
## 論文 圖5.25(B)
b_agent.plot_prominent_modes_and_identify_atom_with_interactive(strandid=None)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=239, min=1), Output()), _dom_classes=('w…

# %%
b_agent.plot_prominent_modes_and_get_identify_pair_with_interactive(\
        strandid=None, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, filter=True)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=239, min=1), Output()), _dom_classes=('w…

# %%
b_agent.t_agent.mean.get_modes_info(strandid=None, n_mode=n_mode, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, is_return=False)
# Out:
# 100%|██████████| 90/90 [00:00<00:00, 139.07it/s]

# %%
## 論文 圖5.25(C)
b_agent.t_agent.mean.display_df_info_by_resid(save=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#     </tr>
#     <tr>
#       <th>Residue Pair</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A1G2</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{63}$=9.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{63}$:<br>O3'C5'(A1G2)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{64}$=9.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_
0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{56}$:<br>O3'C5'(G14G15)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G15G16</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{38}$=16.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{38}$:<br>O3'C5'(G15G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{41}$=16.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{41}$:<br>C4'O2P(G15G16)<br>C3'O2P(G15G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{51}$=13.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{51}$:<br>C2'O1P(G15G16)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G16T17</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{21}$=30.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{21}$:<br>C3'O1P(G16T17)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T17T18</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{24}$=27.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{24}$:<br>C3'O2P(T17T18)<br>C3'O5'(T17T18)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{60}$=11.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{60}$:<br>C4'C5'(T17T18)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T18A19</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{22}$=29.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{22}$:<br>C3'O2P(T18A19)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{26}$=21.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{26}$:<br>C4'O5'(T18A19)<br>O3'C4'(T17T18)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{65}$=9.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{65}$:<br>O3'C5'(T18A19)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{68}$=8.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{68}$:<br>C2'O1P(T18A19)</td>
#     </tr>
#     <tr>
#       <th>A19G20</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{17}$=36.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{17}$:<br>C3'O2P(A19G20)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{81}$=5.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{81}$:<br>C4'O1P(A19G20)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{90}$=4.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{90}$:<br>O3'C4'(A19G20)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G20G21</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{8}$=48.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{8}$:<br>C3'O2P(G20G21)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{11}$=47.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{11}$:<br>C2'P(G20
# Write /home/user/workfolder/g4dna_protocol_demo/hybrid-ii/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/hybrid-ii_PR1.csv

# %%
b_agent.t_agent.mean.df_m.sort_values(by='k', ascending=False)
# Out:
#        Enm_i Strand_i  Resid_i Atomname_i  Atomid_i Enm_j Strand_j  Resid_j  \
# PairID
# 4542    A209  STRAND1       10        C3'       209  A214  STRAND1       11
# 3780    A165  STRAND1        8        C3'       165  A170  STRAND1        9
# 4169    A187  STRAND1        9        C3'       187  A192  STRAND1       10
# 5749    A270  STRAND1       13        C3'       270  A275  STRAND1       14
# 1043     A38  STRAND1        2        C3'        38   A43  STRAND1        3
# ...      ...      ...      ...        ...       ...   ...      ...      ...
# 3908    A175  STRAND1        9        C1'       175  A196  STRAND1       10
# 3909    A175  STRAND1        9        C1'       175  A197  STRAND1       10
# 4173    A187  STRAND1        9        C3'       187  A196  STRAND1       10
# 4178    A188  STRAND1        9        C2'       188  A192  STRAND1       10
# 8449    A443  STRAND1       21        O3'       443  A464  STRAND1       22
#
#        Atomname_j  Atomid_j          k        b0 Category
# PairID
# 4542          O2P       214  26.191995  2.927305      pr1
# 3780          O2P       170  25.422863  2.933774      pr1
# 4169          O2P       192  24.225389  2.927163      pr1
# 5749          O2P       275  24.119295  2.933847      pr1
# 1043          O2P        43  23.218300  2.946368      pr1
# ...           ...       ...        ...       ...      ...
# 3908          O4'       196   0.000000  4.105000      pr1
# 3909          C1'       197   0.000000  4.996774      pr1
# 4173          O4'       196   0.000000  4.986847      pr1
# 4178          O2P       192   0.000000  3.558479      pr1
# 8449          C2'       464   0.000000  5.402921      pr1
#
# [983 rows x 13 columns]

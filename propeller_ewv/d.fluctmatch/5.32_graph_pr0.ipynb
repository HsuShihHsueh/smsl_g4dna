# %%
import sys
sys.path.append("../../smsl")

# %%
from smsl.graphBigtraj import BigTrajGraphAgent
from smsl.graph import PR0

import warnings; warnings.filterwarnings("ignore")
import numpy as np

# %%
## 見論文表B.7
n_mode=90         ## $\alpha_c$
vlv_threshold=0.2 ## $\nu_{\text{c}}$
pe_threshold=0.5  ## $\kappa_{\text{c}}$

# %%
b_agent = BigTrajGraphAgent(PR0)
# Out:
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_ewv/d.fluctmatch/bigtraj_fluctmatch/0000_0500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_ewv/d.fluctmatch/bigtraj_fluctmatch/0250_0750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_ewv/d.fluctmatch/bigtraj_fluctmatch/0500_1000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_ewv/d.fluctmatch/bigtraj_fluctmatch/0750_1250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_ewv/d.fluctmatch/bigtraj_fluctmatch/1000_1500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_ewv/d.fluctmatch/bigtraj_fluctmatch/1250_1750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_ewv/d.fluctmatch/bigtraj_fluctmatch/1500_2000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_ewv/d.fluctmatch/bigtraj_fluctmatch/1750_2250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_ewv/d.fluctmatch/bigtraj_fluctmatch/2000_2500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_ewv/d.fluctmatch/bigtraj_fluctmatch/2250_2750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_ewv/d.fluctmatch/bigtraj_fluctmatch/2500_3000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_ewv/d.fluctmatch/bigtraj_fluctmatch/2750_3250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_ewv/d.fluctmatch/bigtraj_fluctmatch/3000_3500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_ewv/d.fluctmatch/bigtraj_fluctmatch/3250_3750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_ewv/d.fluctmatch/bigtraj_fluctmatch/3500_4000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_ewv/d.fluctmatch/bigtraj_fluctmatch/3750_4250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_ewv/d.fluctmatch/bigtraj_fluctmatch/4000_4500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_ewv/d.fluctmatch/bigtraj_fluctmatch/4250_4750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_ewv/d.fluctmatch/bigtraj_fluctmatch/4500_5000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_ewv/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/pairtypes_k_b0_cutoff_5.00.csv

# %%
b_agent.spectral_decomposition()
b_agent.set_mean_r_alpha_array()
b_agent.t_agent.mean.GetEigenvectorEigenvectorT()
# Out:
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.

# %%
## 論文 圖5.24(B)
b_agent.plot_prominent_modes_and_identify_atom_with_interactive(strandid=None)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=239, min=1), Output()), _dom_classes=('w…

# %%
b_agent.plot_prominent_modes_and_get_identify_pair_with_interactive(\
        strandid=None, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, filter=True)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=239, min=1), Output()), _dom_classes=('w…

# %%
b_agent.t_agent.mean.get_modes_info(strandid=None, n_mode=n_mode, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, is_return=False)
# Out:
# 100%|██████████| 90/90 [00:00<00:00, 134.07it/s]

# %%
## 論文 圖5.24(C)
b_agent.t_agent.mean.display_df_info_by_resid(save=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#     </tr>
#     <tr>
#       <th>Residue Pair</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A1</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{11}$=34.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{11}$:<br>C5'C2'(A1A1)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{30}$=27.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{30}$:<br>O5'C3'(A1A1)<br>O5'O4'(A1A1)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{50}$=17.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{50}$:<br>O4'O3'(A1A1)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G2</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{35}$=24.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{35}$:<br>O1PC5'(G2G2)<br>C5'C2'(G2G2)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{38}$=24.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{38}$:<br>O5'O4'(G2G2)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{61}$=13.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{61}$:<br>O1PC4'(G2G2)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{74}$=10.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{74}$:<br>PC3'(G2G2)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G3</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{6}$=35.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{6}$:<br>O5'C3'(G3G3)<br>O5'O4'(G3G3)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{29}$=28.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{29}$:<br>O1PC5'(G3G3)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G4</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{3}$=41.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{3}$:<br>C5'C2'(G4G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{16}$=32.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{16}$:<br>O4'O3'(G4G4)<br>O5'O4'(G4G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{49}$=17.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{49}$:<br>C1'O3'(G4G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{65}$=11.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{65}$:<br>O1PC4'(G4G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{86}$=8.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{86}$:<br>O2PC3'(G4G4)</td>
#     </tr>
#     <tr>
#       <th>T5</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{2}$=41.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{2}$:<br>C5'C2'(T5T5)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{22}$=30.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{22}$:<br>O4'O3'(T5T5)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{72}$=10.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{72}$:<br>O5'C3'(T5T5)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T6</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{4}$=41.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{4}$:<br>C5'C2'(T6T6)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{9}$=35.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{9}$:<br>O5'O4'(T6T6)<br>O4'O3'(T6T6)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{46}$=19.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{46}$:<br>C1'O3'(T6T6)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A7</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{1}$=46.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{1}$:<br>O1PC5'(A7A7)<br>C5'C2'(A7A7)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{8}$=35.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{8}$:<br>O5'O4'(A7A7)<br>O5'C3'(A7A7)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{47}$=18.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{47}$:<br>O4'O3'(A7A7)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G8</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{32}$=25.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{32}$:<br>O5'C3'(G8G8)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{37}$=24.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{37}$:<br>C1'O3'(G8G8)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{56}$=14.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{56}$:<br>C5'C2'(G8G8)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G9</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{42}$=21.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{42}$:<br>O5'O4'(G9G9)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G10</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{5}$=41.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{5}$:<br>C5'C2'(G10G10)<br>O1PC5'(G10G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{14}$=33.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{14}$:<br>O4'O3'(G10G10)<br>O5'O4'(G10G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{44}$=19.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{44}$:<br>C1'O3'(G10G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{52}$=16.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{52}$:<br>O1PC4'(G10G10)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T11</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{21}$=30.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{21}$:<br>C5'C1'(T11T11)<br>C5'C2'(T11T11)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{24}$=28.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{24}$:<br>O5'O4'(T11T11)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{68}$=11.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{68}$:<br>C1'O3'(T11T11)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{87}$=8.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{87}$:<br>O1PC4'(T11T11)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T12</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{18}$=32.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{18}$:<br>O4'O3'(T12T12)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{33}$=25.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{33}$:<br>C5'C2'(T12T12)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{53}$=16.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{53}$:<br>O5'C3'(T12T12)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A13</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{15}$=33.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{15}$:<br>C5'C2'(A13A13)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{34}$=25.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{34}$:<br>O5'C3'(A13A13)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{62}$=13.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{62}$:<br>O1PO4'(A13A13)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G14</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{13}$=33.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{13}$:<br>O1PC5'(G14G14)<br>C5'C2'(G14G14)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{31}$=27.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{31}$:<br>O5'C3'(G14G14)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{51}$=17.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{51}$:<br>C1'O3'(G14G14)<br>O4'O3'(G14G14)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G15</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{43}$=19.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{43}$:<br>O5'O4'(G15G15)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{84}$=9.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{84}$:<br>O1PC5'(G15G15)<br>C5'C2'(G15G15)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{88}$=8.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{88}$:<br>PC3'(G15G15)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G16</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{7}$=35.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{7}$:<br>C5'C2'(G16G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{20}$=31.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{20}$:<br>O5'O4'(G16G16)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T17</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{25}$=28.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{25}$:<br>C5'C2'(T17T17)<br>C5'C1'(T17T17)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{36}$=24.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{36}$:<br>O5'O4'(T17T17)<br>O5'C3'(T17T17)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{60}$=13.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{60}$:<br>O4'O3'(T17T17)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T18</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{12}$=33.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{12}$:<br>C5'C2'(T18T18)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{26}$=28.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{26}$:<br>O5'C3'(T18T18)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{39}$=23.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{39}$:<br>O4'O3'(T18T18)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A19</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{19}$=32.2, ${\{\rm{a}_i
# Write /home/user/workfolder/g4dna_protocol_demo/propeller_ewv/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/propeller_ewv_PR0.csv

# %%
b_agent.t_agent.mean.df_m.sort_values(by='k', ascending=False)
# Out:
#        Enm_i Strand_i  Resid_i Atomname_i  Atomid_i Enm_j Strand_j  Resid_j  \
# PairID
# 3028    A126  STRAND1        7        O1P       126  A129  STRAND1        7
# 9671    A403  STRAND1       20        O5'       403  A419  STRAND1       20
# 2380     A89  STRAND1        5        C5'        89  A103  STRAND1        5
# 1877     A67  STRAND1        4        C5'        67   A83  STRAND1        4
# 2762    A109  STRAND1        6        C5'       109  A123  STRAND1        6
# ...      ...      ...      ...        ...       ...   ...      ...      ...
# 1823     A63  STRAND1        4          P        63   A82  STRAND1        4
# 740      A21  STRAND1        2        O2P        21   A24  STRAND1        2
# 739      A21  STRAND1        2        O2P        21   A23  STRAND1        2
# 9248    A379  STRAND1       19          P       379  A384  STRAND1       19
# 7219    A296  STRAND1       15        O1P       296  A314  STRAND1       15
#
#        Atomname_j  Atomid_j          k        b0 Category
# PairID
# 3028          C5'       129  18.155874  2.986358      pr0
# 9671          C3'       419  17.184679  3.014068      pr0
# 2380          C2'       103  16.777263  3.286221      pr0
# 1877          C2'        83  16.199168  3.306379      pr0
# 2762          C2'       123  15.813800  3.302063      pr0
# ...           ...       ...        ...       ...      ...
# 1823          C3'        82   0.000000  4.555563      pr0
# 740           C4'        24   0.000000  4.884537      pr0
# 739           C5'        23   0.000000  3.747616      pr0
# 9248          C4'       384   0.000000  3.851579      pr0
# 7219          C3'       314   0.000000  4.898795      pr0
#
# [544 rows x 13 columns]

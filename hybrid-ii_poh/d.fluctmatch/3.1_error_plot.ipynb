# %%
import sys
sys.path.append("../../smsl")

# %% [markdown]
# ### Part 1: Initialize

# %%
from smsl.fluctMatch import FmAgent

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
fm_agent = FmAgent()
fm_agent.load_TimeAgent()

# %%
for time_label, st_agent in fm_agent.t_agent.items():
    err_data = np.genfromtxt(st_agent.error_file, skip_header=2).T
    plt.plot(err_data[0], err_data[1], label=time_label)
plt.legend(bbox_to_anchor=(1.35, 1.1))
plt.xlabel('Epoch')
plt.ylabel('RMS of Fluctuation(Å)')
# Out:
# Text(0, 0.5, 'RMS of Fluctuation(Å)')

# %%
for time_label, st_agent in fm_agent.t_agent.items():
    err_data = np.genfromtxt(st_agent.error_file, skip_header=2).T
    print('Last loss of windows', time_label, ': ', err_data[1, -1])
# Out:
# Last loss of windows 0000_0500 :  0.4303
# Last loss of windows 0250_0750 :  0.3572
# Last loss of windows 0500_1000 :  0.5771
# Last loss of windows 0750_1250 :  0.4278
# Last loss of windows 1000_1500 :  0.7707
# Last loss of windows 1250_1750 :  0.64
# Last loss of windows 1500_2000 :  0.4246
# Last loss of windows 1750_2250 :  0.4605
# Last loss of windows 2000_2500 :  0.4446
# Last loss of windows 2250_2750 :  0.2891
# Last loss of windows 2500_3000 :  0.2269
# Last loss of windows 2750_3250 :  0.3614
# Last loss of windows 3000_3500 :  0.4485
# Last loss of windows 3250_3750 :  0.1596
# Last loss of windows 3500_4000 :  0.1558
# Last loss of windows 3750_4250 :  0.1526
# Last loss of windows 4000_4500 :  0.1457
# Last loss of windows 4250_4750 :  0.1399
# Last loss of windows 4500_5000 :  0.5125

# %% [markdown]
# ### Catch Outlier Windows

# %%
for time_label, st_agent in fm_agent.t_agent.items():
    err_data = np.genfromtxt(st_agent.error_file, skip_header=2).T
    if err_data[1].max() > err_data[1][1]:
        plt.plot(err_data[0], err_data[1], label=time_label)
plt.legend()
plt.show()

# %%
import sys
sys.path.append("../../smsl")

# %%
from smsl.graphBigtraj import BigTrajGraphAgent
from smsl.graph import PR1

import warnings; warnings.filterwarnings("ignore")
import numpy as np

# %%
## 見論文表B.7
n_mode=90         ## $\alpha_c$
vlv_threshold=0.2 ## $\nu_{\text{c}}$
pe_threshold=0.5  ## $\kappa_{\text{c}}$

# %%
b_agent = BigTrajGraphAgent(PR1)
# Out:
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/0000_0500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/0250_0750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/0500_1000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/0750_1250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/1000_1500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/1250_1750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/1500_2000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/1750_2250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/2000_2500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/2250_2750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/2500_3000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/2750_3250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/3000_3500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/3250_3750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/3500_4000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/3750_4250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/4000_4500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/4250_4750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/4500_5000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/pairtypes_k_b0_cutoff_5.00.csv

# %%
b_agent.spectral_decomposition()
b_agent.set_mean_r_alpha_array()
b_agent.t_agent.mean.GetEigenvectorEigenvectorT()
# Out:
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.

# %%
## 論文 圖5.25(B)
b_agent.plot_prominent_modes_and_identify_atom_with_interactive(strandid=None)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=239, min=1), Output()), _dom_classes=('w…

# %%
b_agent.plot_prominent_modes_and_get_identify_pair_with_interactive(\
        strandid=None, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, filter=True)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=239, min=1), Output()), _dom_classes=('w…

# %%
b_agent.t_agent.mean.get_modes_info(strandid=None, n_mode=n_mode, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, is_return=False)
# Out:
# 100%|██████████| 90/90 [00:00<00:00, 138.55it/s]

# %%
## 論文 圖5.25(C)
b_agent.t_agent.mean.display_df_info_by_resid(save=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#     </tr>
#     <tr>
#       <th>Residue Pair</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A1G2</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{66}$=7.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{66}$:<br>O3'C4'(A1G2)<br>C4'O1P(G2G3)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{67}$=7.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{67}$:<br>C4'O5'(A1G2)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G2G3</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{5}$=50.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{5}$:<br>C2'P(G2G3)<br>C2'O5'(G2G3)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{8}$=48.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{8}$:<br>C3'O2P(G2G3)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{34}$=18.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{34}$:<br>O3'C5'(G2G3)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{83}$=5.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{83}$:<br>C3'O1P(G2G3)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G3G4</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{41}$=16.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{41}$:<br>O3'C5'(G3G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{45}$=14.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{45}$:<br>C4'O5'(G3G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{46}$=13.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{46}$:<br>C2'O1P(G3G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{55}$=10.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{55}$:<br>O4'O2P(G3G4)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G4T5</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{21}$=25.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{21}$:<br>C3'O2P(G4T5)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{30}$=19.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{30}$:<br>C2'O1P(G4T5)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T5T6</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{1}$=52.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{1}$:<br>C3'O2P(T5T6)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{27}$=20.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{27}$:<br>O3'C5'(T5T6)<br>C2'C5'(T5T6)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{49}$=12.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{49}$:<br>C2'O1P(T5T6)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T6A7</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{28}$=20.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{28}$:<br>O3'C5'(T6A7)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{86}$=4.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{86}$:<br>C4'O5'(T6A7)<br>C4'O2P(T6A7)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A7G8</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{15}$=38.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{15}$:<br>C3'O1P(A7G8)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{37}$=17.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{37}$:<br>C4'C5'(A7G8)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{85}$=4.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{85}$:<br>C1'O2P(A7G8)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G8G9</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{7}$=49.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{7}$:<br>C3'O2P(G8G9)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{12}$=45.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{12}$:<br>C2'P(G8G9)<br>C2'O1P(G8G9)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{23}$=22.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{23}$:<br>O3'C5'(G8G9)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G9G10</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{2}$=51.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{2}$:<br>C3'O2P(G9G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{22}$=22.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{22}$:<br>C2'P(G9G10)<br>C2'O1P(G9G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{56}$=10.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{56}$:<br>O3'C5'(G9G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{57}$=10.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{57}$:<br>C4'O5'(G9G10)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G10T11</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{9}$=47.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{9}$:<br>C3'O2P(G10T11)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{52}$=12.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{52}$:<br>C2'P(G10T11)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{76}$=5.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{76}$:<br>C4'O5'(G10T11)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T11T12</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{26}$=21.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{26}$:<br>C3'O2P(T11T12)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{61}$=7.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{61}$:<br>C5'O5'(T11T12)<br>C3'O5'(T11T12)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{84}$=4.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{84}$:<br>C4'O1P(T11T12)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T12A13</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{3}$=51.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{3}$:<br>C3'O2P(T12A13)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{16}$=37.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{16}$:<br>C2'O5'(T12A13)<br>C2'P(T12A13)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{24}$=21.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{24}$:<br>O3'C5'(T12A13)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A13G14</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{13}$=42.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{13}$:<br>C3'O1P(A13G14)<br>C3'O2P(A13G14)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{40}$=16.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{40}$:<br>C2'O1P(A13G14)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{48}$=12.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{48}$:<br>C2'P(A13G14)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{51}$=12.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{51}$:<br>O3'C5'(A13G14)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{69}$=7.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{69}$:<br>C4'O5'(A13G14)</td>
#     </tr>
#     <tr>
#       <th>G14G15</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{4}$=50.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{4}$:<br>C2'P(G14G15)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{11}$=46.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{11}$:<br>C3'O2P(G14G15)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{25}$=21.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{25}$:<br>O3'C5'(G14G15)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G15G16</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{20}$=27.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{20}$:<br>O3'C5'(G15G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{31}$=19.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{31}$:<br>C4'O2P(G15G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{36}$=17.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{36}$:<br>C2'O1P(G15G16)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G16T17</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{18}$=29.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{18}$:<br>C3'O1P(G16T17)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T17T18</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{59}$=9.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{59}$:<br>O4'P(T17T18)<br>O4'O1P(T17T18)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{65}$=7.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{65}$:<br>C4'O1P(T17T18)<br>C4'O5'(T17T18)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{68}$=7.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{68}$:<br>O3'C4'(T17T18)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{82}$=5.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{82}$:<br>C3'O5'(T17T18)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T18A19</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{17}$=32.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{17}$:<br>C3'O2P(T18A19)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{32}$=18.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{32}$:<br>C2'O5'(T18A19)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{72}$=6.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{72}$:<br>O4'O1P(T18A19)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A19G20</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{14}$=39.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{14}$:<br>C3'
# Write /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/hybrid-ii_poh_PR1.csv

# %%
b_agent.t_agent.mean.df_m.sort_values(by='k', ascending=False)
# Out:
#        Enm_i Strand_i  Resid_i Atomname_i  Atomid_i Enm_j Strand_j  Resid_j  \
# PairID
# 4768    A187  STRAND1        9        C3'       187  A192  STRAND1       10
# 4371    A165  STRAND1        8        C3'       165  A170  STRAND1        9
# 3000    A102  STRAND1        5        C3'       102  A107  STRAND1        6
# 5335    A209  STRAND1       10        C3'       209  A214  STRAND1       11
# 6126    A249  STRAND1       12        C3'       249  A254  STRAND1       13
# ...      ...      ...      ...        ...       ...   ...      ...      ...
# 7812    A321  STRAND1       16        C5'       321  A363  STRAND1       18
# 5355    A210  STRAND1       10        C2'       210  A219  STRAND1       11
# 7809    A321  STRAND1       16        C5'       321  A360  STRAND1       18
# 7808    A321  STRAND1       16        C5'       321  A359  STRAND1       18
# 3584    A129  STRAND1        7        C5'       129  A150  STRAND1        8
#
#        Atomname_j  Atomid_j          k        b0 Category
# PairID
# 4768          O2P       192  24.918242  2.920742      pr1
# 4371          O2P       170  24.132205  2.937179      pr1
# 3000          O2P       107  23.400605  2.963963      pr1
# 5335          O2P       214  22.924879  2.927479      pr1
# 6126          O2P       254  22.539837  2.958626      pr1
# ...           ...       ...        ...       ...      ...
# 7812          C5'       363   0.000000  5.343437      pr1
# 5355          C1'       219   0.000000  5.488774      pr1
# 7809          O1P       360   0.000000  6.614474      pr1
# 7808            P       359   0.000000  5.862716      pr1
# 3584          C5'       150   0.000000  4.543289      pr1
#
# [1101 rows x 13 columns]

# %%
import sys
sys.path.append("../../smsl")

# %%
from smsl.graphBigtraj import BigTrajGraphAgent
from smsl.graph import PR0

import warnings; warnings.filterwarnings("ignore")
import numpy as np

# %%
## 見論文表B.7
n_mode=90         ## $\alpha_c$
vlv_threshold=0.2 ## $\nu_{\text{c}}$
pe_threshold=0.5  ## $\kappa_{\text{c}}$

# %%
b_agent = BigTrajGraphAgent(PR0)
# Out:
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/0000_0500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/0250_0750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/0500_1000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/0750_1250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/1000_1500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/1250_1750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/1500_2000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/1750_2250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/2000_2500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/2250_2750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/2500_3000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/2750_3250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/3000_3500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/3250_3750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/3500_4000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/3750_4250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/4000_4500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/4250_4750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/4500_5000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/pairtypes_k_b0_cutoff_5.00.csv

# %%
b_agent.spectral_decomposition()
b_agent.set_mean_r_alpha_array()
b_agent.t_agent.mean.GetEigenvectorEigenvectorT()
# Out:
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.

# %%
## 論文 圖5.24(B)
b_agent.plot_prominent_modes_and_identify_atom_with_interactive(strandid=None)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=239, min=1), Output()), _dom_classes=('w…

# %%
b_agent.plot_prominent_modes_and_get_identify_pair_with_interactive(\
        strandid=None, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, filter=True)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=239, min=1), Output()), _dom_classes=('w…

# %%
b_agent.t_agent.mean.get_modes_info(strandid=None, n_mode=n_mode, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, is_return=False)
# Out:
# 100%|██████████| 90/90 [00:00<00:00, 137.96it/s]

# %%
## 論文 圖5.24(C)
b_agent.t_agent.mean.display_df_info_by_resid(save=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#     </tr>
#     <tr>
#       <th>Residue Pair</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A1</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{40}$=21.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{40}$:<br>C5'C2'(A1A1)<br>C5'C1'(A1A1)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{69}$=11.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{69}$:<br>O5'C3'(A1A1)<br>O4'O3'(A1A1)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{86}$=8.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{86}$:<br>O4'O3'(A1A1)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G2</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{39}$=21.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{39}$:<br>C1'O3'(G2G2)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{60}$=13.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{60}$:<br>C5'C2'(G2G2)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G3</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{15}$=36.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{15}$:<br>O1PC5'(G3G3)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{25}$=30.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{25}$:<br>O5'C3'(G3G3)<br>O5'O4'(G3G3)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G4</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{8}$=38.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{8}$:<br>C5'C2'(G4G4)<br>O1PC5'(G4G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{26}$=30.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{26}$:<br>O5'O4'(G4G4)<br>O4'O3'(G4G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{53}$=17.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{53}$:<br>C1'O3'(G4G4)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T5</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{1}$=53.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{1}$:<br>C5'C2'(T5T5)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{20}$=34.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{20}$:<br>O4'O3'(T5T5)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{52}$=18.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{52}$:<br>O5'O4'(T5T5)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T6</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{9}$=38.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{9}$:<br>O5'C3'(T6T6)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{24}$=31.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{24}$:<br>O1PC5'(T6T6)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{62}$=13.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{62}$:<br>O4'O3'(T6T6)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A7</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{17}$=34.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{17}$:<br>O5'C3'(A7A7)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{35}$=25.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{35}$:<br>O1PC5'(A7A7)<br>C5'C2'(A7A7)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{51}$=18.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{51}$:<br>C1'O3'(A7A7)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{70}$=11.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{70}$:<br>O1PC4'(A7A7)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G8</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{10}$=37.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{10}$:<br>C1'O3'(G8G8)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{45}$=19.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{45}$:<br>O5'O4'(G8G8)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{77}$=10.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{77}$:<br>O2PC3'(G8G8)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G9</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{43}$=20.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{43}$:<br>O5'C3'(G9G9)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G10</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{22}$=32.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{22}$:<br>O5'O4'(G10G10)<br>O5'O3'(G10G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{30}$=28.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{30}$:<br>O1PC5'(G10G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{59}$=14.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{59}$:<br>O1PC4'(G10G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{74}$=10.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{74}$:<br>C1'O3'(G10G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{90}$=7.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{90}$:<br>O5'C3'(G10G10)</td>
#     </tr>
#     <tr>
#       <th>T11</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{4}$=45.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{4}$:<br>C5'C2'(T11T11)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{27}$=30.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{27}$:<br>O4'O3'(T11T11)<br>C1'O3'(T11T11)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{48}$=18.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{48}$:<br>O5'O4'(T11T11)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T12</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{7}$=39.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{7}$:<br>C5'C2'(T12T12)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{18}$=34.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{18}$:<br>O5'C3'(T12T12)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{33}$=26.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{33}$:<br>C1'O3'(T12T12)<br>O4'O3'(T12T12)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A13</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{3}$=47.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{3}$:<br>O1PC5'(A13A13)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{12}$=37.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{12}$:<br>O5'O4'(A13A13)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{41}$=21.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{41}$:<br>C1'O3'(A13A13)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G14</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{5}$=44.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{5}$:<br>C5'C2'(G14G14)<br>O1PC5'(G14G14)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{23}$=32.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{23}$:<br>O4'O3'(G14G14)<br>O5'O4'(G14G14)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{37}$=22.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{37}$:<br>C1'O3'(G14G14)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G15</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{11}$=37.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{11}$:<br>O1PC5'(G15G15)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{16}$=35.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{16}$:<br>O5'C3'(G15G15)<br>O5'O4'(G15G15)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G16</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{28}$=29.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{28}$:<br>C5'C2'(G16G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{34}$=26.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{34}$:<br>O5'O4'(G16G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{49}$=18.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{49}$:<br>C1'O3'(G16G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{61}$=13.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{61}$:<br>O1PC4'(G16G16)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T17</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{13}$=36.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{13}$:<br>C5'C2'(T17T17)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{36}$=23.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{36}$:<br>O4'O3'(T17T17)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{44}$=20.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{44}$:<br>O5'C3'(T17T17)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T18</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{6}$=42.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{6}$:<br>C5'C2'(T18T18)<br>O1PC5'(T18T18)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{31}$=28.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{31}$:<br>O5'C3'(T18T18)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{56}$=15.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{56}$:<br>O4'O3'(T18T18)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A19</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{29}$=29.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{29}$:<br>O5'C3'(A19A19)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{32}$=27.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{32}$:<br>C1'O3'(A19A19)<br>C5'C2'(A19A19)</td>
#       <td>$\rm{\lambda}^{\rm{
# Write /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_poh/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/hybrid-ii_poh_PR0.csv

# %%
b_agent.t_agent.mean.df_m.sort_values(by='k', ascending=False)
# Out:
#        Enm_i Strand_i  Resid_i Atomname_i  Atomid_i Enm_j Strand_j  Resid_j  \
# PairID
# 9475    A404  STRAND1       20        C5'       404  A420  STRAND1       20
# 6175    A253  STRAND1       13        O1P       253  A256  STRAND1       13
# 2786     A89  STRAND1        5        C5'        89  A103  STRAND1        5
# 7168    A296  STRAND1       15        O1P       296  A299  STRAND1       15
# 1686     A42  STRAND1        3        O1P        42   A45  STRAND1        3
# ...      ...      ...      ...        ...       ...   ...      ...      ...
# 3991    A146  STRAND1        8          P       146  A165  STRAND1        8
# 3996    A147  STRAND1        8        O1P       147  A150  STRAND1        8
# 4013    A149  STRAND1        8        O5'       149  A165  STRAND1        8
# 4014    A149  STRAND1        8        O5'       149  A166  STRAND1        8
# 10763   A451  STRAND1       22        C1'       451  A465  STRAND1       22
#
#        Atomname_j  Atomid_j          k        b0 Category
# PairID
# 9475          C2'       420  20.175726  3.126411      pr0
# 6175          C5'       256  18.873284  2.976268      pr0
# 2786          C2'       103  18.507379  3.269189      pr0
# 7168          C5'       299  18.160984  2.977063      pr0
# 1686          C5'        45  18.086332  2.974500      pr0
# ...           ...       ...        ...       ...      ...
# 3991          C3'       165   0.000000  5.134605      pr0
# 3996          C5'       150   0.000000  3.737642      pr0
# 4013          C3'       165   0.000000  3.743858      pr0
# 4014          C2'       166   0.000000  4.367474      pr0
# 10763         O3'       465   0.000000  2.983095      pr0
#
# [526 rows x 13 columns]

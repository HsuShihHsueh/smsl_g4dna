# %%
import sys
sys.path.append("../../smsl")

# %%
from smsl.graphBigtraj import BigTrajGraphAgent
from smsl.graph import PR0

import warnings; warnings.filterwarnings("ignore")
import numpy as np

# %%
## 見論文表B.7
n_mode=90         ## $\alpha_c$
vlv_threshold=0.2 ## $\nu_{\text{c}}$
pe_threshold=0.5  ## $\kappa_{\text{c}}$

# %%
b_agent = BigTrajGraphAgent(PR0)
# Out:
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/chair/d.fluctmatch/bigtraj_fluctmatch/0000_0500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/chair/d.fluctmatch/bigtraj_fluctmatch/0250_0750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/chair/d.fluctmatch/bigtraj_fluctmatch/0500_1000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/chair/d.fluctmatch/bigtraj_fluctmatch/0750_1250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/chair/d.fluctmatch/bigtraj_fluctmatch/1000_1500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/chair/d.fluctmatch/bigtraj_fluctmatch/1250_1750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/chair/d.fluctmatch/bigtraj_fluctmatch/1500_2000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/chair/d.fluctmatch/bigtraj_fluctmatch/1750_2250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/chair/d.fluctmatch/bigtraj_fluctmatch/2000_2500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/chair/d.fluctmatch/bigtraj_fluctmatch/2250_2750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/chair/d.fluctmatch/bigtraj_fluctmatch/2500_3000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/chair/d.fluctmatch/bigtraj_fluctmatch/2750_3250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/chair/d.fluctmatch/bigtraj_fluctmatch/3000_3500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/chair/d.fluctmatch/bigtraj_fluctmatch/3250_3750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/chair/d.fluctmatch/bigtraj_fluctmatch/3500_4000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/chair/d.fluctmatch/bigtraj_fluctmatch/3750_4250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/chair/d.fluctmatch/bigtraj_fluctmatch/4000_4500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/chair/d.fluctmatch/bigtraj_fluctmatch/4250_4750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/chair/d.fluctmatch/bigtraj_fluctmatch/4500_5000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/chair/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/pairtypes_k_b0_cutoff_5.00.csv

# %%
b_agent.spectral_decomposition()
b_agent.set_mean_r_alpha_array()
b_agent.t_agent.mean.GetEigenvectorEigenvectorT()
# Out:
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.

# %%
## 論文 圖5.24(B)
b_agent.plot_prominent_modes_and_identify_atom_with_interactive(strandid=None)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=239, min=1), Output()), _dom_classes=('w…

# %%
b_agent.plot_prominent_modes_and_get_identify_pair_with_interactive(\
        strandid=None, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, filter=True)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=239, min=1), Output()), _dom_classes=('w…

# %%
b_agent.t_agent.mean.get_modes_info(strandid=None, n_mode=n_mode, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, is_return=False)
# Out:
# 100%|██████████| 90/90 [00:00<00:00, 129.38it/s]

# %%
## 論文 圖5.24(C)
b_agent.t_agent.mean.display_df_info_by_resid(save=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#     </tr>
#     <tr>
#       <th>Residue Pair</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A1</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{28}$=35.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{28}$:<br>C5'C2'(A1A1)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{52}$=21.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{52}$:<br>C1'O3'(A1A1)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{82}$=12.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_
th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{13}$=43.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{13}$:<br>O1PC5'(G15G15)<br>C5'C2'(G15G15)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{16}$=40.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{16}$:<br>O5'C3'(G15G15)<br>O5'O4'(G15G15)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{51}$=21.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{51}$:<br>O4'O3'(G15G15)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G16</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{15}$=41.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{15}$:<br>C5'C2'(G16G16)<br>O1PC5'(G16G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{29}$=35.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{29}$:<br>O5'O4'(G16G16)<br>O4'O3'(G16G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{57}$=19.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{57}$:<br>C1'O3'(G16G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{89}$=11.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{89}$:<br>O5'C1'(G16G16)</td>
#     </tr>
#     <tr>
#       <th>T17</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{11}$=44.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{11}$:<br>C5'C2'(T17T17)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{32}$=34.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{32}$:<br>O4'O3'(T17T17)<br>C1'O3'(T17T17)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{56}$=19.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{56}$:<br>O5'O4'(T17T17)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T18</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{24}$=37.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{24}$:<br>O5'C3'(T18T18)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{31}$=34.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{31}$:<br>O1PC5'(T18T18)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{60}$=18.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{60}$:<br>C1'O3'(T18T18)<br>O4'O3'(T18T18)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A19</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{2}$=55.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{2}$:<br>C5'C2'(A19A19)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{14}$=42.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{14}$:<br>O5'O4'(A19A19)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{37}$=31.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{37}$:<br>C1'O3'(A19A19)<br>O4'O3'(A19A19)</td>
#       <td></td>
#     </
# Write /home/user/workfolder/g4dna_protocol_demo/chair/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/chair_PR0.csv

# %%
b_agent.t_agent.mean.df_m.sort_values(by='k', ascending=False)
# Out:
#        Enm_i Strand_i  Resid_i Atomname_i  Atomid_i Enm_j Strand_j  Resid_j  \
# PairID
# 7610    A445  STRAND1       22        O1P       445  A448  STRAND1       22
# 4524    A236  STRAND1       12        C5'       236  A250  STRAND1       12
# 3831    A191  STRAND1       10        O1P       191  A194  STRAND1       10
# 4280    A216  STRAND1       11        C5'       216  A230  STRAND1       11
# 4785    A253  STRAND1       13        O1P       253  A256  STRAND1       13
# ...      ...      ...      ...        ...       ...   ...      ...      ...
# 6287    A341  STRAND1       17        O2P       341  A345  STRAND1       17
# 6286    A341  STRAND1       17        O2P       341  A344  STRAND1       17
# 4240    A212  STRAND1       11          P       212  A229  STRAND1       11
# 6282    A340  STRAND1       17        O1P       340  A356  STRAND1       17
# 4484    A232  STRAND1       12          P       232  A239  STRAND1       12
#
#        Atomname_j  Atomid_j          k        b0 Category
# PairID
# 7610          C5'       448  20.230484  2.952347      pr0
# 4524          C2'       250  19.912068  3.261168      pr0
# 3831          C5'       194  19.491258  2.951863      pr0
# 4280          C2'       230  18.890226  3.266189      pr0
# 4785          C5'       256  18.344537  2.984737      pr0
# ...           ...       ...        ...       ...      ...
# 6287          O4'       345   0.000000  5.324458      pr0
# 6286          C4'       344   0.000000  4.738705      pr0
# 4240          C3'       229   0.000000  4.589695      pr0
# 6282          C3'       356   0.000000  5.215000      pr0
# 4484          C1'       239   0.000000  4.991347      pr0
#
# [490 rows x 13 columns]

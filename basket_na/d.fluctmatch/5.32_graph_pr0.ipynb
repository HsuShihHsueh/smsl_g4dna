# %%
import sys
sys.path.append("../../smsl")

# %%
from smsl.graphBigtraj import BigTrajGraphAgent
from smsl.graph import PR0

import warnings; warnings.filterwarnings("ignore")
import numpy as np

# %%
## 見論文表B.7
n_mode=90         ## $\alpha_c$
vlv_threshold=0.2 ## $\nu_{\text{c}}$
pe_threshold=0.5  ## $\kappa_{\text{c}}$

# %%
b_agent = BigTrajGraphAgent(PR0)
# Out:
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket_na/d.fluctmatch/bigtraj_fluctmatch/0000_0500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket_na/d.fluctmatch/bigtraj_fluctmatch/0250_0750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket_na/d.fluctmatch/bigtraj_fluctmatch/0500_1000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket_na/d.fluctmatch/bigtraj_fluctmatch/0750_1250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket_na/d.fluctmatch/bigtraj_fluctmatch/1000_1500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket_na/d.fluctmatch/bigtraj_fluctmatch/1250_1750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket_na/d.fluctmatch/bigtraj_fluctmatch/1500_2000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket_na/d.fluctmatch/bigtraj_fluctmatch/1750_2250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket_na/d.fluctmatch/bigtraj_fluctmatch/2000_2500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket_na/d.fluctmatch/bigtraj_fluctmatch/2250_2750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket_na/d.fluctmatch/bigtraj_fluctmatch/2500_3000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket_na/d.fluctmatch/bigtraj_fluctmatch/2750_3250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket_na/d.fluctmatch/bigtraj_fluctmatch/3000_3500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket_na/d.fluctmatch/bigtraj_fluctmatch/3250_3750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket_na/d.fluctmatch/bigtraj_fluctmatch/3500_4000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket_na/d.fluctmatch/bigtraj_fluctmatch/3750_4250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket_na/d.fluctmatch/bigtraj_fluctmatch/4000_4500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket_na/d.fluctmatch/bigtraj_fluctmatch/4250_4750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket_na/d.fluctmatch/bigtraj_fluctmatch/4500_5000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket_na/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/pairtypes_k_b0_cutoff_5.00.csv

# %%
b_agent.spectral_decomposition()
b_agent.set_mean_r_alpha_array()
b_agent.t_agent.mean.GetEigenvectorEigenvectorT()
# Out:
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.

# %%
## 論文 圖5.24(B)
b_agent.plot_prominent_modes_and_identify_atom_with_interactive(strandid=None)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=239, min=1), Output()), _dom_classes=('w…

# %%
b_agent.plot_prominent_modes_and_get_identify_pair_with_interactive(\
        strandid=None, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, filter=True)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=239, min=1), Output()), _dom_classes=('w…

# %%
b_agent.t_agent.mean.get_modes_info(strandid=None, n_mode=n_mode, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, is_return=False)
# Out:
# 100%|██████████| 90/90 [00:00<00:00, 138.05it/s]

# %%
## 論文 圖5.24(C)
b_agent.t_agent.mean.display_df_info_by_resid(save=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#     </tr>
#     <tr>
#       <th>Residue Pair</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A1</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{2}$=55.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{2}$:<br>C5'C2'(A1A1)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{15}$=34.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{15}$:<br>O4'O3'(A1A1)<br>C1'O3'(A1A1)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{25}$=27.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{25}$:<br>O5'C3'(A1A1)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G2</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{6}$=43.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{6}$:<br>O1PC5'(G2G2)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{19}$=31.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{19}$:<br>O5'O4'(G2G2)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{53}$=15.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{53}$:<br>C1'O3'(G2G2)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G3</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{34}$=23.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{34}$:<br>C5'O3'(G3G3)<br>O1PC5'(G3G3)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{44}$=17.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{44}$:<br>O5'O4'(G3G3)<br>O5'C3'(G3G3)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{78}$=9.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{78}$:<br>O4'O3'(G3G3)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G4</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{29}$=25.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{29}$:<br>O1PC5'(G4G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{40}$=19.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{40}$:<br>O5'O4'(G4G4)<br>O4'O3'(G4G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{48}$=16.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{48}$:<br>PC4'(G4G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{83}$=8.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{83}$:<br>C1'O3'(G4G4)</td>
#     </tr>
#     <tr>
#       <th>T5</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{24}$=27.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{24}$:<br>C5'C2'(T5T5)<br>C5'C1'(T5T5)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{31}$=23.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{31}$:<br>O4'O3'(T5T5)<br>O5'O4'(T5T5)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{45}$=17.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{45}$:<br>O5'C3'(T5T5)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T6</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{18}$=31.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{18}$:<br>O5'C3'(T6T6)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{28}$=25.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{28}$:<br>O1PC5'(T6T6)<br>C5'C2'(T6T6)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{55}$=14.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{55}$:<br>O4'O3'(T6T6)<br>O2PO4'(T6T6)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{82}$=8.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{82}$:<br>C1'O3'(T6T6)</td>
#     </tr>
#     <tr>
#       <th>A7</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{22}$=30.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{22}$:<br>O5'C3'(A7A7)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{66}$=12.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{66}$:<br>C1'O3'(A7A7)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{76}$=9.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{76}$:<br>C5'C2'(A7A7)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{79}$=9.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{79}$:<br>O2PO4'(A7A7)</td>
#     </tr>
#     <tr>
#       <th>G8</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{62}$=13.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{62}$:<br>C1'O3'(G8G8)<br>O4'O3'(G8G8)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{67}$=11.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{67}$:<br>O5'O4'(G8G8)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G9</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{10}$=37.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{10}$:<br>O1PC5'(G9G9)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{14}$=34.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{14}$:<br>O5'C3'(G9G9)<br>O5'O4'(G9G9)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{89}$=7.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{89}$:<br>O1PC4'(G9G9)<br>C5'C1'(G9G9)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G10</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{38}$=20.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{38}$:<br>O4'O3'(G10G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{42}$=18.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{42}$:<br>C5'C1'(G10G10)<br>C5'C2'(G10G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{86}$=7.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{86}$:<br>C1'O3'(G10G10)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T11</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{21}$=30.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{21}$:<br>C5'C2'(T11T11)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{30}$=24.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{30}$:<br>O4'O3'(T11T11)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{43}$=17.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{43}$:<br>O5'C3'(T11T11)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T12</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{12}$=35.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{12}$:<br>O1PC5'(T12T12)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{26}$=25.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{26}$:<br>O5'O4'(T12T12)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{68}$=11.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{68}$:<br>PC3'(T12T12)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A13</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{41}$=19.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{41}$:<br>C5'C2'(A13A13)<br>O1PC5'(A13A13)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{50}$=16.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{50}$:<br>O5'O4'(A13A13)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{61}$=13.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{61}$:<br>C1'O3'(A13A13)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G14</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{13}$=34.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{13}$:<br>O1PC5'(G14G14)<br>C5'C2'(G14G14)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{17}$=31.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{17}$:<br>O5'O4'(G14G14)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{52}$=15.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{52}$:<br>PC3'(G14G14)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{54}$=15.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{54}$:<br>C1'O3'(G14G14)</td>
#     </tr>
#     <tr>
#       <th>G15</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{35}$=22.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{35}$:<br>C1'O3'(G15G15)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{80}$=8.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{80}$:<br>C5'C2'(G15G15)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{90}$=7.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{90}$:<br>O5'C3'(G15G15)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G16</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{7}$=40.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{7}$:<br>O1PC5'(G16G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{9}$=38.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{9}$:<br>O5'C3'(G16G16)<br>O5'O4'(G16G16)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T17</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{1}$=58.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{1}$:<br>C5'C2'(T17T17)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{20}$=30.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{20}$:<br>O4'O3'(T17T17)<br>O5'O4'(T17T17)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{37}$=21.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{37}$:<br>O5'C3'(T17T17)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{71}$=10.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{71}$:<br>O2PC4'(T17T17)</td>
#     </tr>
#     <tr>
#       <th>T18</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{3}$=54.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{3}$:<br>C5'C2'(T18T18)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{16}$=32.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{16}$:<br>O5'C3'(T18T18)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{23}$=28.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{23}$:<br>C1'O3'(T18T18)<br>O4'O3'(T18T18)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{85}$=7.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{85}$:<br>O2PC4'(T18T18)</td>
#     </tr>
#     <tr>
#       <th>A19</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{5}$=48.0, ${\{\rm{a}_i\rm{a}_j\}}^
# Write /home/user/workfolder/g4dna_protocol_demo/basket_na/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/basket_PR0.csv

# %%
b_agent.t_agent.mean.df_m.sort_values(by='k', ascending=False)
# Out:
#        Enm_i Strand_i  Resid_i Atomname_i  Atomid_i Enm_j Strand_j  Resid_j  \
# PairID
# 49        A2  STRAND1        1        C5'         2   A17  STRAND1        1
# 7931    A343  STRAND1       17        C5'       343  A357  STRAND1       17
# 7475    A318  STRAND1       16        O1P       318  A321  STRAND1       16
# 8158    A363  STRAND1       18        C5'       363  A377  STRAND1       18
# 9001    A423  STRAND1       21        O1P       423  A426  STRAND1       21
# ...      ...      ...      ...        ...       ...   ...      ...      ...
# 8119    A359  STRAND1       18          P       359  A366  STRAND1       18
# 1901     A66  STRAND1        4        O5'        66   A82  STRAND1        4
# 8117    A359  STRAND1       18          P       359  A364  STRAND1       18
# 5262    A212  STRAND1       11          P       212  A217  STRAND1       11
# 6012    A253  STRAND1       13        O1P       253  A271  STRAND1       13
#
#        Atomname_j  Atomid_j          k        b0 Category
# PairID
# 49            C2'        17  22.838553  3.281658      pr0
# 7931          C2'       357  21.335500  3.264389      pr0
# 7475          C5'       321  20.064916  2.968226      pr0
# 8158          C2'       377  19.304737  3.261574      pr0
# 9001          C5'       426  18.132579  2.972805      pr0
# ...           ...       ...        ...       ...      ...
# 8119          C1'       366   0.000000  5.030932      pr0
# 1901          C3'        82   0.000000  3.451247      pr0
# 8117          C4'       364   0.000000  3.953242      pr0
# 5262          C4'       217   0.000000  3.964426      pr0
# 6012          C2'       271   0.000000  5.737963      pr0
#
# [529 rows x 13 columns]

# %%
import sys
sys.path.append("../../smsl")

# %%
from smsl.graphBigtraj import BigTrajGraphAgent
from smsl.graph import PR1

import warnings; warnings.filterwarnings("ignore")
import numpy as np

# %%
## 見論文表B.7
n_mode=90         ## $\alpha_c$
vlv_threshold=0.2 ## $\nu_{\text{c}}$
pe_threshold=0.5  ## $\kappa_{\text{c}}$

# %%
b_agent = BigTrajGraphAgent(PR1)
# Out:
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/0000_0500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/0250_0750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/0500_1000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/0750_1250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/1000_1500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/1250_1750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/1500_2000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/1750_2250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/2000_2500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/2250_2750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/2500_3000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/2750_3250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/3000_3500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/3250_3750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/3500_4000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/3750_4250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/4000_4500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/4250_4750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/4500_5000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/pairtypes_k_b0_cutoff_5.00.csv

# %%
b_agent.spectral_decomposition()
b_agent.set_mean_r_alpha_array()
b_agent.t_agent.mean.GetEigenvectorEigenvectorT()
# Out:
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.

# %%
## 論文 圖5.25(B)
b_agent.plot_prominent_modes_and_identify_atom_with_interactive(strandid=None)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=239, min=1), Output()), _dom_classes=('w…

# %%
b_agent.plot_prominent_modes_and_get_identify_pair_with_interactive(\
        strandid=None, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, filter=True)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=239, min=1), Output()), _dom_classes=('w…

# %%
b_agent.t_agent.mean.get_modes_info(strandid=None, n_mode=n_mode, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, is_return=False)
# Out:
# 100%|██████████| 90/90 [00:00<00:00, 141.67it/s]

# %%
## 論文 圖5.25(C)
b_agent.t_agent.mean.display_df_info_by_resid(save=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#     </tr>
#     <tr>
#       <th>Residue Pair</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A1G2</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{6}$=50.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{6}$:<br>C3'O2P(A1G2)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{21}$=36.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{21}$:<br>C2'O1P(A1G2)<br>C2'P(A1G2)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G2G3</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{12}$=46.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{12}$:<br>C3'O2P(G2G3)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{28}$=26.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{28}$:<br>C2'P(G2G3)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G3G4</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{2}$=54.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{2}$:<br>C4'P(G3G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{20}$=36.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{20}$:<br>C3'O2P(G3G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{37}$=19.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{37}$:<br>O3'C5'(G3G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{47}$=14.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{47}$:<br>C2'O4'(G3G4)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G4T5</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{7}$=49.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{7}$:<br>C3'O2P(G4T5)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{22}$=34.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{22}$:<br>O3'C5'(G4T5)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T5T6</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{16}$=43.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{16}$:<br>C3'O1P(T5T6)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{26}$=29.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{26}$:<br>C4'P(T5T6)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{43}$=15.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{43}$:<br>O3'C5'(T5T6)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{57}$=11.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{57}$:<br>C3'O5'(T5T6)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{78}$=7.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{78}$:<br>C2'O5'(T5T6)</td>
#     </tr>
#     <tr>
#       <th>T6A7</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{25}$=30.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{25}$:<br>C3'O1P(T6A7)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{30}$=23.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{30}$:<br>O3'C5'(T6A7)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{40}$=17.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{40}$:<br>C4'O2P(T6A7)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A7G8</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{34}$=20.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{34}$:<br>C3'O1P(A7G8)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{64}$=9.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{64}$:<br>O3'C5'(A7G8)<br>C4'C5'(A7G8)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{70}$=8.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{70}$:<br>C1'O5'(A7G8)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{72}$=8.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{72}$:<br>O3'C4'(A7G8)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{85}$=5.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{85}$:<br>C4'C5'(A7G8)</td>
#     </tr>
#     <tr>
#       <th>G8G9</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{4}$=53.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{4}$:<br>C3'O2P(G8G9)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{27}$=28.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{27}$:<br>C2'P(G8G9)<br>C2'O5'(G8G9)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{53}$=12.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{53}$:<br>O3'C5'(G8G9)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G9G10</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{62}$=9.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{62}$:<br>O4'O2P(G9G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{84}$=6.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{84}$:<br>O3'C5'(G9G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{88}$=5.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{88}$:<br>C1'P(G9G10)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G10T11</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{24}$=31.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{24}$:<br>C3'O2P(G10T11)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{75}$=7.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{75}$:<br>C4'O1P(G10T11)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T11T12</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{10}$=46.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{10}$:<br>C3'O2P(T11T12)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{23}$=33.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{23}$:<br>C2'O1P(T11T12)<br>C2'P(T11T12)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T12A13</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{11}$=46.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{11}$:<br>C3'O2P(T12A13)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{31}$=22.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{31}$:<br>C2'P(T12A13)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{42}$=15.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{42}$:<br>C4'O5'(T12A13)<br>O3'C4'(T11T12)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{71}$=8.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{71}$:<br>O3'C4'(T12A13)<br>O3'C5'(T12A13)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A13G14</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{81}$=6.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{81}$:<br>O4'O2P(A13G14)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G14G15</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{9}$=47.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{9}$:<br>C2'P(G14G15)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{15}$=43.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{15}$:<br>C3'O2P(G14G15)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{29}$=25.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{29}$:<br>O3'C5'(G14G15)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{45}$=14.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{45}$:<br>C4'O5'(G14G15)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G15G16</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{8}$=48.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{8}$:<br>C3'O2P(G15G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{14}$=43.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{14}$:<br>C2'P(G15G16)<br>C2'O5'(G15G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{36}$=19.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{36}$:<br>O3'C5'(G15G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{77}$=7.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{77}$:<br>C4'O1P(G15G16)<br>O3'C4'(G14G15)<br>C1'C4'(G14G15)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G16T17</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{1}$=60.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{1}$:<br>C3'O2P(G16T17)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{82}$=6.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{82}$:<br>C2'P(G16T17)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T17T18</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{19}$=37.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{19}$:<br>C3'O2P(T17T18)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{69}$=8.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{69}$:<br>C4'O1P(T17T18)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T18A19</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{5}$=52.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{5}$:<br>C3'O2P(T18A19)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{17}$=40.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{17}$:<br>C2'P(T18A19)<br>C2'O5'(T18A19)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{32}$=22.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{32}$:<br>O3'C5'(T18A19)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A19G20</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{13}$=44.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{13}$:<br>C3'O1P(A19G20)<br>C3'O2P(A19G20)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{49}$=13.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{49}$:<br>O3'C5'(A19G20)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{58}$=11.0, ${\{\rm{a}_i\rm{a}_j\}}^
# Write /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/basket_PR1.csv

# %%
b_agent.t_agent.mean.df_m.sort_values(by='k', ascending=False)
# Out:
#        Enm_i Strand_i  Resid_i Atomname_i  Atomid_i Enm_j Strand_j  Resid_j  \
# PairID
# 6564    A336  STRAND1       16        C3'       336  A341  STRAND1       17
# 3476    A165  STRAND1        8        C3'       165  A170  STRAND1        9
# 7655    A419  STRAND1       20        C3'       419  A424  STRAND1       21
# 7126    A376  STRAND1       18        C3'       376  A381  STRAND1       19
# 1991     A82  STRAND1        4        C3'        82   A87  STRAND1        5
# ...      ...      ...      ...        ...       ...   ...      ...      ...
# 4363    A219  STRAND1       11        C1'       219  A235  STRAND1       12
# 4348    A218  STRAND1       11        O4'       218  A238  STRAND1       12
# 4330    A217  STRAND1       11        C4'       217  A234  STRAND1       12
# 4328    A217  STRAND1       11        C4'       217  A232  STRAND1       12
# 7997    A443  STRAND1       21        O3'       443  A464  STRAND1       22
#
#        Atomname_j  Atomid_j          k        b0 Category
# PairID
# 6564          O2P       341  28.053795  2.928726      pr1
# 3476          O2P       170  25.374842  2.924847      pr1
# 7655          O2P       424  24.492826  2.934079      pr1
# 7126          O2P       381  23.324595  2.951737      pr1
# 1991          O2P        87  22.953889  2.982611      pr1
# ...           ...       ...        ...       ...      ...
# 4363          O5'       235   0.000000  3.980437      pr1
# 4348          O4'       238   0.000000  5.342863      pr1
# 4330          O2P       234   0.000000  4.393795      pr1
# 4328            P       232   0.000000  3.958411      pr1
# 7997          C2'       464   0.000000  5.815547      pr1
#
# [924 rows x 13 columns]

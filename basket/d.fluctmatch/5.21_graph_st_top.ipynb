# %%
import sys
sys.path.append("../../smsl")

# %%
from smsl.graphBigtraj import BigTrajGraphAgent
from smsl.graph import ST_TOP

import warnings; warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd

# %%
## 見論文表B.7
n_mode=30         ## $\alpha_c$
vlv_threshold=0.1 ## $\nu_{\text{c}}$
pe_threshold=0.6  ## $\kappa_{\text{c}}$

# %%
b_agent = BigTrajGraphAgent(ST_TOP)
# Out:
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/0000_0500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/0250_0750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/0500_1000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/0750_1250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/1000_1500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/1250_1750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/1500_2000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/1750_2250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/2000_2500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/2250_2750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/2500_3000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/2750_3250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/3000_3500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/3250_3750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/3500_4000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/3750_4250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/4000_4500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/4250_4750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/4500_5000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/pairtypes_k_b0_cutoff_5.00.csv

# %%
b_agent.spectral_decomposition()
b_agent.set_mean_r_alpha_array()
b_agent.t_agent.mean.GetEigenvectorEigenvectorT()
# Out:
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.

# %%
## 論文 圖5.21(A)
b_agent.plot_prominent_modes_and_identify_atom_with_interactive(strandid=None)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=132, min=1), Output()), _dom_classes=('w…

# %%
b_agent.plot_prominent_modes_and_get_identify_pair_with_interactive(\
        strandid=None, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, filter=True)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=132, min=1), Output()), _dom_classes=('w…

# %%
b_agent.t_agent.mean.get_modes_info(strandid=None, n_mode=n_mode, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, is_return=False)
# Out:
# 100%|██████████| 30/30 [00:00<00:00, 45.80it/s]

# %%
## 論文 圖5.22(C)
b_agent.t_agent.mean.display_df_info_by_resid(save=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#     </tr>
#     <tr>
#       <th>Residue Pair</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>ss_st<br>Q3,top</th>
#       <td>$\rm{\lambda}^{\rm{st}}_{1}$=30.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{st}}_{1}$:<br>C5C2(G2G3)<br>C4N3(G2G3)<br>C4C4(G2G3)</td>
#       <td>$\rm{\lambda}^{\rm{st}}_{4}$=25.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{st}}_{4}$:<br>C4N3(G2G3)<br>C5C6(G2G3)<br>C5N1(G2G3)<br>C4C4(G2G3)</td>
#       <td>$\rm{\lambda}^{\rm{st}}_{6}$=22.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{st}}_{6}$:<br>C6C6(G2G3)<br>N1C6(G2G3)</td>
#       <td>$\rm{\lambda}^{\rm{st}}_{8}$=18.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{st}}_{8}$:<br>C2C4(G2G3)<br>N3C4(G2G3)</td>
#       <td>$\rm{\lambda}^{\rm{st}}_{12}$=16.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{st}}_{12}$:<br>N1C5(G2G3)<br>C2C5(G2G3)</td>
#       <td>$\rm{\lambda}^{\rm{st}}_{14}$=15.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{st}}_{14}$:<br>C2C5(G2G3)</td>
#       <td>$\rm{\lambda}^{\rm{st}}_{16}$=14.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{st}}_{16}$:<br>N7N2(G2G3)<br>C8N2(G2G3)<br>N7N1(G2G3)</td>
#       <td>$\rm{\lambda}^{\rm{st}}_{20}$=12.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{st}}_{20}$:<br>N3N3(G2G3)</td>
#       <td>$\rm{\lambda}^{\rm{st}}_{28}$=9.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{st}}_{28}$:<br>N7N1(G2G3)</td>
#     </tr>
#     <tr>
#       <th>ss_st<br>Q2,top</th>
#       <td>$\rm{\lambda}^{\rm{st}}_{5}$=22.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{st}}_{5}$:<br>C6N1(G10G9)<br>C6C2(G10G9)<br>C6N3(G10G9)<br>N1C4(G10G9)<br>N1N3(G10G9)</td>
#       <td>$\rm{\lambda}^{\rm{st}}_{7}$=19.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{st}}_{7}$:<br>N1C4(G10G9)<br>C6N1(G10G9)</td>
#       <td>$\rm{\lambda}^{\rm{st}}_{15}$=14.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{st}}_{15}$:<br>O6N1(G10G9)<br>C6N3(G10G9)</td>
#       <td>$\rm{\lambda}^{\rm{st}}_{26}$=10.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{st}}_{26}$:<br>C5C2(G10G9)<br>O6C2(G10G9)<br>C5N3(G10G9)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>ss_st<br>Q1,top</th>
#       <td>$\rm{\lambda}^{\rm{st}}_{2}$=27.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{st}}_{2}$:<br>C6N1(G22G21)<br>C6C2(G22G21)<br>C6C6(G22G21)</td>
#       <td>$\rm{\lambda}^{\rm{st}}_{10}$=17.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{st}}_{10}$:<br>C5C2(G22G21)<br>N1C2(G22G21)<br>C4C2(G22G21)</td>
#       <td>$\rm{\lambda}^{\rm{st}}_{13}$=15.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{st}}_{13}$:<br>C2C4(G22G21)<br>C2N3(G22G21)<br>N3C4(G22G21)</td>
#       <td>$\rm{\lambda}^{\rm{st}}_{17}$=14.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{st}}_{17}$:<br>N1C6(G22G21)<br>O6C6(G14G21)<br>C5N1(G22G21)</td>
#       <td>$\rm{\lambda}^{\rm{st}}_{22}$=11.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{st}}_{22}$:<br>N1C5(G22G21)</td>
#       <td>$\rm{\lambda}^{\rm{st}}_{23}$=11.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{st}}_{23}$:<br>C4N3(G22G21)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>ss_st<br>Q4,top</th>
#       <td>$\rm{\lambda}^{\rm{st}}_{3}$=25.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{st}}_{3}$:<br>C6N1(G14G15)<br>C6C6(G14G15)<br>N1C6(G14G15)</td>
#       <td>$\rm{\lambda}^{\rm{st}}_{9}$=17.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{st}}_{9}$:<br>N1C6(G14G15)<br>N1C5(G14G15)<br>C2C4(G14G15)<br>C2C5(G14G15)</td>
#       <td>$\rm{\lambda}^{\rm{st}}_{11}$=17.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{st}}_{11}$:<br>C5C2(G14G15)<br>C4C2(G14G15)<br>C5N3(G14G15)<br>C4N3(G14G15)<br>N3N3(G14G15)</td>
#       <td>$\rm{\lambda}^{\rm{st}}_{18}$=13.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{st}}_{18}$:<br>C5C2(G14G15)</td>
#       <td>$\rm{\lambda}^{\rm{st}}_{19}$=12.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{st}}_{19}$:<br>C6C6(G14G15)<br>N1N1(G14G15)<br>C5N1(G14G15)</td>
#       <td>$\rm{\lambda}^{\rm{st}}_{21}$=11.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{st}}_{21}$:<br>C2C5(G14G15)<br>C4N3(G14G15)<br>N3N3(G14G15)<br>C2C2(G14G15)</td>
#       <td>$\rm{\lambda}^{\rm{st}}_{25}$=10.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{st}}_{25}$:<br>N3C4(G14G15)<br>C2N3(G14G15)</td>
#       <td>$\rm{\lambda}^{\rm{st}}_{30}$=8.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{st}}_{30}$:<br>C4C2(G14G15)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>cs_st<br>Q4Q1,top</th>
#       <td>$\rm{\lambda}^{\rm{st}}_{29}$=9.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{st}}_{29}$:<br>O6C6(G14G21)<br>O6O6(G14G21)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# Write /home/user/workfolder/g4dna_protocol_demo/basket/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/basket_ST_TOP.csv

# %%
hotspot_pair_num = 8
## Summaries aiaj
atom_pairs_all_resid = {}
for gstrand_layer, modes_info in b_agent.t_agent.mean.df_info_by_resid.iterrows():
    if not 'ss_st' in gstrand_layer: continue
    atom_pairs_all_resid.setdefault(gstrand_layer, [])
    for mode_info in modes_info:
        atom_pairs = mode_info.split()
        atom_pairs = atom_pairs[2:]
        atom_pairs = [atom_pair.split('(')[0] for atom_pair in atom_pairs]
        atom_pairs_all_resid[gstrand_layer] += atom_pairs
## count aiaj and select highest 7 aiaj as hotspot pair
atom_pairs_count = list(atom_pairs_all_resid.values())
atom_pairs_count = [a for ap in atom_pairs_count for a in ap]
atom_pairs_count = np.unique(atom_pairs_count, return_counts=True)
atom_pairs_count = {atom_pair: count for atom_pair, count in zip(atom_pairs_count[0], atom_pairs_count[1])}
atom_pairs_count = dict(sorted(atom_pairs_count.items(), key=lambda x:x[1], reverse=True))
df_hotspot_pairs = pd.DataFrame([atom_pairs_count.keys(),atom_pairs_count.values()], index=[r'$\rm{a}_{i}\rm{a}_{j}$','count']).T
df_hotspot_pairs.index = range(1, len(df_hotspot_pairs)+1)
df_hotspot_pairs['hotspot'] = ''
df_hotspot_pairs.loc[df_hotspot_pairs.index[:hotspot_pair_num], 'hotspot'] = 'v'

# %%
df_hotspot_pairs
# Out:
#    $\rm{a}_{i}\rm{a}_{j}$ count hotspot
# 1                    C4N3     5       v
# 2                    C5C2     5       v
# 3                    C2C5     4       v
# 4                    C6C6     4       v
# 5                    C6N1     4       v
# 6                    N1C6     4       v
# 7                    C2C4     3       v
# 8                    C4C2     3       v
# 9                    C5N1     3
# 10                   N1C5     3
# 11                   N3C4     3
# 12                   N3N3     3
# 13                   C2N3     2
# 14                   C4C4     2
# 15                   C5N3     2
# 16                   C6C2     2
# 17                   C6N3     2
# 18                   N1C4     2
# 19                   N7N1     2
# 20                   C2C2     1
# 21                   C5C6     1
# 22                   C8N2     1
# 23                   N1C2     1
# 24                   N1N1     1
# 25                   N1N3     1
# 26                   N7N2     1
# 27                   O6C2     1
# 28                   O6C6     1
# 29                   O6N1     1

# %%
## 確認機械熱點原子對的機械強度k_ij是否較高
b_agent.t_agent.mean.df_m.sort_values(by='k', ascending=False)
# Out:
#        Enm_i Strand_i  Resid_i Atomname_i  Atomid_i Enm_j Strand_j  Resid_j  \
# PairID
# 7886    A436  STRAND1       21         N1       436  A456  STRAND1       22
# 828      A31  STRAND1        2         C6        31   A53  STRAND1        3
# 1036     A37  STRAND1        2         C4        37   A58  STRAND1        3
# 801      A30  STRAND1        2         C5        30   A56  STRAND1        3
# 5631    A285  STRAND1       14         C6       285  A309  STRAND1       15
# ...      ...      ...      ...        ...       ...   ...      ...      ...
# 3688    A178  STRAND1        9         N7       178  A458  STRAND1       22
# 3686    A178  STRAND1        9         N7       178  A456  STRAND1       22
# 3682    A178  STRAND1        9         N7       178  A452  STRAND1       22
# 3675    A178  STRAND1        9         N7       178  A207  STRAND1       10
# 3806    A184  STRAND1        9         N2       184  A198  STRAND1       10
#
#        Atomname_j  Atomid_j         k        b0 Category
# PairID
# 7886           C6       456  7.862589  3.349900    ss_st
# 828            C6        53  7.569158  3.503774    ss_st
# 1036           N3        58  7.449679  3.413774    ss_st
# 801            C2        56  7.355132  3.481674    ss_st
# 5631           N1       309  7.025979  3.305689    ss_st
# ...           ...       ...       ...       ...      ...
# 3688           N1       458  0.000000  5.297068    cs_st
# 3686           C6       456  0.000000  4.102637    cs_st
# 3682           N9       452  0.000000  5.561689    cs_st
# 3675           N3       207  0.000000  5.496211    ss_st
# 3806           N9       198  0.000000  5.182174    ss_st
#
# [518 rows x 13 columns]

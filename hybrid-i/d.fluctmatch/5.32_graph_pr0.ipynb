# %%
import sys
sys.path.append("../../smsl")

# %%
from smsl.graphBigtraj import BigTrajGraphAgent
from smsl.graph import PR0

import warnings; warnings.filterwarnings("ignore")
import numpy as np

# %%
## 見論文表B.7
n_mode=90         ## $\alpha_c$
vlv_threshold=0.2 ## $\nu_{\text{c}}$
pe_threshold=0.5  ## $\kappa_{\text{c}}$

# %%
b_agent = BigTrajGraphAgent(PR0)
# Out:
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/0000_0500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/0250_0750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/0500_1000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/0750_1250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/1000_1500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/1250_1750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/1500_2000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/1750_2250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/2000_2500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/2250_2750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/2500_3000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/2750_3250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/3000_3500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/3250_3750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/3500_4000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/3750_4250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/4000_4500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/4250_4750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/4500_5000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/pairtypes_k_b0_cutoff_5.00.csv

# %%
b_agent.spectral_decomposition()
b_agent.set_mean_r_alpha_array()
b_agent.t_agent.mean.GetEigenvectorEigenvectorT()
# Out:
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.

# %%
## 論文 圖5.24(B)
b_agent.plot_prominent_modes_and_identify_atom_with_interactive(strandid=None)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=239, min=1), Output()), _dom_classes=('w…

# %%
b_agent.plot_prominent_modes_and_get_identify_pair_with_interactive(\
        strandid=None, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, filter=True)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=239, min=1), Output()), _dom_classes=('w…

# %%
b_agent.t_agent.mean.get_modes_info(strandid=None, n_mode=n_mode, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, is_return=False)
# Out:
# 100%|██████████| 90/90 [00:00<00:00, 135.93it/s]

# %%
## 論文 圖5.24(C)
b_agent.t_agent.mean.display_df_info_by_resid(save=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#     </tr>
#     <tr>
#       <th>Residue Pair</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A1</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{16}$=37.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{16}$:<br>C5'C2'(A1A1)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{42}$=23.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{42}$:<br>O4'O3'(A1A1)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{63}$=13.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{63}$:<br>O5'C3'(A1A1)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G2</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{32}$=29.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{32}$:<br>C5'C1'(G2G2)<br>C1'O3'(G2G2)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{48}$=20.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{48}$:<br>O4'O3'(G2G2)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{70}$=12.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{70}$:<br>O2PC4'(G2G2)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G3</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{6}$=43.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{6}$:<br>O1PC5'(G3G3)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{7}$=42.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{7}$:<br>O5'C3'(G3G3)<br>O5'O4'(G3G3)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{50}$=18.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{50}$:<br>O4'O3'(G3G3)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G4</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{17}$=36.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{17}$:<br>C5'C2'(G4G4)<br>O1PC5'(G4G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{24}$=32.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{24}$:<br>O5'O4'(G4G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{46}$=20.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{46}$:<br>C1'O3'(G4G4)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T5</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{35}$=27.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{35}$:<br>C1'O3'(T5T5)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{57}$=16.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{57}$:<br>O5'O4'(T5T5)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{74}$=11.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{74}$:<br>C5'C2'(T5T5)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T6</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{8}$=42.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{8}$:<br>O1PC5'(T6T6)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{27}$=30.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{27}$:<br>O4'O3'(T6T6)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{54}$=17.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{54}$:<br>O5'C3'(T6T6)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{90}$=7.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{90}$:<br>C1'O3'(T6T6)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A7</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{23}$=34.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{23}$:<br>O5'C3'(A7A7)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{41}$=23.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{41}$:<br>C5'C2'(A7A7)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{49}$=19.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{49}$:<br>O4'O3'(A7A7)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G8</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{12}$=40.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{12}$:<br>O1PC5'(G8G8)<br>C5'C2'(G8G8)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{29}$=29.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{29}$:<br>O4'O3'(G8G8)<br>C1'O3'(G8G8)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{52}$=18.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{52}$:<br>O5'C3'(G8G8)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G9</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{4}$=44.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{4}$:<br>O5'C3'(G9G9)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{10}$=41.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{10}$:<br>O1PC5'(G9G9)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{55}$=17.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{55}$:<br>O4'O3'(G9G9)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G10</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{15}$=37.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{15}$:<br>C5'C2'(G10G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{36}$=26.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{36}$:<br>O5'O4'(G10G10)<br>O4'O3'(G10G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{61}$=14.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{61}$:<br>C1'O3'(G10G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{83}$=9.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{83}$:<br>O1PC4'(G10G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{86}$=8.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{86}$:<br>O2PC3'(G10G10)</td>
#     </tr>
#     <tr>
#       <th>T11</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{14}$=38.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{14}$:<br>O1PC5'(T11T11)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{22}$=34.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{22}$:<br>O5'O4'(T11T11)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{59}$=15.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{59}$:<br>O4'O3'(T11T11)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T12</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{20}$=36.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{20}$:<br>O1PC5'(T12T12)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{28}$=30.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{28}$:<br>O5'O4'(T12T12)<br>O5'C3'(T12T12)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A13</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{37}$=26.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{37}$:<br>C1'O3'(A13A13)<br>O4'O3'(A13A13)<br>C5'O3'(A13A13)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{40}$=24.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{40}$:<br>PC3'(A13A13)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{65}$=13.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{65}$:<br>C5'C2'(A13A13)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G14</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{11}$=41.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{11}$:<br>C1'O3'(G14G14)<br>O4'O3'(G14G14)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{33}$=27.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{33}$:<br>O5'O4'(G14G14)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{51}$=18.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{51}$:<br>C5'C2'(G14G14)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G15</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{30}$=29.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{30}$:<br>O5'C3'(G15G15)<br>O5'O4'(G15G15)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{47}$=20.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{47}$:<br>O1PC5'(G15G15)<br>O1PC4'(G15G15)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G16</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{13}$=38.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{13}$:<br>O1PC5'(G16G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{25}$=31.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{25}$:<br>O5'O4'(G16G16)<br>O5'C3'(G16G16)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T17</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{1}$=52.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{1}$:<br>C5'C2'(T17T17)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{9}$=41.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{9}$:<br>O4'O3'(T17T17)<br>C1'O3'(T17T17)<br>O5'O4'(T17T17)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{39}$=24.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{39}$:<br>O5'O4'(T17T17)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T18</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{2}$=49.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{2}$:<br>C5'C2'(T18T18)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{19}$=36.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{19}$:<br>O5'C3'(T18T18)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{38}$=26.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{38}$:<br>C1'O3'(T18T18)<br>O4'O3'(T18T18)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A19</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{3}$=44.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{3}$:<br>O1PC5'(A19A19)</td>
#       <td>$\rm{\la
# Write /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/hybrid-i_PR0.csv

# %%
b_agent.t_agent.mean.df_m.sort_values(by='k', ascending=False)
# Out:
#        Enm_i Strand_i  Resid_i Atomname_i  Atomid_i Enm_j Strand_j  Resid_j  \
# PairID
# 6612    A343  STRAND1       17        C5'       343  A357  STRAND1       17
# 3549    A169  STRAND1        9        O1P       169  A172  STRAND1        9
# 1115     A42  STRAND1        3        O1P        42   A45  STRAND1        3
# 7641    A423  STRAND1       21        O1P       423  A426  STRAND1       21
# 3563    A171  STRAND1        9        O5'       171  A187  STRAND1        9
# ...      ...      ...      ...        ...       ...   ...      ...      ...
# 4684    A236  STRAND1       12        C5'       236  A251  STRAND1       12
# 4743    A239  STRAND1       12        C1'       239  A251  STRAND1       12
# 4926    A252  STRAND1       13          P       252  A257  STRAND1       13
# 4927    A252  STRAND1       13          P       252  A258  STRAND1       13
# 8011    A451  STRAND1       22        C1'       451  A465  STRAND1       22
#
#        Atomname_j  Atomid_j          k        b0 Category
# PairID
# 6612          C2'       357  20.829789  3.262732      pr0
# 3549          C5'       172  20.076389  2.947753      pr0
# 1115          C5'        45  19.199558  2.975911      pr0
# 7641          C5'       426  18.650463  2.979347      pr0
# 3563          C3'       187  18.486953  2.907879      pr0
# ...           ...       ...        ...       ...      ...
# 4684          O3'       251   0.000000  3.578721      pr0
# 4743          O3'       251   0.000000  3.073216      pr0
# 4926          C4'       257   0.000000  3.373479      pr0
# 4927          O4'       258   0.000000  3.785984      pr0
# 8011          O3'       465   0.000000  2.971895      pr0
#
# [498 rows x 13 columns]

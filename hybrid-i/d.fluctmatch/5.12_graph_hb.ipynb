# %%
import sys
sys.path.append("../../smsl")

# %%
from smsl.graphBigtraj import BigTrajGraphAgent
from smsl.graph import HB

import warnings; warnings.filterwarnings("ignore")
import numpy as np

# %%
## 見論文表B.7
n_mode=30         ## $\alpha_c$
vlv_threshold=0.1 ## $\nu_{\text{c}}$
pe_threshold=0.6  ## $\kappa_{\text{c}}$

# %%
b_agent = BigTrajGraphAgent(HB)
# Out:
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/0000_0500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/0250_0750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/0500_1000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/0750_1250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/1000_1500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/1250_1750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/1500_2000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/1750_2250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/2000_2500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/2250_2750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/2500_3000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/2750_3250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/3000_3500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/3250_3750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/3500_4000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/3750_4250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/4000_4500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/4250_4750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/4500_5000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/pairtypes_k_b0_cutoff_5.00.csv

# %%
b_agent.spectral_decomposition()
b_agent.set_mean_r_alpha_array()
b_agent.t_agent.mean.GetEigenvectorEigenvectorT()
# Out:
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 132 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.

# %%
## 論文 圖5.20(A)
b_agent.plot_prominent_modes_and_identify_atom_with_interactive(strandid=None)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=132, min=1), Output()), _dom_classes=('w…

# %%
b_agent.plot_prominent_modes_and_get_identify_pair_with_interactive(\
        strandid=None, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, filter=True)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=132, min=1), Output()), _dom_classes=('w…

# %%
b_agent.t_agent.mean.get_modes_info(strandid=None, n_mode=n_mode, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, is_return=False)
# Out:
# 100%|██████████| 30/30 [00:00<00:00, 59.05it/s]

# %%
b_agent.t_agent.mean.df_info_by_modes
# Out:
#    mode lambda hotspot_atom             0             1             2  \
# 1     1   36.6       N7(G3)   N2N7(G21G3)
# 2     2   36.1      N2(G10)  N2N7(G10G14)
# 3     3   31.2       N7(G2)    N2N7(G8G2)
# 4     4   29.2      N2(G15)  N2N7(G15G21)
# 5     5   27.4       O6(G3)   O6O6(G21G3)    O6O6(G3G9)  O6O6(G15G21)
# 6     6   25.7       N7(G8)   N2N7(G16G8)
# 7     7   25.0      N2(G14)  N2N7(G14G22)
# 8     8   23.8       N2(G4)   N2N7(G4G10)
# 9     9   21.5       N7(G4)   N2N7(G22G4)
# 10   10   20.6      N7(G16)  N2N7(G20G16)  N2C5(G20G16)
# 11   11   18.8      N1(G14)  N1O6(G14G22)  O6O6(G14G22)  N1N1(G10G14)
# 12   12   17.9       N2(G9)   N2N7(G9G15)
# 13   13   16.6       N1(G2)   N1O6(G2G20)    N1N1(G8G2)   N1N1(G2G20)
# 14   14   15.3       N2(G3)    N2N7(G3G9)    N2C4(G3G9)
# 15   15   14.9       O6(G3)   O6O6(G9G15)
# 16   16   14.1       N1(G4)   N1O6(G4G10)   N1N1(G22G4)   N1N1(G4G10)
# 17   17   13.1       O6(G9)
# 18   18   12.8       C2(G4)   C2C5(G4G10)
# 19   19   12.6      O6(G16)   O6O6(G16G8)  N1O6(G20G16)  C6O6(G20G16)
# 20   20   12.0       O6(G2)   O6O6(G2G20)    N1N1(G8G2)   N1N1(G2G20)
# 21   21   11.9      O6(G14)  O6O6(G10G14)   N1N1(G22G4)  N1N1(G14G22)
# 22   22   11.2       C6(G3)    C6C6(G3G9)   C6C6(G9G15)   C6C6(G21G3)
# 23   23   11.1       O6(G2)    N1O6(G8G2)   N1N1(G16G8)    O6O6(G8G2)
# 24   24   10.6       O6(G4)  N1N1(G10G14)   O6O6(G4G10)   O6O6(G22G4)
# 25   25   10.1       C5(G3)   C2C5(G21G3)   N1C5(G21G3)
# 26   26    9.9      C6(G14)  C2C6(G14G22)   C6O6(G22G4)  C6O6(G14G22)
# 27   27    9.2       C5(G8)   C2C5(G16G8)
# 28   28    8.9      C2(G10)  C2C6(G10G14)  C2C6(G14G22)  C2C5(G10G14)
# 29   29    8.9       C2(G3)    C2C5(G3G9)    N1C5(G3G9)
# 30   30    8.2       O6(G8)   N1O6(G16G8)
#
#                3            4
# 1
# 2
# 3
# 4
# 5    O6O6(G9G15)
# 6
# 7
# 8
# 9
# 10
# 11   O6O6(G22G4)
# 12
# 13   O6O6(G2G20)   N1O6(G8G2)
# 14
# 15
# 16
# 17
# 18
# 19
# 20    O6O6(G8G2)  O6O6(G16G8)
# 21  N1O6(G10G14)
# 22
# 23  N1O6(G20G16)   C6O6(G8G2)
# 24
# 25
# 26
# 27
# 28
# 29
# 30

# %%
## 論文 圖5.20(B)
b_agent.t_agent.mean.display_df_info_by_resid(save=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#     </tr>
#     <tr>
#       <th>Residue Pair</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Q3Q4,top</th>
#       <td>$\rm{\lambda}^{\rm{hb}}_{13}$=16.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{hb}}_{13}$:<br>N1O6(G2G20)<br>N1N1(G8G2)<br>N1N1(G2G20)<br>O6O6(G2G20)<br>N1O6(G8G2)</td>
#       <td>$\rm{\lambda}^{\rm{hb}}_{20}$=12.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{hb}}_{20}$:<br>O6O6(G2G20)<br>N1N1(G8G2)<br>N1N1(G2G20)<br>O6O6(G8G2)<br>O6O6(G16G8)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Q2Q3,top</th>
#       <td>$\rm{\lambda}^{\rm{hb}}_{3}$=31.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{hb}}_{3}$:<br>N2N7(G8G2)</td>
#       <td>$\rm{\lambda}^{\rm{hb}}_{23}$=11.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{hb}}_{23}$:<br>N1O6(G8G2)<br>N1N1(G16G8)<br>O6O6(G8G2)<br>N1O6(G20G16)<br>C6O6(G8G2)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Q1Q2,top</th>
#       <td>$\rm{\lambda}^{\rm{hb}}_{6}$=25.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{hb}}_{6}$:<br>N2N7(G16G8)</td>
#       <td>$\rm{\lambda}^{\rm{hb}}_{19}$=12.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{hb}}_{19}$:<br>O6O6(G16G8)<br>N1O6(G20G16)<br>C6O6(G20G16)</td>
#       <td>$\rm{\lambda}^{\rm{hb}}_{27}$=9.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{hb}}_{27}$:<br>C2C5(G16G8)</td>
#       <td>$\rm{\lambda}^{\rm{hb}}_{30}$=8.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{hb}}_{30}$:<br>N1O6(G16G8)</td>
#     </tr>
#     <tr>
#       <th>Q4Q1,top</th>
#       <td>$\rm{\lambda}^{\rm{hb}}_{10}$=20.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{hb}}_{10}$:<br>N2N7(G20G16)<br>N2C5(G20G16)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Q3Q2,mid</th>
#       <td>$\rm{\lambda}^{\rm{hb}}_{14}$=15.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{hb}}_{14}$:<br>N2N7(G3G9)<br>N2C4(G3G9)</td>
#       <td>$\rm{\lambda}^{\rm{hb}}_{22}$=11.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{hb}}_{22}$:<br>C6C6(G3G9)<br>C6C6(G9G15)<br>C6C6(G21G3)</td>
#       <td>$\rm{\lambda}^{\rm{hb}}_{29}$=8.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{hb}}_{29}$:<br>C2C5(G3G9)<br>N1C5(G3G9)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Q2Q1,mid</th>
#       <td>$\rm{\lambda}^{\rm{hb}}_{12}$=17.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{hb}}_{12}$:<br>N2N7(G9G15)</td>
#       <td>$\rm{\lambda}^{\rm{hb}}_{15}$=14.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{hb}}_{15}$:<br>O6O6(G9G15)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Q1Q4,mid</th>
#       <td>$\rm{\lambda}^{\rm{hb}}_{4}$=29.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{hb}}_{4}$:<br>N2N7(G15G21)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Q4Q3,mid</th>
#       <td>$\rm{\lambda}^{\rm{hb}}_{1}$=36.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{hb}}_{1}$:<br>N2N7(G21G3)</td>
#       <td>$\rm{\lambda}^{\rm{hb}}_{5}$=27.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{hb}}_{5}$:<br>O6O6(G21G3)<br>O6O6(G3G9)<br>O6O6(G15G21)<br>O6O6(G9G15)</td>
#       <td>$\rm{\lambda}^{\rm{hb}}_{25}$=10.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{hb}}_{25}$:<br>C2C5(G21G3)<br>N1C5(G21G3)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Q3Q2,bot</th>
#       <td>$\rm{\lambda}^{\rm{hb}}_{8}$=23.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{hb}}_{8}$:<br>N2N7(G4G10)</td>
#       <td>$\rm{\lambda}^{\rm{hb}}_{16}$=14.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{hb}}_{16}$:<br>N1O6(G4G10)<br>N1N1(G22G4)<br>N1N1(G4G10)</td>
#       <td>$\rm{\lambda}^{\rm{hb}}_{18}$=12.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{hb}}_{18}$:<br>C2C5(G4G10)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Q2Q1,bot</th>
#       <td>$\rm{\lambda}^{\rm{hb}}_{2}$=36.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{hb}}_{2}$:<br>N2N7(G10G14)</td>
#       <td>$\rm{\lambda}^{\rm{hb}}_{21}$=11.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{hb}}_{21}$:<br>O6O6(G10G14)<br>N1N1(G22G4)<br>N1N1(G14G22)<br>N1O6(G10G14)</td>
#       <td>$\rm{\lambda}^{\rm{hb}}_{24}$=10.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{hb}}_{24}$:<br>N1N1(G10G14)<br>O6O6(G4G10)<br>O6O6(G22G4)</td>
#       <td>$\rm{\lambda}^{\rm{hb}}_{28}$=8.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{hb}}_{28}$:<br>C2C6(G10G14)<br>C2C6(G14G22)<br>C2C5(G10G14)</td>
#     </tr>
#     <tr>
#       <th>Q1Q4,bot</th>
#       <td>$\rm{\lambda}^{\rm{hb}}_{7}$=25.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{hb}}_{7}$:<br>N2N7(G14G22)</td>
#       <td>$\rm{\lambda}^{\rm{hb}}_{11}$=18.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{hb}}_{11}$:<br>N1O6(G14G22)<br>O6O6(G14G22)<br>N1N1(G10G14)<br>O6O6(G22G4)</td>
#       <td>$\rm{\lambda}^{\rm{hb}}_{26}$=9.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{hb}}_{26}$:<br>C2C6(G14G22)<br>C6O6(G22G4)<br>C6O6(G14G22)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>Q4Q3,bot</th>
#       <td>$\rm{\lambda}^{\rm{hb}}_{9}$=21.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{hb}}_{9}$:<br>N2N7(G22G4)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# Write /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/hybrid-i_HB.csv

# %%
## 確認機械熱點原子對的機械強度k_ij是否較高
b_agent.t_agent.mean.df_m.sort_values(by='k', ascending=False)
# Out:
#        Enm_i Strand_i  Resid_i Atomname_i  Atomid_i Enm_j Strand_j  Resid_j  \
# PairID
# 1319     A51  STRAND1        3         N7        51  A438  STRAND1       21
# 4217    A206  STRAND1       10         N2       206  A283  STRAND1       14
# 862      A29  STRAND1        2         N7        29  A162  STRAND1        8
# 6083    A311  STRAND1       15         N2       311  A432  STRAND1       21
# 3357    A156  STRAND1        8         N7       156  A333  STRAND1       16
# ...      ...      ...      ...        ...       ...   ...      ...      ...
# 3386    A157  STRAND1        8         C5       157  A331  STRAND1       16
# 1016     A35  STRAND1        2         N2        35  A409  STRAND1       20
# 3408    A158  STRAND1        8         C6       158  A329  STRAND1       16
# 3435    A159  STRAND1        8         O6       159  A328  STRAND1       16
# 3731    A180  STRAND1        9         C6       180  A435  STRAND1       21
#
#        Atomname_j  Atomid_j          k        b0 Category
# PairID
# 1319           N2       438  17.147226  2.928147       hb
# 4217           N7       283  17.091195  2.939700       hb
# 862            N2       162  14.249211  2.950053       hb
# 6083           N7       432  14.120653  2.968321       hb
# 3357           N2       333  11.012884  2.956737       hb
# ...           ...       ...        ...       ...      ...
# 3386           N1       331   0.000000  4.350258       hb
# 1016           C8       409   0.000000  4.086979       hb
# 3408           C6       329   0.000000  4.815279       hb
# 3435           C5       328   0.000000  5.032900       hb
# 3731           O6       435   0.000000  5.221668       hb
#
# [328 rows x 13 columns]

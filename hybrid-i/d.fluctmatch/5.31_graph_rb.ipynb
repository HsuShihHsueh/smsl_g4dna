# %%
import sys
sys.path.append("../../smsl")

# %%
from smsl.graphBigtraj import BigTrajGraphAgent
from smsl.graph import RB

import warnings; warnings.filterwarnings("ignore")
import numpy as np

# %%
## 見論文表B.7
n_mode=45         ## $\alpha_c$
vlv_threshold=0.2 ## $\nu_{\text{c}}$
pe_threshold=0.55 ## $\kappa_{\text{c}}$

# %%
b_agent = BigTrajGraphAgent(RB)
# Out:
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/0000_0500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/0250_0750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/0500_1000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/0750_1250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/1000_1500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/1250_1750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/1500_2000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/1750_2250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/2000_2500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/2250_2750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/2500_3000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/2750_3250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/3000_3500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/3250_3750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/3500_4000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/3750_4250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/4000_4500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/4250_4750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/4500_5000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/pairtypes_k_b0_cutoff_5.00.csv

# %%
b_agent.spectral_decomposition()
b_agent.set_mean_r_alpha_array()
b_agent.t_agent.mean.GetEigenvectorEigenvectorT()
# Out:
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 465 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.

# %%
## 論文 圖5.23(A)
b_agent.plot_prominent_modes_and_identify_atom_with_interactive(strandid=None)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=465, min=1), Output()), _dom_classes=('w…

# %%
b_agent.plot_prominent_modes_and_get_identify_pair_with_interactive(\
        strandid=None, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, filter=True)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=465, min=1), Output()), _dom_classes=('w…

# %%
b_agent.t_agent.mean.get_modes_info(strandid=None, n_mode=n_mode, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, is_return=False)
# Out:
# 100%|██████████| 45/45 [00:00<00:00, 66.67it/s]

# %%
## 論文 圖5.23(C)
b_agent.t_agent.mean.display_df_info_by_resid(save=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#     <tr>
#       <th>Residue Pair</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A1</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{29}$=52.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{29}$:<br>C1'N3(A1A1)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G2</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{7}$=78.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{7}$:<br>C4C2'(G2G2)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{33}$=48.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{33}$:<br>C1'N3(G2G2)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G3</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{28}$=52.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{28}$:<br>C8C2'(G3G3)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{41}$=43.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{41}$:<br>C1'N3(G3G3)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G4</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{15}$=71.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{15}$:<br>C8C2'(G4G4)<br>C4C2'(G4G4)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T5</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{6}$=83.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{6}$:<br>C6C2'(T5T5)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{14}$=71.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{14}$:<br>C1'O2(T5T5)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T6</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{5}$=88.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{5}$:<br>C6C2'(T6T6)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{16}$=70.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{16}$:<br>C1'O2(T6T6)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A7</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{4}$=90.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{4}$:<br>C1'N1(A7A7)<br>C1'C6(A7A7)<br>C1'N3(A7A7)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G8</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{8}$=77.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{8}$:<br>C4C2'(G8G8)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{32}$=49.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{32}$:<br>C1'N3(G8G8)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G9</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{45}$=41.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{45}$:<br>C1'N3(G9G9)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G10</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{10}$=75.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{10}$:<br>C8C2'(G10G10)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{44}$=42.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{44}$:<br>C1'N3(G10G10)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T11</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{9}$=76.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{9}$:<br>C1'O2(T11T11)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{11}$=74.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{11}$:<br>C6C2'(T11T11)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T12</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{13}$=72.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{13}$:<br>C1'O2(T12T12)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{24}$=56.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{24}$:<br>C6C2'(T12T12)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{40}$=43.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{40}$:<br>O4'N3(T12T12)</td>
#     </tr>
#     <tr>
#       <th>A13</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{20}$=62.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{20}$:<br>C4C2'(A13A13)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{35}$=47.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{35}$:<br>C1'N3(A13A13)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G14</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{2}$=95.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{2}$:<br>C4C2'(G14G14)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{38}$=46.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{38}$:<br>C1'N3(G14G14)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{43}$=42.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{43}$:<br>O4'C8(G14G14)</td>
#     </tr>
#     <tr>
#       <th>G15</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{12}$=74.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{12}$:<br>O4'C4(G15G15)<br>O4'C8(G15G15)<br>C4C2'(G15G15)<br>C8C2'(G15G15)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{26}$=53.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{26}$:<br>C1'N3(G15G15)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G16</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{23}$=58.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{23}$:<br>C8C2'(G16G16)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T17</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{17}$=70.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{17}$:<br>O4'C6(T17T17)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{22}$=59.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{22}$:<br>C1'O2(T17T17)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T18</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{3}$=93.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{3}$:<br>C6C2'(T18T18)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{19}$=66.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{19}$:<br>C1'O2(T18T18)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{34}$=48.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{34}$:<br>O4'C2(T18T18)</td>
#     </tr>
#     <tr>
#       <th>A19</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{18}$=69.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{18}$:<br>C8C2'(A19A19)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G20</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{1}$=96.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{1}$:<br>C4C2'(G20G20)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{25}$=55.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{25}$:<br>C1'N3(G20G20)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{30}$=51.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{30}$:<br>O4'C8(G20G20)</td>
#     </tr>
#     <tr>
#       <th>G21</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{36}$=46.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{36}$:<br>C8C2'(G21G21)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{39}$=44.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{39}$:<br>C1'N3(G21G21)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G22</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{21}$=60.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{21}$:<br>C8C2'(G22G22)<br>N7C2'(G22G22)</td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# Write /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/hybrid-i_RB.csv

# %%
b_agent.t_agent.mean.df_m.sort_values(by='k', ascending=False)
# Out:
#        Enm_i Strand_i  Resid_i Atomname_i  Atomid_i Enm_j Strand_j  Resid_j  \
# PairID
# 4374    A219  STRAND1       11        C1'       219  A228  STRAND1       11
# 2228     A92  STRAND1        5        C1'        92  A101  STRAND1        5
# 4740    A239  STRAND1       12        C1'       239  A248  STRAND1       12
# 6939    A368  STRAND1       18         C6       368  A377  STRAND1       18
# 2672    A114  STRAND1        6         C6       114  A123  STRAND1        6
# ...      ...      ...      ...        ...       ...   ...      ...      ...
# 4032    A198  STRAND1       10         N9       198  A209  STRAND1       10
# 4021    A197  STRAND1       10        C1'       197  A223  STRAND1       11
# 4020    A197  STRAND1       10        C1'       197  A222  STRAND1       11
# 4019    A197  STRAND1       10        C1'       197  A221  STRAND1       11
# 5         A1  STRAND1        1        O5'         1    A6  STRAND1        1
#
#        Atomname_j  Atomid_j          k        b0 Category
# PairID
# 4374           O2       228  34.827353  2.804005       rb
# 2228           O2       101  32.396000  2.800605       rb
# 4740           O2       248  32.395221  2.809800       rb
# 6939          C2'       377  31.370689  3.109626       rb
# 2672          C2'       123  30.586721  3.022253       rb
# ...           ...       ...        ...       ...      ...
# 4032          C3'       209   0.000000  3.686732       rb
# 4021          C5M       223   0.000000  5.116132       rb
# 4020           C5       222   0.000000  4.966368       rb
# 4019           C6       221   0.000000  4.314811       rb
# 5              N9         6   0.000000  4.632400       rb
#
# [2028 rows x 13 columns]

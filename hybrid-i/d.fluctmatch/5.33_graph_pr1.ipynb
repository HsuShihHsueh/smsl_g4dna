# %%
import sys
sys.path.append("../../smsl")

# %%
from smsl.graphBigtraj import BigTrajGraphAgent
from smsl.graph import PR1

import warnings; warnings.filterwarnings("ignore")
import numpy as np

# %%
## 見論文表B.7
n_mode=90         ## $\alpha_c$
vlv_threshold=0.2 ## $\nu_{\text{c}}$
pe_threshold=0.5  ## $\kappa_{\text{c}}$

# %%
b_agent = BigTrajGraphAgent(PR1)
# Out:
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/0000_0500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/0250_0750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/0500_1000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/0750_1250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/1000_1500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/1250_1750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/1500_2000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/1750_2250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/2000_2500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/2250_2750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/2500_3000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/2750_3250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/3000_3500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/3250_3750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/3500_4000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/3750_4250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/4000_4500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/4250_4750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/4500_5000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/pairtypes_k_b0_cutoff_5.00.csv

# %%
b_agent.spectral_decomposition()
b_agent.set_mean_r_alpha_array()
b_agent.t_agent.mean.GetEigenvectorEigenvectorT()
# Out:
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.

# %%
## 論文 圖5.25(B)
b_agent.plot_prominent_modes_and_identify_atom_with_interactive(strandid=None)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=239, min=1), Output()), _dom_classes=('w…

# %%
b_agent.plot_prominent_modes_and_get_identify_pair_with_interactive(\
        strandid=None, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, filter=True)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=239, min=1), Output()), _dom_classes=('w…

# %%
b_agent.t_agent.mean.get_modes_info(strandid=None, n_mode=n_mode, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, is_return=False)
# Out:
# 100%|██████████| 90/90 [00:00<00:00, 146.60it/s]

# %%
## 論文 圖5.25(C)
b_agent.t_agent.mean.display_df_info_by_resid(save=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#     </tr>
#     <tr>
#       <th>Residue Pair</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A1G2</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{23}$=33.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{23}$:<br>C3'O1P(A1G2)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{28}$=22.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{28}$:<br>C4'O2P(A1G2)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{61}$=11.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{61}$:<br>C2'O5'(A1G2)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{62}$=11.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{62}$:<br>O3'C5'(A1G2)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{63}$=10.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{63}$:<br>O4'P(A1G2)</td>
#     </tr>
#     <tr>
#       <th>G2G3</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{3}$=53.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{3}$:<br>C3'O2P(G2G3)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{20}$=39.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{20}$:<br>C2'P(G2G3)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{34}$=20.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{34}$:<br>O3'C5'(G2G3)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G3G4</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{31}$=20.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{31}$:<br>O3'C5'(G3G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{50}$=15.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{50}$:<br>C2'O1P(G3G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{56}$=13.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{56}$:<br>C4'O2P(G3G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{74}$=7.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{74}$:<br>C1'P(G3G4)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G4T5</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{24}$=32.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{24}$:<br>C3'O1P(G4T5)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{30}$=20.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{30}$:<br>C4'O5'(G4T5)<br>C4'P(G4T5)<br>C4'C5'(G4T5)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{70}$=8.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{70}$:<br>C2'C5'(G4T5)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{86}$=5.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{86}$:<br>C3'O4'(G4T5)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T5T6</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{10}$=48.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{10}$:<br>C3'O2P(T5T6)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{21}$=39.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{21}$:<br>C2'O5'(T5T6)<br>C2'P(T5T6)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{35}$=19.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{35}$:<br>O3'C5'(T5T6)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T6A7</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{9}$=49.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{9}$:<br>C3'O2P(T6A7)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{25}$=31.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{25}$:<br>C2'O1P(T6A7)<br>C2'P(T6A7)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{89}$=5.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{89}$:<br>C4'O2P(T6A7)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A7G8</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{12}$=45.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{12}$:<br>C3'O2P(A7G8)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{57}$=13.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{57}$:<br>C2'O1P(A7G8)<br>C2'P(A7G8)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G8G9</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{8}$=49.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{8}$:<br>C3'O2P(G8G9)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{18}$=41.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{18}$:<br>C2'O5'(G8G9)<br>C2'P(G8G9)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{45}$=15.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{45}$:<br>O3'C5'(G8G9)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G9G10</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{37}$=18.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{37}$:<br>O3'C5'(G9G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{43}$=15.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{43}$:<br>C2'O1P(G9G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{66}$=9.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{66}$:<br>C3'O2P(G9G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{87}$=5.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{87}$:<br>C1'P(G9G10)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G10T11</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{11}$=48.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{11}$:<br>C3'O2P(G10T11)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{15}$=44.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{15}$:<br>C2'P(G10T11)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{33}$=20.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{33}$:<br>O3'C5'(G10T11)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T11T12</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{7}$=50.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{7}$:<br>C3'O2P(T11T12)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{14}$=45.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{14}$:<br>C2'P(T11T12)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{42}$=16.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{42}$:<br>O3'C5'(T11T12)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T12A13</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{75}$=6.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{75}$:<br>O4'O2P(T12A13)<br>C4'O2P(T12A13)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A13G14</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{32}$=20.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{32}$:<br>C3'O1P(A13G14)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{59}$=13.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{59}$:<br>C4'O2P(A13G14)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{65}$=9.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{65}$:<br>O3'C5'(A13G14)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{68}$=9.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{68}$:<br>C1'P(A13G14)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{79}$=6.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{79}$:<br>C2'O5'(A13G14)</td>
#     </tr>
#     <tr>
#       <th>G14G15</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{6}$=51.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{6}$:<br>C2'P(G14G15)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{13}$=45.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{13}$:<br>C3'O2P(G14G15)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{29}$=22.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{29}$:<br>O3'C5'(G14G15)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G15G16</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{2}$=53.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{2}$:<br>C3'O2P(G15G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{26}$=26.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{26}$:<br>C2'P(G15G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{51}$=14.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{51}$:<br>O3'C5'(G15G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{71}$=8.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{71}$:<br>C4'O5'(G15G16)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G16T17</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{1}$=55.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{1}$:<br>C3'O2P(G16T17)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{73}$=7.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{73}$:<br>C2'P(G16T17)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{90}$=4.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{90}$:<br>C3'O5'(G16T17)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T17T18</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{22}$=35.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{22}$:<br>C3'O2P(T17T18)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{64}$=10.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{64}$:<br>C5'O5'(T17T18)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{78}$=6.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{78}$:<br>C4'O1P(T17T18)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T18A19</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{5}$=51.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{5}$:<br>C3'O2P(T18A19)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{17}$=41.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{17}$:<br>C2'P(T18A19
# Write /home/user/workfolder/g4dna_protocol_demo/hybrid-i/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/hybrid-i_PR1.csv

# %%
b_agent.t_agent.mean.df_m.sort_values(by='k', ascending=False)
# Out:
#        Enm_i Strand_i  Resid_i Atomname_i  Atomid_i Enm_j Strand_j  Resid_j  \
# PairID
# 6519    A336  STRAND1       16        C3'       336  A341  STRAND1       17
# 6122    A314  STRAND1       15        C3'       314  A319  STRAND1       16
# 1069     A38  STRAND1        2        C3'        38   A43  STRAND1        3
# 3512    A165  STRAND1        8        C3'       165  A170  STRAND1        9
# 7601    A419  STRAND1       20        C3'       419  A424  STRAND1       21
# ...      ...      ...      ...        ...       ...   ...      ...      ...
# 3577    A172  STRAND1        9        C5'       172  A190  STRAND1       10
# 3578    A172  STRAND1        9        C5'       172  A191  STRAND1       10
# 3589    A173  STRAND1        9        C4'       173  A190  STRAND1       10
# 3590    A173  STRAND1        9        C4'       173  A191  STRAND1       10
# 7936    A443  STRAND1       21        O3'       443  A464  STRAND1       22
#
#        Atomname_j  Atomid_j          k        b0 Category
# PairID
# 6519          O2P       341  26.606016  2.918179      pr1
# 6122          O2P       319  26.059121  2.919426      pr1
# 1069          O2P        43  23.422558  2.931326      pr1
# 3512          O2P       170  23.325184  2.947711      pr1
# 7601          O2P       424  23.167626  2.937453      pr1
# ...           ...       ...        ...       ...      ...
# 3577            P       190   0.000000  4.752695      pr1
# 3578          O1P       191   0.000000  4.769632      pr1
# 3589            P       190   0.000000  3.811800      pr1
# 3590          O1P       191   0.000000  4.139500      pr1
# 7936          C2'       464   0.000000  5.227716      pr1
#
# [944 rows x 13 columns]

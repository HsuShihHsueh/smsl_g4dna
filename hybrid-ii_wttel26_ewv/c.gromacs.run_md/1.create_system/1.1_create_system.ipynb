# %% [markdown]
# ### Reinitialize the file

# %%
# warning !! remove all except this script
## remove -i argument to run
# !rm `(ls | grep -v '.ipynb')`

# %%
pdbid = '2jpz'
drug  = 'EWV'
jobname = f'{pdbid}_{drug}' if not drug is None else pdbid

# %%
import os
ff_folder  = os.path.realpath("../../../smsl/opt/force_field")
mdp_folder = os.path.realpath("../../../smsl/opt/mdp")

# %% [markdown]
# ### Copy DNA from the file which process CHARMM

# %%
if drug is None:
    # !cp ../../a.charmm.dna_setup/{jobname}.pgro.pdb ./
else: 
    # !cp ../../b.amber.drug_ff/5.Output/{pdbid}.pgro.pdb ./
    # !cp ../../b.amber.drug_ff/5.Output/*{drug}* ./

# %%
# !export GMXLIB={ff_folder};\
 echo "2" | gmx pdb2gmx -f {pdbid}.pgro.pdb -o {pdbid}.gro.pdb -chainsep ter -water tip3p
# Out:
#                      :-) GROMACS - gmx pdb2gmx, 2023.2 (-:
#
# Executable:   /home/user/opt/gromacs-2023/bin/gmx
# Data prefix:  /home/user/opt/gromacs-2023
# Working dir:  /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/c.gromacs.run_md/1.create_system
# Command line:
#   gmx pdb2gmx -f 2jpz.pgro.pdb -o 2jpz.gro.pdb -chainsep ter -water tip3p
#
# Select the Force Field:
#
# From '/home/user/workfolder/g4dna_protocol_demo/smsl/opt/force_field':
#
#  1: AMBER14SB_parmbsc1
#
#  2: OL21 nucleic (Zgarbova et al., J. Chem. Theory Comput. 17, 6292-6301, 2021
#
# From '/home/user/opt/gromacs-2023/share/gromacs/top':
#
#  3: AMBER03 protein, nucleic AMBER94 (Duan et al., J. Comp. Chem. 24, 1999-2012, 2003)
#
#  4: AMBER94 force field (Cornell et al., JACS 117, 5179-5197, 1995)
#
#  5: AMBER96 protein, nucleic AMBER94 (Kollman et al., Acc. Chem. Res. 29, 461-469, 1996)
#
#  6: AMBER99 protein, nucleic AMBER94 (Wang et al., J. Comp. Chem. 21, 1049-1074, 2000)
#
#  7: AMBER99SB protein, nucleic AMBER94 (Hornak et al., Proteins 65, 712-725, 2006)
#
#  8: AMBER99SB-ILDN protein, nucleic AMBER94 (Lindorff-Larsen et al., Proteins 78, 1950-58, 2010)
#
#  9: AMBERGS force field (Garcia & Sanbonmatsu, PNAS 99, 2782-2787, 2002)
#
# 10: CHARMM27 all-atom force field (CHARM22 plus CMAP for proteins)
#
# 11: GROMOS96 43a1 force field
#
# 12: GROMOS96 43a2 force field (improved alkane dihedrals)
#
# 13: GROMOS96 45a3 force field (Schuler JCC 2001 22 1205)
#
# 14: GROMOS96 53a5 force field (JCC 2004 vol 25 pag 1656)
#
# 15: GROMOS96 53a6 force field (JCC 2004 vol 25 pag 1656)
#
# 16: GROMOS96 54a7 force field (Eur. Biophys. J. (2011), 40,, 843-856, DOI: 10.1007/s00249-011-0700-9)
#
# 17: OPLS-AA/L all-atom force field (2001 aminoacid dihedrals)
#
# Using the Amber14sb_OL21 force field in directory /home/user/workfolder/g4dna_protocol_demo/smsl/opt/force_field/amber14sb_OL21.ff
#
# going to rename /home/user/workfolder/g4dna_protocol_demo/smsl/opt/force_field/amber14sb_OL21.ff/aminoacids.r2b
# Opening force field file /home/user/workfolder/g4dna_protocol_demo/smsl/opt/force_field/amber14sb_OL21.ff/aminoacids.r2b
#
# going to rename /home/user/workfolder/g4dna_protocol_demo/smsl/opt/force_field/amber14sb_OL21.ff/dna.r2b
# Opening force field file /home/user/workfolder/g4dna_protocol_demo/smsl/opt/force_field/amber14sb_OL21.ff/dna.r2b
#
# going to rename /home/user/workfolder/g4dna_protocol_demo/smsl/opt/force_field/amber14sb_OL21.ff/rna.r2b
# Opening force field file /home/user/workfolder/g4dna_protocol_demo/smsl/opt/force_field/amber14sb_OL21.ff/rna.r2b
# Reading 2jpz.pgro.pdb...
# Read '', 845 atoms
#
# Analyzing pdb file
# Splitting chemical chains based on TER records only (ignoring chain id).
#
# There are 2 chains and 0 blocks of water and 28 residues with 845 atoms
#
#   chain  #res #atoms
#
#   1 ' '    26    843
#
#   2 ' '     2      2
#
# All occupancies are one
# All occupancies are one
# Opening force field file /home/user/workfolder/g4dna_protocol_demo/smsl/opt/force_field/amber14sb_OL21.ff/atomtypes.atp
#
# Reading residue database... (Amber14sb_OL21)
# Opening force field file /home/user/workfolder/g4dna_protocol_demo/smsl/opt/force_field/amber14sb_OL21.ff/aminoacids.rtp
# Opening force field file /home/user/workfolder/g4dna_protocol_demo/smsl/opt/force_field/amber14sb_OL21.ff/dna.rtp
# Opening force field file /home/user/workfolder/g4dna_protocol_demo/smsl/opt/force_field/amber14sb_OL21.ff/rna.rtp
# Opening force field file /home/user/workfolder/g4dna_protocol_demo/smsl/opt/force_field/amber14sb_OL21.ff/aminoacids.hdb
# Opening force field file /home/user/workfolder/g4dna_protocol_demo/smsl/opt/force_field/amber14sb_OL21.ff/dna.hdb
# Opening force field file /home/user/workfolder/g4dna_protocol_demo/smsl/opt/force_field/amber14sb_OL21.ff/rna.hdb
# Opening force field file /home/user/workfolder/g4dna_protocol_demo/smsl/opt/force_field/amber14sb_OL21.ff/aminoacids.n.tdb
# Opening force field file /home/user/workfolder/g4dna_protocol_demo/smsl/opt/force_field/amber14sb_OL21.ff/aminoacids.c.tdb
#
# Processing chain 1 (843 atoms, 26 residues)
#
# Identified residue DT1 as a starting terminus.
#
# Identified residue DT26 as a ending terminus.
# 8 out of 8 lines of specbond.dat converted successfully
# Opening force field file /home/user/workfolder/g4dna_protocol_demo/smsl/opt/force_field/amber14sb_OL21.ff/aminoacids.arn
# Opening force field file /home/user/workfolder/g4dna_protocol_demo/smsl/opt/force_field/amber14sb_OL21.ff/dna.arn
# Opening force field file /home/user/workfolder/g4dna_protocol_demo/smsl/opt/force_field/amber14sb_OL21.ff/rna.arn
#
# Checking for duplicate atoms....
#
# Generating any missing hydrogen atoms and/or adding termini.
#
# Now there are 26 residues with 843 atoms
# Chain time...
#
# Making bonds...
#
# Number of bonds was 910, now 910
#
# Generating angles, dihedrals and pairs...
# Before cleaning: 2204 pairs
# Before cleaning: 2414 dihedrals
#
# Making cmap torsions...
#
# There are 2414 dihedrals,  152 impropers, 1656 angles
#           2126 pairs,      910 bonds and     0 virtual sites
#
# Total mass 8158.234 a.m.u.
#
# Total charge -25.000 e
#
# Writing topology
#
# Processing chain 2 (2 atoms, 2 residues)
#
# Residue K1 has type 'Ion', assuming it is not linked into a chain.
#
# Residue K2 has type 'Ion', assuming it is not linked into a chain.
#
# Problem with chain definition, or missing terminal residues. This chain does not appear to contain a recognized chain molecule. If this is incorrect, you can edit residuetypes.dat to modify the behavior.
# 8 out of 8 lines of specbond.dat converted successfully
# Opening force field file /home/user/workfolder/g4dna_protocol_demo/smsl/opt/force_field/amber14sb_OL21.ff/aminoacids.arn
# Opening force field file /home/user/workfolder/g4dna_protocol_demo/smsl/opt/force_field/amber14sb_OL21.ff/dna.arn
# Opening force field file /home/user/workfolder/g4dna_protocol_demo/smsl/opt/force_field/amber14sb_OL21.ff/rna.arn
#
# Checking for duplicate atoms....
#
# Generating any missing hydrogen atoms and/or adding termini.
#
# Now there are 2 residues with 2 atoms
# Chain time...
#
# Making bonds...
#
# No bonds
#
# Generating angles, dihedrals and pairs...
#
# Making cmap torsions...
#
# There are    0 dihedrals,    0 impropers,    0 angles
#              0 pairs,        0 bonds and     0 virtual sites
#
# Total mass 78.200 a.m.u.
#
# Total charge 2.000 e
#
# Writing topology
#
# Including chain 1 in system: 843 atoms 26 residues
#
# Including chain 2 in system: 2 atoms 2 residues
#
# Now there are 845 atoms and 28 residues
#
# Total mass in system 8236.434 a.m.u.
#
# Total charge in system -23.000 e
#
# Writing coordinate file...
#
# 		--------- PLEASE NOTE ------------
#
# You have successfully generated a topology from: 2jpz.pgro.pdb.
#
# The Amber14sb_OL21 force field and the tip3p water model are used.
#
# 		--------- ETON ESAELP ------------
#
# GROMACS reminds you: "Occams Razor is the scientific principle that, all things being equal, the simplest explanation is always the dog ate my homework." (Greg Tamblyn)

# %% [markdown]
# ### Modify `topol.top`
# 1. in line 29(Include forcefield parameters下兩行), Adding
# ```
# ; Include ligand parameters
# #include "$drug_GMX.top"
# ```
# 2. in line 36(Include water topology之上), Adding
# ```
# ; Include ligand topology
# #ifdef POSRES
# #include "posre_$drug.itp"
# #endif
# ```
# 3. in line 61(最後一行), Adding
# ```
# $drug                 1
# (remember to reserved space here)
# ```

# %%
# Step 1: Add the ligand parameters include line at line 29
# !sed -i "28a ; Include ligand parameters\n#include \"\{drug}_GMX.top\"\n" topol.top

# # Step 2: Add the ligand topology section just after ligand parameters (Step 1) include at line 32
# !sed -i "31a ; Include ligand topology\n#ifdef POSRES\n#include \"posre_\{drug}.itp\"\n#endif\n" topol.top

# # Step 3: Add the ligand molecule at line 62
# # First, find where the last molecule line is (i.e., "DNA 1") and add the drug molecule after that.
# !sed -i "61a \{drug}                 1" topol.top

# %% [markdown]
# ### 因為兩藥物與G四聯體結構重疊，先回到
# [../../b.amber.drug_ff/6.Em_min/command.ipynb](../../b.amber.drug_ff/6.Em_min/command.ipynb) <br>
# 後，再複製不重疊結構回來

# %%
# !cp ../../b.amber.drug_ff/6.Em_min/{jobname}.final.gro.pdb ./{jobname}.gro.pdb

# %% [markdown]
# ### Add box and add solvent (water)
# `-d` can be change by [1.2_waterbox_setting.ipynb](1.2_waterbox_setting.ipynb)

# %%
# !cp topol.top topol.top.bak1

# %%
# !cp topol.top.bak1 topol.top

# %%
# !gmx editconf -f {jobname}.gro.pdb -o {jobname}_dode.pdb -c yes -d 1.03888 -bt dodecahedron
# Out:
#                      :-) GROMACS - gmx editconf, 2023.2 (-:
#
# Executable:   /home/user/opt/gromacs-2023/bin/gmx
# Data prefix:  /home/user/opt/gromacs-2023
# Working dir:  /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/c.gromacs.run_md/1.create_system
# Command line:
#   gmx editconf -f 2jpz_EWV.gro.pdb -o 2jpz_EWV_dode.pdb -c yes -d 1.03888 -bt dodecahedron
#
# Note that major changes are planned in future for editconf, to improve usability and utility.
# Read 888 atoms
# Volume: 162.282 nm^3, corresponds to roughly 73000 electrons
# No velocities found
#     system size :  3.391  2.963  2.445 (nm)
#     diameter    :  3.580               (nm)
#     center      :  0.042  0.003 -0.009 (nm)
#     box vectors :  6.122  6.122  6.122 (nm)
#     box angles  :  60.00  60.00  90.00 (degrees)
#     box volume  : 162.28               (nm^3)
#     shift       :  4.202  4.240  2.009 (nm)
# new center      :  4.243  4.243  2.000 (nm)
# new box vectors :  5.658  5.658  5.658 (nm)
# new box angles  :  60.00  60.00  90.00 (degrees)
# new box volume  : 128.05               (nm^3)
#
# GROMACS reminds you: "Remember, being healthy is basically dying as slowly as possible." (Ricky Gervais)

# %% [markdown]
# ### Add solvent (water)

# %%
# !gmx solvate -cp {jobname}_dode.pdb -cs spc216.gro -o {jobname}_water.pdb -p topol.top
# Out:
#                      :-) GROMACS - gmx solvate, 2023.2 (-:
#
# Executable:   /home/user/opt/gromacs-2023/bin/gmx
# Data prefix:  /home/user/opt/gromacs-2023
# Working dir:  /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/c.gromacs.run_md/1.create_system
# Command line:
#   gmx solvate -cp 2jpz_EWV_dode.pdb -cs spc216.gro -o 2jpz_EWV_water.pdb -p topol.top
#
# Reading solute configuration
# Reading solvent configuration
#
# Initialising inter-atomic distances...
#
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
# NOTE: From version 5.0 gmx solvate uses the Van der Waals radii
# from the source below. This means the results may be different
# compared to previous GROMACS versions.
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# A. Bondi
# van der Waals Volumes and Radii
# J. Phys. Chem. 68 (1964) pp. 441-451
# -------- -------- --- Thank You --- -------- --------
#
# Generating solvent configuration
# Will generate new solvent configuration of 4x4x3 boxes
# Solvent box contains 15315 atoms in 5105 residues
# Removed 2997 solvent atoms due to solvent-solvent overlap
# Removed 921 solvent atoms due to solute-solvent overlap
# Sorting configuration
# Found 1 molecule type:
#     SOL (   3 atoms):  3799 residues
# Generated solvent containing 11397 atoms in 3799 residues
# Writing generated configuration to 2jpz_EWV_water.pdb
#
# Output configuration contains 12285 atoms in 3828 residues
# Volume                 :     128.044 (nm^3)
# Density                :     1000.07 (g/l)
# Number of solvent molecules:   3799
#
# Processing topology
# Adding line for 3799 solvent molecules with resname (SOL) to topology file (topol.top)
#
# Back Off! I just backed up topol.top to ./#topol.top.1#
#
# GROMACS reminds you: "Kick the Dog and You Will Die" (Magnapop)

# %% [markdown]
# #### Add ions

# %% [markdown]
# ## Remove PBC and See dodecahedron
# select `0(System)` for output group

# %%
# !echo "0" | gmx trjconv -s {jobname}_water.pdb -f {jobname}_water.pdb -o {jobname}_water.dode.pdb -pbc res -ur compact
# Out:
#                      :-) GROMACS - gmx trjconv, 2023.2 (-:
#
# Executable:   /home/user/opt/gromacs-2023/bin/gmx
# Data prefix:  /home/user/opt/gromacs-2023
# Working dir:  /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/c.gromacs.run_md/1.create_system
# Command line:
#   gmx trjconv -s 2jpz_EWV_water.pdb -f 2jpz_EWV_water.pdb -o 2jpz_EWV_water.dode.pdb -pbc res -ur compact
#
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Will write pdb: Protein data bank file
#
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
#
# WARNING: If there are molecules in the input trajectory file
#          that are broken across periodic boundaries, they
#          cannot be made whole (or treated as whole) without
#          you providing a run input file.
#
# Select group for output
# Group     0 (         System) has 12285 elements
# Group     1 (            DNA) has   843 elements
# Group     2 (              K) has     2 elements
# Group     3 (            EWV) has    43 elements
# Group     4 (            Ion) has     2 elements
# Group     5 (          Water) has 11397 elements
# Group     6 (            SOL) has 11397 elements
# Group     7 (      non-Water) has   888 elements
# Group     8 ( Water_and_ions) has 11399 elements
# Select a group: Selected 0: 'System'
# Reading frame       0 time    0.000
# Precision of 2jpz_EWV_water.pdb is 0.0001 (nm)
#  '', 12285 atoms
# Last frame          0 time    0.000
#  ->  frame      0 time    0.000
# Last written: frame      0 time    0.000
#
#
# GROMACS reminds you: "Kick the Dog and You Will Die" (Magnapop)

# %%
## visualize
# !pymol {jobname}_water.dode.pdb

# %% [markdown]
# ### Add ions
# gmx genion ~
# `-conc` unit: (mol/liters) default=0.125
# sele `5(SOL)` for group of solvent molecules

# %%
# !gmx grompp -f {mdp_folder}/ions.mdp -c {jobname}_water.pdb -p topol.top -o ions.tpr
# Out:
#                       :-) GROMACS - gmx grompp, 2023.2 (-:
#
# Executable:   /home/user/opt/gromacs-2023/bin/gmx
# Data prefix:  /home/user/opt/gromacs-2023
# Working dir:  /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/c.gromacs.run_md/1.create_system
# Command line:
#   gmx grompp -f /home/user/workfolder/g4dna_protocol_demo/smsl/opt/mdp/ions.mdp -c 2jpz_EWV_water.pdb -p topol.top -o ions.tpr
#
# Ignoring obsolete mdp entry 'ns_type'
#
# NOTE 1 [file /home/user/workfolder/g4dna_protocol_demo/smsl/opt/mdp/ions.mdp]:
#   With Verlet lists the optimal nstlist is >= 10, with GPUs >= 20. Note
#   that with the Verlet scheme, nstlist has no effect on the accuracy of
#   your simulation.
#
# Setting the LD random seed to -6562310
#
# Generated 4851 of the 4851 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 0.5
#
# Generated 4851 of the 4851 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'DNA'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'EWV'
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# NOTE 2 [file topol.top, line 63]:
#   System has non-zero total charge: -22.000000
#   Total charge should normally be an integer. See
#   http://www.gromacs.org/Documentation/Floating_Point_Arithmetic
#   for discussion on how close it should be to an integer.
#
#
#
#
# NOTE 3 [file topol.top, line 63]:
#   In moleculetype 'Ion2' 2 atoms are not bound by a potential or constraint
#   to any other atom in the same moleculetype. Although technically this
#   might not cause issues in a simulation, this often means that the user
#   forgot to add a bond/potential/constraint or put multiple molecules in
#   the same moleculetype definition by mistake. Run with -v to get
#   information for each atom.
#
# Analysing residue names:
# There are:    26        DNA residues
# There are:     2        Ion residues
# There are:     1      Other residues
# There are:  3799      Water residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
# Number of degrees of freedom in T-Coupling group rest is 25455.00
# The integrator does not provide a ensemble temperature, there is no system ensemble temperature
#
# NOTE 4 [file /home/user/workfolder/g4dna_protocol_demo/smsl/opt/mdp/ions.mdp]:
#   You are using a plain Coulomb cut-off, which might produce artifacts.
#   You might want to consider using PME electrostatics.
#
#
#
# This run will generate roughly 1 Mb of data
#
# There were 4 NOTEs
#
# GROMACS reminds you: "Kick the Dog and You Will Die" (Magnapop)

# %%
# !echo "SOL" | gmx genion -s ions.tpr -o {jobname}_solv.pdb -p topol.top -pname K -nname CL -neutral -conc 0.125
# Out:
#                       :-) GROMACS - gmx genion, 2023.2 (-:
#
# Executable:   /home/user/opt/gromacs-2023/bin/gmx
# Data prefix:  /home/user/opt/gromacs-2023
# Working dir:  /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/c.gromacs.run_md/1.create_system
# Command line:
#   gmx genion -s ions.tpr -o 2jpz_EWV_solv.pdb -p topol.top -pname K -nname CL -neutral -conc 0.125
#
# Reading file ions.tpr, VERSION 2023.2 (single precision)
# Reading file ions.tpr, VERSION 2023.2 (single precision)
# Will try to add 32 K ions and 10 CL ions.
# Select a continuous group of solvent molecules
# Group     0 (         System) has 12285 elements
# Group     1 (            DNA) has   843 elements
# Group     2 (              K) has     2 elements
# Group     3 (            EWV) has    43 elements
# Group     4 (            Ion) has     2 elements
# Group     5 (          Water) has 11397 elements
# Group     6 (            SOL) has 11397 elements
# Group     7 (      non-Water) has   888 elements
# Group     8 ( Water_and_ions) has 11399 elements
# Select a group: Selected 6: 'SOL'
# Number of (3-atomic) solvent molecules: 3799
#
# Processing topology
# Replacing 42 solute molecules in topology file (topol.top)  by 32 K and 10 CL ions.
#
# Back Off! I just backed up topol.top to ./#topol.top.2#
# Using random seed 2138955174.
# Replacing solvent molecule 2640 (atom 8808) with K
# Replacing solvent molecule 966 (atom 3786) with K
# Replacing solvent molecule 1699 (atom 5985) with K
# Replacing solvent molecule 1897 (atom 6579) with K
# Replacing solvent molecule 3032 (atom 9984) with K
# Replacing solvent molecule 745 (atom 3123) with K
# Replacing solvent molecule 1287 (atom 4749) with K
# Replacing solvent molecule 99 (atom 1185) with K
# Replacing solvent molecule 2487 (atom 8349) with K
# Replacing solvent molecule 914 (atom 3630) with K
# Replacing solvent molecule 3337 (atom 10899) with K
# Replacing solvent molecule 2653 (atom 8847) with K
# Replacing solvent molecule 1260 (atom 4668) with K
# Replacing solvent molecule 1730 (atom 6078) with K
# Replacing solvent molecule 2231 (atom 7581) with K
# Replacing solvent molecule 2279 (atom 7725) with K
# Replacing solvent molecule 1159 (atom 4365) with K
# Replacing solvent molecule 1903 (atom 6597) with K
# Replacing solvent molecule 2823 (atom 9357) with K
# Replacing solvent molecule 384 (atom 2040) with K
# Replacing solvent molecule 2888 (atom 9552) with K
# Replacing solvent molecule 356 (atom 1956) with K
# Replacing solvent molecule 2697 (atom 8979) with K
# Replacing solvent molecule 1375 (atom 5013) with K
# Replacing solvent molecule 2855 (atom 9453) with K
# Replacing solvent molecule 64 (atom 1080) with K
# Replacing solvent molecule 1202 (atom 4494) with K
# Replacing solvent molecule 3102 (atom 10194) with K
# Replacing solvent molecule 2800 (atom 9288) with K
# Replacing solvent molecule 746 (atom 3126) with K
# Replacing solvent molecule 1222 (atom 4554) with K
# Replacing solvent molecule 943 (atom 3717) with K
# Replacing solvent molecule 416 (atom 2136) with CL
# Replacing solvent molecule 1550 (atom 5538) with CL
# Replacing solvent molecule 3502 (atom 11394) with CL
# Replacing solvent molecule 2700 (atom 8988) with CL
# Replacing solvent molecule 135 (atom 1293) with CL
# Replacing solvent molecule 3238 (atom 10602) with CL
# Replacing solvent molecule 1126 (atom 4266) with CL
# Replacing solvent molecule 1392 (atom 5064) with CL
# Replacing solvent molecule 30 (atom 978) with CL
# Replacing solvent molecule 964 (atom 3780) with CL
#
#
# GROMACS reminds you: "The biggest lie in science is 'data and code available upon request'" (Michael Eisen)

# %%
## rmpbc and visualize
## check System has 12200±1 elements
# !echo "0" | gmx trjconv -s {jobname}_solv.pdb -f {jobname}_solv.pdb -o {jobname}_solv.dode.pdb -pbc res -ur compact
#!pymol {jobname}_ions.dode.pdb
# Out:
#                      :-) GROMACS - gmx trjconv, 2023.2 (-:
#
# Executable:   /home/user/opt/gromacs-2023/bin/gmx
# Data prefix:  /home/user/opt/gromacs-2023
# Working dir:  /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/c.gromacs.run_md/1.create_system
# Command line:
#   gmx trjconv -s 2jpz_EWV_solv.pdb -f 2jpz_EWV_solv.pdb -o 2jpz_EWV_solv.dode.pdb -pbc res -ur compact
#
# Note that major changes are planned in future for trjconv, to improve usability and utility.
# Will write pdb: Protein data bank file
#
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
#
# WARNING: If there are molecules in the input trajectory file
#          that are broken across periodic boundaries, they
#          cannot be made whole (or treated as whole) without
#          you providing a run input file.
#
# Select group for output
# Group     0 (         System) has 12201 elements
# Group     1 (            DNA) has   843 elements
# Group     2 (              K) has    34 elements
# Group     3 (            EWV) has    43 elements
# Group     4 (             CL) has    10 elements
# Group     5 (            Ion) has    44 elements
# Group     6 (          Water) has 11271 elements
# Group     7 (            SOL) has 11271 elements
# Group     8 (      non-Water) has   930 elements
# Group     9 ( Water_and_ions) has 11315 elements
# Select a group: Selected 0: 'System'
# Reading frame       0 time    0.000
# Precision of 2jpz_EWV_solv.pdb is 0.0001 (nm)
#  '', 12201 atoms
# Last frame          0 time    0.000
#  ->  frame      0 time    0.000
# Last written: frame      0 time    0.000
#
#
# GROMACS reminds you: "The biggest lie in science is 'data and code available upon request'" (Michael Eisen)

# %% [markdown]
# ### Energy Minimization

# %%
# !gmx grompp -f {mdp_folder}/min1.mdp -c {jobname}_solv.pdb -r {jobname}_solv.pdb -p topol.top -o min1.tpr
# !gmx mdrun -deffnm min1 -c min1.pdb
# Out:
#                       :-) GROMACS - gmx grompp, 2023.2 (-:
#
# Executable:   /home/user/opt/gromacs-2023/bin/gmx
# Data prefix:  /home/user/opt/gromacs-2023
# Working dir:  /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/c.gromacs.run_md/1.create_system
# Command line:
#   gmx grompp -f /home/user/workfolder/g4dna_protocol_demo/smsl/opt/mdp/min1.mdp -c 2jpz_EWV_solv.pdb -r 2jpz_EWV_solv.pdb -p topol.top -o min1.tpr
#
# Setting the LD random seed to -16319688
#
# Generated 4851 of the 4851 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 0.5
#
# Generated 4851 of the 4851 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'DNA'
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# Excluding 3 bonded neighbours molecule type 'EWV'
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# Excluding 1 bonded neighbours molecule type 'K'
#
# Excluding 1 bonded neighbours molecule type 'CL'
#
# NOTE 1 [file topol.top, line 65]:
#   In moleculetype 'Ion2' 2 atoms are not bound by a potential or constraint
#   to any other atom in the same moleculetype. Although technically this
#   might not cause issues in a simulation, this often means that the user
#   forgot to add a bond/potential/constraint or put multiple molecules in
#   the same moleculetype definition by mistake. Run with -v to get
#   information for each atom.
#
# Analysing residue names:
# There are:    26        DNA residues
# There are:    44        Ion residues
# There are:     1      Other residues
# There are:  3757      Water residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
# Number of degrees of freedom in T-Coupling group rest is 25329.00
# The integrator does not provide a ensemble temperature, there is no system ensemble temperature
#
# The largest distance between excluded atoms is 0.417 nm between atom 389 and 396
#
# NOTE 2 [file /home/user/workfolder/g4dna_protocol_demo/smsl/opt/mdp/min1.mdp]:
#   Removing center of mass motion in the presence of position restraints
#   might cause artifacts. When you are using position restraints to
#   equilibrate a macro-molecule, the artifacts are usually negligible.
#
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 48x48x48, spacing 0.118 0.118 0.118
#
# Estimate for the relative computational load of the PME mesh part: 0.19
#
# This run will generate roughly 1 Mb of data
#
# There were 2 NOTEs
#
# GROMACS reminds you: "The biggest lie in science is 'data and code available upon request'" (Michael Eisen)
#
#                       :-) GROMACS - gmx mdrun, 2023.2 (-:
#
# Executable:   /home/user/opt/gromacs-2023/bin/gmx
# Data prefix:  /home/user/opt/gromacs-2023
# Working dir:  /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/c.gromacs.run_md/1.create_system
# Command line:
#   gmx mdrun -deffnm min1 -c min1.pdb
#
# Reading file min1.tpr, VERSION 2023.2 (single precision)
# 1 GPU selected for this run.
# Mapping of GPU IDs to the 1 GPU task in the 1 rank on this node:
#   PP:0
# PP tasks will do (non-perturbed) short-ranged interactions on the GPU
# PP task will update and constrain coordinates on the CPU
# Using 1 MPI thread
# Using 12 OpenMP threads
#
#
# Steepest Descents:
#    Tolerance (Fmax)   =  1.00000e+03
#    Number of steps    =         5000
#
# writing lowest energy coordinates.
#
# Steepest Descents converged to Fmax < 1000 in 221 steps
# Potential Energy  = -1.9477792e+05
# Maximum force     =  8.5489392e+02 on atom 697
# Norm of force     =  5.9214136e+01
#
# GROMACS reminds you: "Rat-tat-tat Ka boom boom" (The Smashing Pumpkins)

# %%
## -r argument min1.pdb or {jobname}_solv.pdb
# !gmx grompp -f {mdp_folder}/min2.mdp -c min1.pdb -r {jobname}_solv.pdb -p topol.top -o min2.tpr
# !gmx mdrun -deffnm min2 -c min2.pdb
# Out:
#                       :-) GROMACS - gmx grompp, 2023.2 (-:
#
# Executable:   /home/user/opt/gromacs-2023/bin/gmx
# Data prefix:  /home/user/opt/gromacs-2023
# Working dir:  /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/c.gromacs.run_md/1.create_system
# Command line:
#   gmx grompp -f /home/user/workfolder/g4dna_protocol_demo/smsl/opt/mdp/min2.mdp -c min1.pdb -r 2jpz_EWV_solv.pdb -p topol.top -o min2.tpr
#
#
# NOTE 1 [file /home/user/workfolder/g4dna_protocol_demo/smsl/opt/mdp/min2.mdp]:
#   With Verlet lists the optimal nstlist is >= 10, with GPUs >= 20. Note
#   that with the Verlet scheme, nstlist has no effect on the accuracy of
#   your simulation.
#
# Setting the LD random seed to -1644331283
#
# Generated 4851 of the 4851 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 0.5
#
# Generated 4851 of the 4851 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'DNA'
#
# turning H bonds into constraints...
#
# Excluding 3 bonded neighbours molecule type 'Ion2'
#
# turning H bonds into constraints...
#
# Excluding 3 bonded neighbours molecule type 'EWV'
#
# turning H bonds into constraints...
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# turning H bonds into constraints...
#
# Excluding 1 bonded neighbours molecule type 'K'
#
# turning H bonds into constraints...
#
# Excluding 1 bonded neighbours molecule type 'CL'
#
# turning H bonds into constraints...
#
# NOTE 2 [file topol.top, line 65]:
#   In moleculetype 'Ion2' 2 atoms are not bound by a potential or constraint
#   to any other atom in the same moleculetype. Although technically this
#   might not cause issues in a simulation, this often means that the user
#   forgot to add a bond/potential/constraint or put multiple molecules in
#   the same moleculetype definition by mistake. Run with -v to get
#   information for each atom.
#
# Analysing residue names:
# There are:    26        DNA residues
# There are:    44        Ion residues
# There are:     1      Other residues
# There are:  3757      Water residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
# Number of degrees of freedom in T-Coupling group rest is 25013.00
# The integrator does not provide a ensemble temperature, there is no system ensemble temperature
#
# The largest distance between excluded atoms is 0.410 nm between atom 396 and 421
#
# NOTE 3 [file /home/user/workfolder/g4dna_protocol_demo/smsl/opt/mdp/min2.mdp]:
#   Removing center of mass motion in the presence of position restraints
#   might cause artifacts. When you are using position restraints to
#   equilibrate a macro-molecule, the artifacts are usually negligible.
#
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 36x36x36, spacing 0.157 0.157 0.157
#
# Estimate for the relative computational load of the PME mesh part: 0.17
#
# This run will generate roughly 1 Mb of data
#
# There were 3 NOTEs
#
# GROMACS reminds you: "Rat-tat-tat Ka boom boom" (The Smashing Pumpkins)
#
#                       :-) GROMACS - gmx mdrun, 2023.2 (-:
#
# Executable:   /home/user/opt/gromacs-2023/bin/gmx
# Data prefix:  /home/user/opt/gromacs-2023
# Working dir:  /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/c.gromacs.run_md/1.create_system
# Command line:
#   gmx mdrun -deffnm min2 -c min2.pdb
#
# Reading file min2.tpr, VERSION 2023.2 (single precision)
# Update groups can not be used for this system because atoms that are (in)directly constrained together are interdispersed with other atoms
#
# 1 GPU selected for this run.
# Mapping of GPU IDs to the 1 GPU task in the 1 rank on this node:
#   PP:0
# PP tasks will do (non-perturbed) short-ranged interactions on the GPU
# PP task will update and constrain coordinates on the CPU
# Using 1 MPI thread
# Using 12 OpenMP threads
#
#
# Steepest Descents:
#    Tolerance (Fmax)   =  1.00000e+02
#    Number of steps    =        50000
#
# writing lowest energy coordinates.
#
# Steepest Descents converged to Fmax < 100 in 2979 steps
# Potential Energy  = -2.1602681e+05
# Maximum force     =  9.9417931e+01 on atom 5658
# Norm of force     =  9.8885185e+00
#
# GROMACS reminds you: "Somewhere, something incredible is waiting to be known." (Carl Sagan)

# %% [markdown]
# ## Make Index File

# %%
pdbAtom = !grep "ATOM" {pdbid}.gro.pdb
n_atom = len(pdbAtom)

# %%
cmd = f'''\
a 1-{n_atom}
name 10 Model
q
'''
# !echo -e "{cmd}" | gmx make_ndx -f min2.pdb -o {jobname}.simulate.ndx
# Out:
#                      :-) GROMACS - gmx make_ndx, 2023.2 (-:
#
# Executable:   /home/user/opt/gromacs-2023/bin/gmx
# Data prefix:  /home/user/opt/gromacs-2023
# Working dir:  /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/c.gromacs.run_md/1.create_system
# Command line:
#   gmx make_ndx -f min2.pdb -o 2jpz_EWV.simulate.ndx
#
#
# Reading structure file
# Going to read 0 old index file(s)
# Analysing residue names:
# There are:    26        DNA residues
# There are:    44        Ion residues
# There are:     1      Other residues
# There are:  3757      Water residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
#   0 System              : 12201 atoms
#   1 DNA                 :   843 atoms
#   2 K                   :    34 atoms
#   3 EWV                 :    43 atoms
#   4 CL                  :    10 atoms
#   5 Ion                 :    44 atoms
#   6 Water               : 11271 atoms
#   7 SOL                 : 11271 atoms
#   8 non-Water           :   930 atoms
#   9 Water_and_ions      : 11315 atoms
#
#  nr : group      '!': not  'name' nr name   'splitch' nr    Enter: list groups
#  'a': atom       '&': and  'del' nr         'splitres' nr   'l': list residues
#  't': atom type  '|': or   'keep' nr        'splitat' nr    'h': help
#  'r': residue              'res' nr         'chain' char
#  "name": group             'case': case sensitive           'q': save and quit
#  'ri': residue index
#
# >
# Found 845 atoms in range 1-845
#
# >
#
# >
#
# GROMACS reminds you: "Somewhere, something incredible is waiting to be known." (Carl Sagan)

# %% [markdown]
# ### Equilibrium (generate [1.3_equilibrium.slurm](1.3_equilibrium.slurm))
# (In the energy minimization process, the only parameter required is the initial structure. However, for NVT or NPT processes, since the .pdb file does not contain information about speed or temperature state, an additional parameter, "-t", must be included to provide this information.)

# %%
slurm_script = f'''\
#!/bin/bash
#SBATCH --partition=gpu                  # Define the partition on which the job shall run
#SBATCH --job-name={jobname}                  # Job name
#SBATCH --ntasks=1                       # Total number of tasks
#SBATCH --nodes=1                        # Number of nodes on which to run
#SBATCH --cpus-per-task=20               # Threads per task
#SBATCH --gres=gpu:2                     # number of GPUs per node (gres=gpu:N)
#SBATCH --mem=50000                      # Memory per job in MB
#SBATCH --time=0-999:00:00               # Time limit ( dd-hh:mm:ss ) ← e.g. Maximum run time: 1 hour
#SBATCH --time=0-999:00:00               # Time limit ( dd-hh:mm:ss ) ← e.g. Maximum run time: 1 hour
#SBATCH --output=slurm_simulation_%j.out       # Standard output log
#SBATCH --error=slurm_simulation_%j.out        # Standard error log

  echo "Start at `date`"
  echo "Running on hosts: $SLURM_NODELIST"
  echo "Running on $SLURM_NNODES nodes."
  echo "Running $SLURM_NTASKS tasks."
  echo "Using ${{SLURM_CPUS_PER_TASK}} cpus per task"
  echo "Job id is $SLURM_JOBID"
  echo "Current working directory is `pwd`"

mdpFolder="{mdp_folder}"
mdFolder="."

## load program
export PATH=$HOME/opt/gcc-10.4.0/bin:$PATH
export LD_LIBRARY_PATH=$HOME/opt/gcc-10.4.0/lib64
source $HOME/opt/gromacs-2023/bin/GMXRC

cd ${{mdFolder}}
## HEAT
gmx grompp -f ${{mdpFolder}}/heat.mdp -c min2.pdb -r {jobname}_solv.pdb -p topol.top -o heat.tpr
gmx mdrun -deffnm heat -c heat.pdb -ntmpi 4 -nb gpu -pme gpu -npme 1 -gputasks 0011 -ntomp 6
## NVT
gmx grompp -f ${{mdpFolder}}/nvt1.mdp -c heat.pdb -r {jobname}_solv.pdb -t heat.cpt -p topol.top -o nvt1.tpr
gmx mdrun -deffnm nvt1 -c nvt1.pdb -ntmpi 4 -nb gpu -pme gpu -npme 1 -gputasks 0011 -ntomp 6
## NPT1
gmx grompp -f ${{mdpFolder}}/npt1.mdp -c nvt1.pdb -r {jobname}_solv.pdb -t nvt1.cpt -p topol.top -o npt1.tpr
gmx mdrun -deffnm npt1 -c npt1.pdb -ntmpi 4 -nb gpu -pme gpu -npme 1 -gputasks 0011 -ntomp 6
## NPT2
gmx grompp -f ${{mdpFolder}}/npt2.mdp -c npt1.pdb -r {jobname}_solv.pdb -t npt1.cpt -p topol.top -o npt2.tpr
gmx mdrun -deffnm npt2 -c npt2.pdb -ntmpi 4 -nb gpu -pme gpu -npme 1 -gputasks 0011 -ntomp 6
'''

open("1.3_equilibrium.slurm", 'w').write(slurm_script)
# Out:
# 2182

# %% [markdown]
# #### Running slurm command:
# ```
# > sbatch 1.3_equilibrium.slurm
# ```

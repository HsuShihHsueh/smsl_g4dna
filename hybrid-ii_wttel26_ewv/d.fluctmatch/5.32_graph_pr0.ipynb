# %%
import sys
sys.path.append("../../smsl")

# %%
from smsl.graphBigtraj import BigTrajGraphAgent
from smsl.graph import PR0

import warnings; warnings.filterwarnings("ignore")
import numpy as np

# %%
## 見論文表B.7
n_mode=90         ## $\alpha_c$
vlv_threshold=0.2 ## $\nu_{\text{c}}$
pe_threshold=0.5  ## $\kappa_{\text{c}}$

# %%
b_agent = BigTrajGraphAgent(PR0)
# Out:
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/0000_0500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/0250_0750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/0500_1000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/0750_1250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/1000_1500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/1250_1750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/1500_2000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/1750_2250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/2000_2500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/2250_2750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/2500_3000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/2750_3250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/3000_3500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/3250_3750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/3500_4000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/3750_4250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/4000_4500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/4250_4750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/4500_5000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/pairtypes_k_b0_cutoff_5.00.csv

# %%
b_agent.spectral_decomposition()
b_agent.set_mean_r_alpha_array()
b_agent.t_agent.mean.GetEigenvectorEigenvectorT()
# Out:
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.

# %%
## 論文 圖5.24(B)
b_agent.plot_prominent_modes_and_identify_atom_with_interactive(strandid=None)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=283, min=1), Output()), _dom_classes=('w…

# %%
b_agent.plot_prominent_modes_and_get_identify_pair_with_interactive(\
        strandid=None, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, filter=True)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=283, min=1), Output()), _dom_classes=('w…

# %%
b_agent.t_agent.mean.get_modes_info(strandid=None, n_mode=n_mode, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, is_return=False)
# Out:
# 100%|██████████| 90/90 [00:00<00:00, 132.77it/s]

# %%
## 論文 圖5.24(C)
b_agent.t_agent.mean.display_df_info_by_resid(save=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#     </tr>
#     <tr>
#       <th>Residue Pair</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>T1</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{36}$=27.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{36}$:<br>C5'C2'(T1T1)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{61}$=20.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{61}$:<br>O4'O3'(T1T1)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{88}$=11.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{88}$:<br>O5'C3'(T1T1)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T2</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{32}$=29.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{32}$:<br>O5'C3'(T2T2)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{42}$=25.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{42}$:<br>O1PC5'(T2T2)<br>C5'C2'(T2T2)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{67}$=18.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{67}$:<br>O4'O3'(T2T2)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A3</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{25}$=33.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{25}$:<br>C5'C2'(A3A3)<br>O5'C2'(A3A3)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{48}$=22.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{48}$:<br>O4'O3'(A3A3)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{81}$=13.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{81}$:<br>O1PC4'(A3A3)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G4</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{33}$=28.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{33}$:<br>C1'O3'(G4G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{40}$=26.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{40}$:<br>O5'O4'(G4G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{89}$=10.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{89}$:<br>C5'C2'(G4G4)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G5</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{7}$=43.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{7}$:<br>O1PC5'(G5G5)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{17}$=37.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{17}$:<br>O5'O4'(G5G5)<br>O5'C3'(G5G5)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{60}$=20.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{60}$:<br>O4'O3'(G5G5)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{87}$=11.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{87}$:<br>C1'O3'(G5G5)</td>
#     </tr>
#     <tr>
#       <th>G6</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{2}$=50.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{2}$:<br>O1PC5'(G6G6)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{35}$=27.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{35}$:<br>PC4'(G6G6)<br>PC3'(G6G6)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{44}$=25.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{44}$:<br>O5'O4'(G6G6)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T7</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{50}$=22.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{50}$:<br>O5'C3'(T7T7)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{59}$=20.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{59}$:<br>C5'C2'(T7T7)<br>C5'C1'(T7T7)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{85}$=12.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{85}$:<br>O4'O3'(T7T7)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T8</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{30}$=31.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{30}$:<br>O5'C3'(T8T8)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{34}$=28.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{34}$:<br>C5'C2'(T8T8)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{57}$=21.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{57}$:<br>C1'O3'(T8T8)<br>O4'O3'(T8T8)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A9</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{10}$=40.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{10}$:<br>O5'O4'(A9A9)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{13}$=39.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{13}$:<br>O1PC5'(A9A9)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{52}$=22.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{52}$:<br>O4'O3'(A9A9)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{80}$=13.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{80}$:<br>C1'O3'(A9A9)</td>
#     </tr>
#     <tr>
#       <th>G10</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{21}$=36.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{21}$:<br>C1'O3'(G10G10)<br>C5'C1'(G10G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{38}$=27.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{38}$:<br>O4'O3'(G10G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{74}$=14.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{74}$:<br>O2PC4'(G10G10)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G11</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{79}$=13.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{79}$:<br>O5'O3'(G11G11)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G12</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{6}$=43.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{6}$:<br>O1PC5'(G12G12)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{16}$=37.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{16}$:<br>O5'O4'(G12G12)<br>O4'O3'(G12G12)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{51}$=22.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{51}$:<br>O5'C3'(G12G12)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T13</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{1}$=60.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{1}$:<br>C5'C2'(T13T13)<br>O1PC5'(T13T13)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{22}$=36.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{22}$:<br>C1'O3'(T13T13)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{29}$=32.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{29}$:<br>O5'C3'(T13T13)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T14</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{3}$=47.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{3}$:<br>C5'C2'(T14T14)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{43}$=25.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{43}$:<br>C1'O3'(T14T14)<br>O4'O3'(T14T14)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{70}$=15.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{70}$:<br>O5'O4'(T14T14)<br>O5'C3'(T14T14)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G16</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{47}$=22.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{47}$:<br>C1'O3'(G16G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{69}$=16.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{69}$:<br>C5'C2'(G16G16)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G17</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{9}$=42.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{9}$:<br>O1PC5'(G17G17)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{19}$=37.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{19}$:<br>O5'O4'(G17G17)<br>O5'C3'(G17G17)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{62}$=20.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{62}$:<br>O4'O3'(G17G17)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G18</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{12}$=39.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{12}$:<br>C5'C2'(G18G18)<br>O1PC5'(G18G18)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{27}$=33.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{27}$:<br>O5'O4'(G18G18)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{56}$=21.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{56}$:<br>C1'O3'(G18G18)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{86}$=12.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{86}$:<br>O5'C1'(G18G18)</td>
#     </tr>
#     <tr>
#       <th>T19</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{45}$=24.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{45}$:<br>O1PC5'(T19T19)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{65}$=18.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{65}$:<br>C1'O3'(T19T19)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T20</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{4}$=47.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{4}$:<br>O1PC5'(T20T20)<br>C5'C2'(T20T20)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{53}$=21.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{53}$:<br>O4'O3'(T20T20)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A21</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{31}$=30.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{31}$:<br>C5'C2'(A21A21)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{41}$=25.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{41}$:<br>O5'C3'(A21A21)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{49}$=22.9, ${\{\rm{a}_i\rm{a}_
# Write /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/hybrid-ii_ewv_PR0.csv

# %%
b_agent.t_agent.mean.df_m.sort_values(by='k', ascending=False)
# Out:
#        Enm_i Strand_i  Resid_i Atomname_i  Atomid_i Enm_j Strand_j  Resid_j  \
# PairID
# 2623    A104  STRAND1        6        O1P       104  A107  STRAND1        6
# 6303    A276  STRAND1       14        C5'       276  A290  STRAND1       14
# 7480    A336  STRAND1       17        O1P       336  A339  STRAND1       17
# 9643    A463  STRAND1       23        O1P       463  A466  STRAND1       23
# 2084     A82  STRAND1        5        O1P        82   A85  STRAND1        5
# ...      ...      ...      ...        ...       ...   ...      ...      ...
# 8979    A421  STRAND1       21        O2P       421  A438  STRAND1       21
# 8984    A422  STRAND1       21        O5'       422  A426  STRAND1       21
# 6260    A272  STRAND1       14          P       272  A277  STRAND1       14
# 8991    A422  STRAND1       21        O5'       422  A438  STRAND1       21
# 7481    A336  STRAND1       17        O1P       336  A340  STRAND1       17
#
#        Atomname_j  Atomid_j          k        b0 Category
# PairID
# 2623          C5'       107  22.127063  2.934495      pr0
# 6303          C2'       290  20.536184  3.239642      pr0
# 7480          C5'       339  19.099105  2.972468      pr0
# 9643          C5'       466  19.077947  2.962889      pr0
# 2084          C5'        85  18.833116  2.973447      pr0
# ...           ...       ...        ...       ...      ...
# 8979          C2'       438   0.000000  6.075789      pr0
# 8984          C1'       426   0.000000  4.165232      pr0
# 6260          C4'       277   0.000000  3.977574      pr0
# 8991          C2'       438   0.000000  3.752447      pr0
# 7481          C4'       340   0.000000  4.441889      pr0
#
# [596 rows x 13 columns]

# %%
import sys
sys.path.append("../../smsl")

# %%
from smsl.graphBigtraj import BigTrajGraphAgent
from smsl.graph import RB

import warnings; warnings.filterwarnings("ignore")
import numpy as np

# %%
## 見論文表B.7
n_mode=45         ## $\alpha_c$
vlv_threshold=0.2 ## $\nu_{\text{c}}$
pe_threshold=0.55 ## $\kappa_{\text{c}}$

# %%
b_agent = BigTrajGraphAgent(RB)
# Out:
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/0000_0500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/0250_0750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/0500_1000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/0750_1250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/1000_1500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/1250_1750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/1500_2000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/1750_2250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/2000_2500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/2250_2750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/2500_3000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/2750_3250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/3000_3500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/3250_3750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/3500_4000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/3750_4250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/4000_4500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/4250_4750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/4500_5000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/pairtypes_k_b0_cutoff_5.00.csv

# %%
b_agent.spectral_decomposition()
b_agent.set_mean_r_alpha_array()
b_agent.t_agent.mean.GetEigenvectorEigenvectorT()
# Out:
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 545 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.

# %%
## 論文 圖5.23(A)
b_agent.plot_prominent_modes_and_identify_atom_with_interactive(strandid=None)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=545, min=1), Output()), _dom_classes=('w…

# %%
b_agent.plot_prominent_modes_and_get_identify_pair_with_interactive(\
        strandid=None, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, filter=True)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=545, min=1), Output()), _dom_classes=('w…

# %%
b_agent.t_agent.mean.get_modes_info(strandid=None, n_mode=n_mode, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, is_return=False)
# Out:
# 100%|██████████| 45/45 [00:01<00:00, 40.87it/s]

# %%
## 論文 圖5.23(C)
b_agent.t_agent.mean.display_df_info_by_resid(save=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#     <tr>
#       <th>Residue Pair</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>T1</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{17}$=71.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{17}$:<br>C6C2'(T1T1)<br>C5C2'(T1T1)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{22}$=65.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{22}$:<br>C1'O2(T1T1)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T2</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{1}$=103.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{1}$:<br>C6C2'(T2T2)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{25}$=64.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{25}$:<br>C1'O2(T2T2)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A3</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{18}$=70.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{18}$:<br>C8C2'(A3A3)<br>C4C2'(A3A3)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G4</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{7}$=85.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{7}$:<br>C4C2'(G4G4)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{38}$=56.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{38}$:<br>C1'N3(G4G4)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G5</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{16}$=71.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{16}$:<br>C8C2'(G5G5)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T7</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{11}$=79.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{11}$:<br>C6C2'(T7T7)<br>C5C2'(T7T7)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{32}$=60.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{32}$:<br>C1'O2(T7T7)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T8</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{12}$=78.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{12}$:<br>C1'O2(T8T8)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{14}$=77.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{14}$:<br>C6C2'(T8T8)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A9</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{34}$=58.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{34}$:<br>O4'C8(A9A9)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G10</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{5}$=87.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{5}$:<br>C4C2'(G10G10)<br>C8C2'(G10G10)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{29}$=62.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{29}$:<br>C1'N3(G10G10)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G11</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{8}$=85.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{8}$:<br>C4C2'(G11G11)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{43}$=51.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{43}$:<br>C1'N3(G11G11)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G12</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{31}$=61.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{31}$:<br>C8C2'(G12G12)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T13</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{2}$=90.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{2}$:<br>C2C2'(T13T13)<br>C6C2'(T13T13)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{33}$=60.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{33}$:<br>C1'O2(T13T13)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{39}$=55.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{39}$:<br>O4'C6(T13T13)</td>
#     </tr>
#     <tr>
#       <th>T14</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{30}$=62.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{30}$:<br>C1'O2(T14T14)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{37}$=56.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{37}$:<br>O4'C6(T14T14)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A15</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{36}$=56.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{36}$:<br>C1'N3(A15A15)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G16</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{20}$=69.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{20}$:<br>C4C2'(G16G16)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G17</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{28}$=63.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{28}$:<br>C8C2'(G17G17)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G18</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{35}$=58.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{35}$:<br>C8C2'(G18G18)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T19</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{10}$=83.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{10}$:<br>C6C2'(T19T19)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{21}$=69.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{21}$:<br>C1'O2(T19T19)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T20</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{3}$=90.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{3}$:<br>C6C2'(T20T20)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{23}$=65.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{23}$:<br>C1'O2(T20T20)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A21</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{6}$=86.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{6}$:<br>C1'C6(A21A21)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{45}$=50.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{45}$:<br>O4'N7(A21A21)<br>O4'C5(A21A21)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G22</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{4}$=89.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{4}$:<br>C4C2'(G22G22)<br>C8C2'(G22G22)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{27}$=63.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{27}$:<br>O4'C8(G22G22)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{40}$=55.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{40}$:<br>C1'N3(G22G22)</td>
#     </tr>
#     <tr>
#       <th>G24</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{26}$=63.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{26}$:<br>C8C2'(G24G24)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T25</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{9}$=83.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{9}$:<br>C6C2'(T25T25)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{13}$=77.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{13}$:<br>C1'O2(T25T25)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T26</th>
#       <td>$\rm{\lambda}^{\rm{rb}}_{15}$=74.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{15}$:<br>C6C2'(T26T26)<br>O4'C6(T26T26)</td>
#       <td>$\rm{\lambda}^{\rm{rb}}_{24}$=64.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{rb}}_{24}$:<br>C1'O2(T26T26)</td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# Write /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26_ewv/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/hybrid-ii_ewv_RB.csv

# %%
b_agent.t_agent.mean.df_m.sort_values(by='k', ascending=False)
# Out:
#        Enm_i Strand_i  Resid_i Atomname_i  Atomid_i Enm_j Strand_j  Resid_j  \
# PairID
# 3644    A152  STRAND1        8        C1'       152  A161  STRAND1        8
# 682      A27  STRAND1        2         C6        27   A36  STRAND1        2
# 9041    A426  STRAND1       21        C1'       426  A431  STRAND1       21
# 10401   A513  STRAND1       25        C1'       513  A522  STRAND1       25
# 8737    A408  STRAND1       20         C6       408  A417  STRAND1       20
# ...      ...      ...      ...        ...       ...   ...      ...      ...
# 3909    A160  STRAND1        8         C2       160  A527  STRAND1       26
# 3908    A160  STRAND1        8         C2       160  A526  STRAND1       26
# 3907    A160  STRAND1        8         C2       160  A525  STRAND1       25
# 3898    A160  STRAND1        8         C2       160  A512  STRAND1       25
# 4606    A185  STRAND1        9        O3'       185  A204  STRAND1       10
#
#        Atomname_j  Atomid_j          k        b0 Category
# PairID
# 3644           O2       161  36.611021  2.798884       rb
# 682           C2'        36  34.476821  3.032511       rb
# 9041           C6       431  32.532711  4.844832       rb
# 10401          O2       522  32.155695  2.820774       rb
# 8737          C2'       417  31.978837  3.009942       rb
# ...           ...       ...        ...       ...      ...
# 3909          O1P       527   0.000000  4.710295       rb
# 3908            P       526   0.000000  4.894242       rb
# 3907          O3'       525   0.000000  4.183574       rb
# 3898          O4'       512   0.000000  4.736037       rb
# 4606           C4       204   0.000000  5.477505       rb
#
# [2581 rows x 13 columns]

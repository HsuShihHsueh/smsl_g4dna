# %%
import sys
sys.path.append("../../smsl")

# %%
from smsl.graphBigtraj import BigTrajGraphAgent
from smsl.graph import PR0

import warnings; warnings.filterwarnings("ignore")
import numpy as np

# %%
## 見論文表B.7
n_mode=90         ## $\alpha_c$
vlv_threshold=0.2 ## $\nu_{\text{c}}$
pe_threshold=0.5  ## $\kappa_{\text{c}}$

# %%
b_agent = BigTrajGraphAgent(PR0)
# Out:
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26/d.fluctmatch/bigtraj_fluctmatch/0000_0500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26/d.fluctmatch/bigtraj_fluctmatch/0250_0750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26/d.fluctmatch/bigtraj_fluctmatch/0500_1000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26/d.fluctmatch/bigtraj_fluctmatch/0750_1250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26/d.fluctmatch/bigtraj_fluctmatch/1000_1500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26/d.fluctmatch/bigtraj_fluctmatch/1250_1750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26/d.fluctmatch/bigtraj_fluctmatch/1500_2000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26/d.fluctmatch/bigtraj_fluctmatch/1750_2250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26/d.fluctmatch/bigtraj_fluctmatch/2000_2500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26/d.fluctmatch/bigtraj_fluctmatch/2250_2750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26/d.fluctmatch/bigtraj_fluctmatch/2500_3000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26/d.fluctmatch/bigtraj_fluctmatch/2750_3250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26/d.fluctmatch/bigtraj_fluctmatch/3000_3500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26/d.fluctmatch/bigtraj_fluctmatch/3250_3750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26/d.fluctmatch/bigtraj_fluctmatch/3500_4000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26/d.fluctmatch/bigtraj_fluctmatch/3750_4250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26/d.fluctmatch/bigtraj_fluctmatch/4000_4500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26/d.fluctmatch/bigtraj_fluctmatch/4250_4750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26/d.fluctmatch/bigtraj_fluctmatch/4500_5000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/pairtypes_k_b0_cutoff_5.00.csv

# %%
b_agent.spectral_decomposition()
b_agent.set_mean_r_alpha_array()
b_agent.t_agent.mean.GetEigenvectorEigenvectorT()
# Out:
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 283 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.

# %%
## 論文 圖5.24(B)
b_agent.plot_prominent_modes_and_identify_atom_with_interactive(strandid=None)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=283, min=1), Output()), _dom_classes=('w…

# %%
b_agent.plot_prominent_modes_and_get_identify_pair_with_interactive(\
        strandid=None, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, filter=True)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=283, min=1), Output()), _dom_classes=('w…

# %%
b_agent.t_agent.mean.get_modes_info(strandid=None, n_mode=n_mode, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, is_return=False)
# Out:
# 100%|██████████| 90/90 [00:00<00:00, 112.87it/s]

# %%
## 論文 圖5.24(C)
b_agent.t_agent.mean.display_df_info_by_resid(save=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#     </tr>
#     <tr>
#       <th>Residue Pair</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>T1</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{26}$=35.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{26}$:<br>C5'C2'(T1T1)<br>C5'C1'(T1T1)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{54}$=25.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{54}$:<br>O4'O3'(T1T1)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{87}$=13.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{87}$:<br>O5'C3'(T1T1)<br>O5'O4'(T1T1)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T2</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{21}$=36.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{21}$:<br>C5'C2'(T2T2)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{46}$=28.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{46}$:<br>O4'O3'(T2T2)<br>C1'O3'(T2T2)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A3</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{1}$=61.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{1}$:<br>O1PC5'(A3A3)<br>C5'C2'(A3A3)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{12}$=42.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{12}$:<br>O5'O4'(A3A3)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{24}$=35.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{24}$:<br>C1'O3'(A3A3)<br>O5'C2'(A3A3)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G4</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{27}$=35.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{27}$:<br>O5'O4'(G4G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{47}$=27.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{47}$:<br>C5'O3'(G4G4)<br>C5'C1'(G4G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{72}$=18.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{72}$:<br>C5'C2'(G4G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{90}$=12.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{90}$:<br>O2PC3'(G4G4)</td>
#     </tr>
#     <tr>
#       <th>G5</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{15}$=39.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{15}$:<br>O1PC5'(G5G5)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{18}$=38.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{18}$:<br>O5'C3'(G5G5)<br>O5'O4'(G5G5)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G6</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{14}$=39.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{14}$:<br>O4'O3'(G6G6)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{40}$=30.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{40}$:<br>C5'C2'(G6G6)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{56}$=24.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{56}$:<br>O5'O4'(G6G6)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T7</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{2}$=56.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{2}$:<br>C5'C2'(T7T7)<br>O1PC5'(T7T7)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{9}$=43.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{9}$:<br>O4'O3'(T7T7)<br>O5'O4'(T7T7)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{34}$=31.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{34}$:<br>C1'O3'(T7T7)<br>O5'C2'(T7T7)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T8</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{10}$=43.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{10}$:<br>O1PC5'(T8T8)<br>C5'C2'(T8T8)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{33}$=32.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{33}$:<br>O5'C3'(T8T8)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{45}$=28.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{45}$:<br>O4'O3'(T8T8)<br>C1'O3'(T8T8)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A9</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{31}$=33.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{31}$:<br>O5'C3'(A9A9)<br>O5'O4'(A9A9)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{49}$=27.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{49}$:<br>O1PC5'(A9A9)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{75}$=17.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{75}$:<br>C1'O3'(A9A9)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G10</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{6}$=47.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{6}$:<br>O2PC5'(G10G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{28}$=34.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{28}$:<br>O4'O3'(G10G10)<br>C1'O3'(G10G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{66}$=20.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{66}$:<br>O5'O4'(G10G10)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G11</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{51}$=27.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{51}$:<br>O5'C3'(G11G11)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G12</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{11}$=42.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{11}$:<br>O1PC5'(G12G12)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{19}$=37.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{19}$:<br>O5'C3'(G12G12)<br>O5'O4'(G12G12)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{81}$=15.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{81}$:<br>O4'O3'(G12G12)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T13</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{38}$=30.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{38}$:<br>O5'O4'(T13T13)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{65}$=20.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{65}$:<br>O1PC5'(T13T13)<br>O1PC4'(T13T13)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T14</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{16}$=38.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{16}$:<br>C5'C2'(T14T14)<br>C5'C1'(T14T14)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{48}$=27.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{48}$:<br>C1'O3'(T14T14)<br>O4'O3'(T14T14)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{57}$=23.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{57}$:<br>O5'C3'(T14T14)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A15</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{4}$=50.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{4}$:<br>O1PC5'(A15A15)<br>C5'C2'(A15A15)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{37}$=30.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{37}$:<br>C1'O3'(A15A15)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{52}$=26.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{52}$:<br>PC4'(A15A15)<br>O1PC4'(A15A15)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{70}$=19.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{70}$:<br>O5'C3'(A15A15)</td>
#     </tr>
#     <tr>
#       <th>G16</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{29}$=34.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{29}$:<br>O1PC5'(G16G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{32}$=32.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{32}$:<br>O5'O4'(G16G16)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G17</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{8}$=45.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{8}$:<br>O1PC5'(G17G17)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{43}$=29.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{43}$:<br>O5'C3'(G17G17)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G18</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{17}$=38.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{17}$:<br>C5'C2'(G18G18)<br>O1PC5'(G18G18)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{30}$=34.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{30}$:<br>O5'O4'(G18G18)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{62}$=21.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{62}$:<br>C1'O3'(G18G18)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T19</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{20}$=37.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{20}$:<br>C5'O3'(T19T19)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{58}$=23.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{58}$:<br>O5'O4'(T19T19)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{82}$=15.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{82}$:<br>C5'C2'(T19T19)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T20</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{3}$=51.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{3}$:<br>O1PC5'(T20T20)<br>C5'C2'(T20T20)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{13}$=42.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{13}$:<br>O5'O4'(T20T20)<br>O4'O3'(T20T20)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{50}$=27.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{50}$:<br>O5'C2'(T20T20)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A21</th>
#       <td>$\rm{\lambda}^{\rm{pr0
# Write /home/user/workfolder/g4dna_protocol_demo/hybrid-ii_wttel26/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/hybrid-ii_PR0.csv

# %%
b_agent.t_agent.mean.df_m.sort_values(by='k', ascending=False)
# Out:
#        Enm_i Strand_i  Resid_i Atomname_i  Atomid_i Enm_j Strand_j  Resid_j  \
# PairID
# 1084     A39  STRAND1        3        O1P        39   A42  STRAND1        3
# 4182    A188  STRAND1       10        O2P       188  A190  STRAND1       10
# 1927     A82  STRAND1        5        O1P        82   A85  STRAND1        5
# 7628    A400  STRAND1       20        O1P       400  A403  STRAND1       20
# 9078    A507  STRAND1       25        O1P       507  A510  STRAND1       25
# ...      ...      ...      ...        ...       ...   ...      ...      ...
# 6546    A336  STRAND1       17        O1P       336  A354  STRAND1       17
# 6548    A337  STRAND1       17        O2P       337  A339  STRAND1       17
# 6549    A337  STRAND1       17        O2P       337  A340  STRAND1       17
# 2005     A88  STRAND1        5        C1'        88  A102  STRAND1        5
# 9429    A533  STRAND1       26        C1'       533  A545  STRAND1       26
#
#        Atomname_j  Atomid_j          k        b0 Category
# PairID
# 1084          C5'        42  19.298384  2.949689      pr0
# 4182          C5'       190  18.835305  2.925958      pr0
# 1927          C5'        85  18.411168  2.977942      pr0
# 7628          C5'       403  18.061568  2.977579      pr0
# 9078          C5'       510  17.901063  2.979353      pr0
# ...           ...       ...        ...       ...      ...
# 6546          C3'       354   0.000000  4.990416      pr0
# 6548          C5'       339   0.000000  3.816626      pr0
# 6549          C4'       340   0.000000  4.897232      pr0
# 2005          O3'       102   0.000000  2.887326      pr0
# 9429          O3'       545   0.000000  3.037521      pr0
#
# [592 rows x 13 columns]

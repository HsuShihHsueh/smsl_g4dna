# %%
import sys
sys.path.append("../../smsl")

# %%
from smsl.graphBigtraj import BigTrajGraphAgent
from smsl.graph import PR0

import warnings; warnings.filterwarnings("ignore")
import numpy as np

# %%
## 見論文表B.7
n_mode=90         ## $\alpha_c$
vlv_threshold=0.2 ## $\nu_{\text{c}}$
pe_threshold=0.5  ## $\kappa_{\text{c}}$

# %%
b_agent = BigTrajGraphAgent(PR0)
# Out:
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/0000_0500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/0250_0750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/0500_1000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/0750_1250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/1000_1500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/1250_1750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/1500_2000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/1750_2250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/2000_2500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/2250_2750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/2500_3000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/2750_3250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/3000_3500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/3250_3750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/3500_4000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/3750_4250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/4000_4500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/4250_4750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/4500_5000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/pairtypes_k_b0_cutoff_5.00.csv

# %%
b_agent.spectral_decomposition()
b_agent.set_mean_r_alpha_array()
b_agent.t_agent.mean.GetEigenvectorEigenvectorT()
# Out:
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.

# %%
## 論文 圖5.24(B)
b_agent.plot_prominent_modes_and_identify_atom_with_interactive(strandid=None)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=239, min=1), Output()), _dom_classes=('w…

# %%
b_agent.plot_prominent_modes_and_get_identify_pair_with_interactive(\
        strandid=None, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, filter=True)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=239, min=1), Output()), _dom_classes=('w…

# %%
b_agent.t_agent.mean.get_modes_info(strandid=None, n_mode=n_mode, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, is_return=False)
# Out:
# 100%|██████████| 90/90 [00:00<00:00, 120.08it/s]

# %%
## 論文 圖5.24(C)
b_agent.t_agent.mean.display_df_info_by_resid(save=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#     </tr>
#     <tr>
#       <th>Residue Pair</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A1</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{26}$=27.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{26}$:<br>C5'C2'(A1A1)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{42}$=20.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{42}$:<br>O5'C3'(A1A1)<br>O5'O4'(A1A1)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{59}$=15.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{59}$:<br>O4'O3'(A1A1)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G2</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{31}$=24.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{31}$:<br>O1PC5'(G2G2)<br>C5'C1'(G2G2)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{36}$=23.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{36}$:<br>O5'O4'(G2G2)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{74}$=10.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{74}$:<br>O1PC4'(G2G2)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{78}$=9.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{78}$:<br>O2PC3'(G2G2)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G3</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{8}$=38.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{8}$:<br>O1PC5'(G3G3)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{25}$=27.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{25}$:<br>O5'O4'(G3G3)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{52}$=15.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{52}$:<br>PC3'(G3G3)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G4</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{11}$=37.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{11}$:<br>C5'C2'(G4G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{15}$=34.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{15}$:<br>O5'O4'(G4G4)<br>O4'O3'(G4G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{88}$=7.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{88}$:<br>O2PC3'(G4G4)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T5</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{3}$=43.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{3}$:<br>C5'C2'(T5T5)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{23}$=28.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{23}$:<br>O4'O3'(T5T5)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{45}$=20.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{45}$:<br>O5'C3'(T5T5)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T6</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{2}$=45.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{2}$:<br>C5'C2'(T6T6)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{12}$=36.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{12}$:<br>O4'O3'(T6T6)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{35}$=23.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{35}$:<br>O5'C3'(T6T6)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A7</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{1}$=47.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{1}$:<br>O1PC5'(A7A7)<br>C5'C2'(A7A7)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{16}$=33.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{16}$:<br>O4'O3'(A7A7)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{72}$=10.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{72}$:<br>C1'O3'(A7A7)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G8</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{24}$=27.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{24}$:<br>O5'C3'(G8G8)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{46}$=19.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{46}$:<br>O1PC5'(G8G8)<br>C1'O3'(G8G8)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{51}$=15.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{51}$:<br>O1PC5'(G8G8)<br>C1'O3'(G8G8)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G9</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{40}$=20.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{40}$:<br>O5'O4'(G9G9)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{79}$=9.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{79}$:<br>C5'C2'(G9G9)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G10</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{7}$=38.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{7}$:<br>C5'C2'(G10G10)<br>O1PC5'(G10G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{17}$=32.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{17}$:<br>O5'O4'(G10G10)<br>O4'O3'(G10G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{47}$=17.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{47}$:<br>C1'O3'(G10G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{55}$=15.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{55}$:<br>O1PC4'(G10G10)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T11</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{28}$=26.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{28}$:<br>O4'O3'(T11T11)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{41}$=20.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{41}$:<br>O5'O4'(T11T11)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{60}$=14.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{60}$:<br>C1'O3'(T11T11)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T12</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{4}$=43.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{4}$:<br>C5'C2'(T12T12)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{20}$=31.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{20}$:<br>O5'C3'(T12T12)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{32}$=24.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{32}$:<br>O4'O3'(T12T12)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A13</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{10}$=37.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{10}$:<br>O1PC5'(A13A13)<br>C5'C2'(A13A13)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{21}$=30.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{21}$:<br>O5'O4'(A13A13)<br>O5'C3'(A13A13)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{49}$=16.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{49}$:<br>O4'O3'(A13A13)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{76}$=9.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{76}$:<br>C1'O3'(A13A13)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G14</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{29}$=26.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{29}$:<br>O5'C3'(G14G14)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{30}$=25.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{30}$:<br>C5'C1'(G14G14)<br>C5'C2'(G14G14)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{57}$=15.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{57}$:<br>C1'O3'(G14G14)<br>O4'O3'(G14G14)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G15</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{38}$=22.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{38}$:<br>O5'O4'(G15G15)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{87}$=7.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{87}$:<br>C5'C1'(G15G15)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G16</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{9}$=37.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{9}$:<br>C5'C2'(G16G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{19}$=32.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{19}$:<br>O5'O4'(G16G16)<br>O4'O3'(G16G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{48}$=16.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{48}$:<br>C1'O3'(G16G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{65}$=13.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{65}$:<br>O1PC4'(G16G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{89}$=7.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{89}$:<br>O2PC3'(G16G16)</td>
#     </tr>
#     <tr>
#       <th>T17</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{22}$=30.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{22}$:<br>C5'C2'(T17T17)<br>C5'C1'(T17T17)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{34}$=23.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{34}$:<br>O4'O3'(T17T17)<br>O5'O4'(T17T17)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{66}$=12.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{66}$:<br>C1'O3'(T17T17)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T18</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{6}$=38.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{6}$:<br>C5'C2'(T18T18)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{18}$=32.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{18}$:<br>O5'O4'(T18T18)<br>O4'O3'(T18T18)</td>
#       <td>$\rm{\lambda}^{\r
# Write /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/propeller_PR0.csv

# %%
b_agent.t_agent.mean.df_m.sort_values(by='k', ascending=False)
# Out:
#        Enm_i Strand_i  Resid_i Atomname_i  Atomid_i Enm_j Strand_j  Resid_j  \
# PairID
# 2212     A89  STRAND1        5        C5'        89  A103  STRAND1        5
# 5269    A236  STRAND1       12        C5'       236  A250  STRAND1       12
# 8164    A380  STRAND1       19        O1P       380  A383  STRAND1       19
# 1013     A42  STRAND1        3        O1P        42   A45  STRAND1        3
# 2912    A126  STRAND1        7        O1P       126  A129  STRAND1        7
# ...      ...      ...      ...        ...       ...   ...      ...      ...
# 6821    A319  STRAND1       16        O2P       319  A322  STRAND1       16
# 1653     A65  STRAND1        4        O2P        65   A68  STRAND1        4
# 1652     A65  STRAND1        4        O2P        65   A67  STRAND1        4
# 1638     A64  STRAND1        4        O1P        64   A82  STRAND1        4
# 3264    A146  STRAND1        8          P       146  A166  STRAND1        8
#
#        Atomname_j  Atomid_j          k        b0 Category
# PairID
# 2212          C2'       103  17.955195  3.268300      pr0
# 5269          C2'       250  17.919216  3.282695      pr0
# 8164          C5'       383  17.844911  2.982221      pr0
# 1013          C5'        45  17.327837  2.927821      pr0
# 2912          C5'       129  16.869447  2.997100      pr0
# ...           ...       ...        ...       ...      ...
# 6821          C4'       322   0.000000  4.864821      pr0
# 1653          C4'        68   0.000000  4.873700      pr0
# 1652          C5'        67   0.000000  3.781416      pr0
# 1638          C3'        82   0.000000  5.185037      pr0
# 3264          C2'       166   0.000000  5.532537      pr0
#
# [531 rows x 13 columns]

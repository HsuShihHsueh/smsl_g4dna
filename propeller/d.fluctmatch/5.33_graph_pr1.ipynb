# %%
import sys
sys.path.append("../../smsl")

# %%
from smsl.graphBigtraj import BigTrajGraphAgent
from smsl.graph import PR1

import warnings; warnings.filterwarnings("ignore")
import numpy as np

# %%
## 見論文表B.7
n_mode=90         ## $\alpha_c$
vlv_threshold=0.2 ## $\nu_{\text{c}}$
pe_threshold=0.5  ## $\kappa_{\text{c}}$

# %%
b_agent = BigTrajGraphAgent(PR1)
# Out:
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/0000_0500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/0250_0750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/0500_1000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/0750_1250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/1000_1500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/1250_1750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/1500_2000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/1750_2250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/2000_2500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/2250_2750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/2500_3000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/2750_3250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/3000_3500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/3250_3750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/3500_4000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/3750_4250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/4000_4500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/4250_4750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/4500_5000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/pairtypes_k_b0_cutoff_5.00.csv

# %%
b_agent.spectral_decomposition()
b_agent.set_mean_r_alpha_array()
b_agent.t_agent.mean.GetEigenvectorEigenvectorT()
# Out:
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.

# %%
## 論文 圖5.25(B)
b_agent.plot_prominent_modes_and_identify_atom_with_interactive(strandid=None)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=239, min=1), Output()), _dom_classes=('w…

# %%
b_agent.plot_prominent_modes_and_get_identify_pair_with_interactive(\
        strandid=None, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, filter=True)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=239, min=1), Output()), _dom_classes=('w…

# %%
b_agent.t_agent.mean.get_modes_info(strandid=None, n_mode=n_mode, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, is_return=False)
# Out:
# 100%|██████████| 90/90 [00:00<00:00, 143.68it/s]

# %%
## 論文 圖5.25(C)
b_agent.t_agent.mean.display_df_info_by_resid(save=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#     </tr>
#     <tr>
#       <th>Residue Pair</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A1G2</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{27}$=17.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{27}$:<br>O3'C5'(A1G2)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{35}$=14.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{35}$:<br>C3'O2P(A1G2)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{38}$=14.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{38}$:<br>C2'O1P(A1G2)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G2G3</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{6}$=47.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{6}$:<br>C3'O2P(G2G3)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{13}$=30.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{13}$:<br>C2'P(G2G3)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{51}$=10.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{51}$:<br>O3'C5'(G2G3)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G3G4</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{28}$=16.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{28}$:<br>O3'C5'(G3G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{39}$=12.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{39}$:<br>C2'O1P(G3G4)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{55}$=9.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{55}$:<br>O4'O2P(G3G4)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G4T5</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{8}$=36.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{8}$:<br>C3'O1P(G4T5)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{62}$=8.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{62}$:<br>C2'O5'(G4T5)<br>C2'P(G4T5)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{73}$=7.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{73}$:<br>O4'O2P(G4T5)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T5T6</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{18}$=23.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{18}$:<br>C3'O2P(T5T6)<br>C3'O5'(T5T6)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{42}$=11.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{42}$:<br>C2'O1P(T5T6)<br>C2'P(T5T6)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{50}$=10.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{50}$:<br>O3'C5'(T5T6)<br>O3'C4'(T5T6)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T6A7</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{5}$=50.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{5}$:<br>C3'O2P(T6A7)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{9}$=35.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{9}$:<br>C2'O5'(T6A7)<br>C2'P(T6A7)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{21}$=21.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{21}$:<br>O3'C5'(T6A7)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A7G8</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{11}$=32.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{11}$:<br>C3'O2P(A7G8)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{20}$=21.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{20}$:<br>C2'O1P(A7G8)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{37}$=14.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{37}$:<br>C4'O5'(A7G8)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{61}$=8.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{61}$:<br>O3'C5'(A7G8)</td>
#     </tr>
#     <tr>
#       <th>G8G9</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{2}$=56.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{2}$:<br>C3'O2P(G8G9)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{26}$=17.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{26}$:<br>C2'O1P(G8G9)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{65}$=8.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{65}$:<br>O3'C5'(G8G9)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G9G10</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{34}$=15.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{34}$:<br>O3'C5'(G9G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{49}$=10.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{49}$:<br>C2'P(G9G10)<br>C2'O1P(G9G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{69}$=7.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{69}$:<br>C3'O2P(G9G10)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{78}$=6.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{78}$:<br>C1'P(G9G10)</td>
#     </tr>
#     <tr>
#       <th>G10T11</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{16}$=29.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{16}$:<br>C3'O1P(G10T11)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{33}$=15.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{33}$:<br>C4'O2P(G10T11)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{41}$=11.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{41}$:<br>C2'O5'(G10T11)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T11T12</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{7}$=39.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{7}$:<br>C3'O2P(T11T12)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{24}$=19.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{24}$:<br>C2'O1P(T11T12)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T12A13</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{15}$=29.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{15}$:<br>C3'O2P(T12A13)<br>C3'O5'(T12A13)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{31}$=16.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{31}$:<br>C2'O1P(T12A13)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{58}$=9.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{58}$:<br>O3'C5'(T12A13)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{83}$=5.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{83}$:<br>O3'C4'(T12A13)</td>
#     </tr>
#     <tr>
#       <th>A13G14</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{10}$=32.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{10}$:<br>C3'O2P(A13G14)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{44}$=11.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{44}$:<br>C4'O5'(A13G14)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{54}$=9.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{54}$:<br>C2'O1P(A13G14)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{90}$=4.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{90}$:<br>O3'O4'(A13G14)</td>
#     </tr>
#     <tr>
#       <th>G14G15</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{4}$=52.2, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{4}$:<br>C3'O2P(G14G15)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{19}$=21.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{19}$:<br>C2'O1P(G14G15)<br>C2'O5'(G14G15)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{71}$=7.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{71}$:<br>O3'C5'(G14G15)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G15G16</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{30}$=16.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{30}$:<br>O3'C5'(G15G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{47}$=10.8, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{47}$:<br>C2'O1P(G15G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{59}$=8.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{59}$:<br>C3'O2P(G15G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{89}$=4.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{89}$:<br>C1'P(G15G16)</td>
#     </tr>
#     <tr>
#       <th>G16T17</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{12}$=31.1, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{12}$:<br>C3'O1P(G16T17)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{56}$=9.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{56}$:<br>C2'O5'(G16T17)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{77}$=6.5, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{77}$:<br>C4'O2P(G16T17)<br>O4'O2P(G16T17)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T17T18</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{23}$=19.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{23}$:<br>C3'O5'(T17T18)<br>C3'O2P(T17T18)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{67}$=7.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{67}$:<br>O3'C4'(T17T18)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{86}$=5.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{86}$:<br>O4'O1P(T17T18)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T18A19</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{1}$=59.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{1}$:<br>C3'O2P(T18A19)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{14}$=30.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{14}$:<br>C2'O1P(T18A19)</td>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{22}$=19.7, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{22}$:<br>O3'C5'(T18A19)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>A19G20</th>
#       <td>$\rm{\lambda}^{\rm{pr1}}_{25}$=18.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr1}}_{25}$:<br>C3'O2P(A19G20)<br>C3'O5'(A19G20)</td>
#       <td>$\rm{\lambda
# Write /home/user/workfolder/g4dna_protocol_demo/propeller/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/propeller_PR1.csv

# %%
b_agent.t_agent.mean.df_m.sort_values(by='k', ascending=False)
# Out:
#        Enm_i Strand_i  Resid_i Atomname_i  Atomid_i Enm_j Strand_j  Resid_j  \
# PairID
# 8851    A419  STRAND1       20        C3'       419  A424  STRAND1       21
# 3589    A165  STRAND1        8        C3'       165  A170  STRAND1        9
# 6228    A292  STRAND1       14        C3'       292  A297  STRAND1       15
# 8118    A376  STRAND1       18        C3'       376  A381  STRAND1       19
# 973      A38  STRAND1        2        C3'        38   A43  STRAND1        3
# ...      ...      ...      ...        ...       ...   ...      ...      ...
# 4218    A194  STRAND1       10        C5'       194  A239  STRAND1       12
# 4238    A195  STRAND1       10        C4'       195  A215  STRAND1       11
# 4242    A195  STRAND1       10        C4'       195  A219  STRAND1       11
# 4252    A195  STRAND1       10        C4'       195  A229  STRAND1       11
# 9229    A443  STRAND1       21        O3'       443  A465  STRAND1       22
#
#        Atomname_j  Atomid_j          k        b0 Category
# PairID
# 8851          O2P       424  24.466284  2.936832      pr1
# 3589          O2P       170  24.360905  2.946153      pr1
# 6228          O2P       297  24.022363  2.931647      pr1
# 8118          O2P       381  23.408037  2.947711      pr1
# 973           O2P        43  22.421400  2.912921      pr1
# ...           ...       ...        ...       ...      ...
# 4218          C1'       239   0.000000  9.679842      pr1
# 4238          O5'       215   0.000000  3.761932      pr1
# 4242          C1'       219   0.000000  5.333284      pr1
# 4252          C3'       229   0.000000  5.861974      pr1
# 9229          O3'       465   0.000000  6.270468      pr1
#
# [1134 rows x 13 columns]

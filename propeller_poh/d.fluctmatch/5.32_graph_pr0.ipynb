# %%
import sys
sys.path.append("../../smsl")

# %%
from smsl.graphBigtraj import BigTrajGraphAgent
from smsl.graph import PR0

import warnings; warnings.filterwarnings("ignore")
import numpy as np

# %%
## 見論文表B.7
n_mode=90         ## $\alpha_c$
vlv_threshold=0.2 ## $\nu_{\text{c}}$
pe_threshold=0.5  ## $\kappa_{\text{c}}$

# %%
b_agent = BigTrajGraphAgent(PR0)
# Out:
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_poh/d.fluctmatch/bigtraj_fluctmatch/0000_0500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_poh/d.fluctmatch/bigtraj_fluctmatch/0250_0750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_poh/d.fluctmatch/bigtraj_fluctmatch/0500_1000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_poh/d.fluctmatch/bigtraj_fluctmatch/0750_1250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_poh/d.fluctmatch/bigtraj_fluctmatch/1000_1500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_poh/d.fluctmatch/bigtraj_fluctmatch/1250_1750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_poh/d.fluctmatch/bigtraj_fluctmatch/1500_2000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_poh/d.fluctmatch/bigtraj_fluctmatch/1750_2250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_poh/d.fluctmatch/bigtraj_fluctmatch/2000_2500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_poh/d.fluctmatch/bigtraj_fluctmatch/2250_2750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_poh/d.fluctmatch/bigtraj_fluctmatch/2500_3000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_poh/d.fluctmatch/bigtraj_fluctmatch/2750_3250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_poh/d.fluctmatch/bigtraj_fluctmatch/3000_3500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_poh/d.fluctmatch/bigtraj_fluctmatch/3250_3750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_poh/d.fluctmatch/bigtraj_fluctmatch/3500_4000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_poh/d.fluctmatch/bigtraj_fluctmatch/3750_4250/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_poh/d.fluctmatch/bigtraj_fluctmatch/4000_4500/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_poh/d.fluctmatch/bigtraj_fluctmatch/4250_4750/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_poh/d.fluctmatch/bigtraj_fluctmatch/4500_5000/result/pairtypes_k_b0_cutoff_5.00.csv
# Reading data from: /home/user/workfolder/g4dna_protocol_demo/propeller_poh/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/pairtypes_k_b0_cutoff_5.00.csv

# %%
b_agent.spectral_decomposition()
b_agent.set_mean_r_alpha_array()
b_agent.t_agent.mean.GetEigenvectorEigenvectorT()
# Out:
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.
# Thare are 239 nodes.
# Initialize adjacency, degree and Laplacian matrices... Done.
# Finish the setup for Laplaican matrix.

# %%
## 論文 圖5.24(B)
b_agent.plot_prominent_modes_and_identify_atom_with_interactive(strandid=None)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=239, min=1), Output()), _dom_classes=('w…

# %%
b_agent.plot_prominent_modes_and_get_identify_pair_with_interactive(\
        strandid=None, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, filter=True)
# Out:
# interactive(children=(IntSlider(value=1, description='sele_mode', max=239, min=1), Output()), _dom_classes=('w…

# %%
b_agent.t_agent.mean.get_modes_info(strandid=None, n_mode=n_mode, vlv_threshold=vlv_threshold, pe_threshold=pe_threshold, is_return=False)
# Out:
# 100%|██████████| 90/90 [00:00<00:00, 129.74it/s]

# %%
## 論文 圖5.24(C)
b_agent.t_agent.mean.display_df_info_by_resid(save=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#     </tr>
#     <tr>
#       <th>Residue Pair</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A1</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_
</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{79}$=9.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{79}$:<br>C1'O3'(A13A13)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G14</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{28}$=26.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{28}$:<br>O5'C3'(G14G14)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{43}$=20.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{43}$:<br>C1'O3'(G14G14)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{61}$=13.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{61}$:<br>C5'C2'(G14G14)<br>O1PC5'(G14G14)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G15</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{36}$=23.9, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{36}$:<br>O4'O3'(G15G15)<br>O5'O4'(G15G15)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{58}$=14.4, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{58}$:<br>C5'C2'(G15G15)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>G16</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{6}$=42.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{6}$:<br>C5'C2'(G16G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{15}$=33.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{15}$:<br>O4'O3'(G16G16)<br>O5'O4'(G16G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{48}$=17.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{48}$:<br>C1'O3'(G16G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{69}$=11.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{69}$:<br>O1PC4'(G16G16)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{89}$=8.0, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{89}$:<br>O2PC3'(G16G16)</td>
#     </tr>
#     <tr>
#       <th>T17</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{7}$=40.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{7}$:<br>C5'C2'(T17T17)<br>C5'C1'(T17T17)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{20}$=31.3, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{20}$:<br>O4'O3'(T17T17)<br>O5'O3'(T17T17)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>T18</th>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{10}$=37.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{10}$:<br>C5'C2'(T18T18)</td>
#       <td>$\rm{\lambda}^{\rm{pr0}}_{17}$=32.6, ${\{\rm{a}_i\rm{a}_j\}}^{\rm{pr0}}_{17}$:<br>O5'O4'(T18T18)<br>O4'O3'(T18T18)</td>
# Write /home/user/workfolder/g4dna_protocol_demo/propeller_poh/d.fluctmatch/bigtraj_fluctmatch/0000_5000/result/propeller_poh_PR0.csv

# %%
b_agent.t_agent.mean.df_m.sort_values(by='k', ascending=False)
# Out:
#        Enm_i Strand_i  Resid_i Atomname_i  Atomid_i Enm_j Strand_j  Resid_j  \
# PairID
# 3230    A108  STRAND1        6        O5'       108  A122  STRAND1        6
# 5536    A216  STRAND1       11        C5'       216  A230  STRAND1       11
# 9176    A380  STRAND1       19        O1P       380  A383  STRAND1       19
# 6320    A253  STRAND1       13        O1P       253  A256  STRAND1       13
# 5954    A236  STRAND1       12        C5'       236  A250  STRAND1       12
# ...      ...      ...      ...        ...       ...   ...      ...      ...
# 3777    A146  STRAND1        8          P       146  A166  STRAND1        8
# 3772    A146  STRAND1        8          P       146  A153  STRAND1        8
# 3771    A146  STRAND1        8          P       146  A152  STRAND1        8
# 3535    A127  STRAND1        7        O2P       127  A129  STRAND1        7
# 9168    A379  STRAND1       19          P       379  A384  STRAND1       19
#
#        Atomname_j  Atomid_j          k        b0 Category
# PairID
# 3230          C3'       122  19.262111  3.010142      pr0
# 5536          C2'       230  19.059832  3.268842      pr0
# 9176          C5'       383  18.021668  2.978416      pr0
# 6320          C5'       256  16.048358  2.990942      pr0
# 5954          C2'       250  15.135158  3.306658      pr0
# ...           ...       ...        ...       ...      ...
# 3777          C2'       166   0.000000  5.261053      pr0
# 3772          C1'       153   0.000000  5.477226      pr0
# 3771          O4'       152   0.000000  4.549758      pr0
# 3535          C5'       129   0.000000  3.805447      pr0
# 9168          C4'       384   0.000000  3.959558      pr0
#
# [534 rows x 13 columns]

# %%
import sys
sys.path.append("../../smsl")

# %% [markdown]
# ### Part 1: Initialize

# %%
from smsl.fluctMatch import FmAgent

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
fm_agent = FmAgent()
fm_agent.load_TimeAgent()

# %%
for time_label, st_agent in fm_agent.t_agent.items():
    err_data = np.genfromtxt(st_agent.error_file, skip_header=2).T
    plt.plot(err_data[0], err_data[1], label=time_label)
plt.legend(bbox_to_anchor=(1.35, 1.1))
plt.xlabel('Epoch')
plt.ylabel('RMS of Fluctuation(Å)')
# Out:
# Text(0, 0.5, 'RMS of Fluctuation(Å)')

# %%
for time_label, st_agent in fm_agent.t_agent.items():
    err_data = np.genfromtxt(st_agent.error_file, skip_header=2).T
    print('Last loss of windows', time_label, ': ', err_data[1, -1])
# Out:
# Last loss of windows 0000_0500 :  0.2632
# Last loss of windows 0250_0750 :  0.1274
# Last loss of windows 0500_1000 :  0.1794
# Last loss of windows 0750_1250 :  0.3938
# Last loss of windows 1000_1500 :  0.376
# Last loss of windows 1250_1750 :  0.3915
# Last loss of windows 1500_2000 :  0.2868
# Last loss of windows 1750_2250 :  0.0834
# Last loss of windows 2000_2500 :  0.0841
# Last loss of windows 2250_2750 :  0.0873
# Last loss of windows 2500_3000 :  0.085
# Last loss of windows 2750_3250 :  0.0845
# Last loss of windows 3000_3500 :  0.0886
# Last loss of windows 3250_3750 :  0.0879
# Last loss of windows 3500_4000 :  0.0957
# Last loss of windows 3750_4250 :  0.0797
# Last loss of windows 4000_4500 :  0.0828
# Last loss of windows 4250_4750 :  0.0914
# Last loss of windows 4500_5000 :  0.0881

# %% [markdown]
# ### Catch Outlier Windows

# %%
for time_label, st_agent in fm_agent.t_agent.items():
    err_data = np.genfromtxt(st_agent.error_file, skip_header=2).T
    if err_data[1].max() > err_data[1][1]:
        plt.plot(err_data[0], err_data[1], label=time_label)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## 線上資源
# - mdgx introduction ([link](https://ambermd.org/tutorials/advanced/tutorial32/index.php))
# - Group Meeting Google Drive ([link](https://drive.google.com/file/d/1qc4Dk0s59pbnqsGQYyiSj_ZMideWgyJl))
# - Amber 2023 mounal ([link](https://ambermd.org/doc12/Amber23.pdf))

# %%
drug = "POH"

# %%
# !mkdir conf1 iter1

# %% [markdown]
# ### 建立scan每點zero-point energy所需的結構檔(.orca)

# %%
# %%writefile 2.1.GenConformers.py
from pymol import cmd
from numpy import random
import os

drug = "POH"
n_conf = 360
cpus = 8    ## using {cpus} cpus in parallel computing 
rams = 7000 ## using {rams} MB in computing
w_text = f'''\
! PAL{cpus}
! mp2 cc-pvdz TightSCF  NoKeepInts

%scf
  MaxCore {rams}
end
%mp2
  MaxCore {rams}
end
'''

cmd.load(f'../1.GenTopology/{drug}.mol2')
cmd.set('retain_order', 1)
cmd.alter('all', f"resn='{drug}'")
cmd.alter('all', "elem=''")
for i in range(1, n_conf+1):
    cmd.set_dihedral('name C12', 'name C11', 'name C3', 'name C4', i-random.rand())
    cmd.save(f'conf1/Conf{i}.pdb')
    os.system(f'obabel conf1/Conf{i}.pdb -o orcainp -O conf1/Conf{i}.orca')
    
    with open(f'conf1/Conf{i}.orca', 'r') as f:
        r_text = f.read()
        r_text = r_text[r_text.find('*'):]

    with open(f'conf1/Conf{i}.orca', 'w') as f:
        f.write(w_text+r_text)
exit()
# Out:
# Overwriting 2.1.GenConformers.py

# %%
# !python3  2.1.GenConformers.py
# Out:
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf1.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf2.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf3.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf4.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf5.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf6.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf7.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf8.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf9.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf10.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf11.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf12.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf13.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf14.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf15.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf16.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf17.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf18.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf19.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf20.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf21.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf22.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf23.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf24.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf25.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf26.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf27.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf28.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf29.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf30.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf31.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf32.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf33.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf34.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf35.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf36.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf37.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf38.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf39.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf40.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf41.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf42.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf43.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf44.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf45.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf46.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf47.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf48.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf49.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf50.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf51.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf52.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf53.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf54.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf55.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf56.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf57.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf58.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf59.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf60.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf61.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf62.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf63.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf64.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf65.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf66.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf67.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf68.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf69.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf70.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf71.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf72.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf73.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf74.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf75.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf76.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf77.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf78.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf79.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf80.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf81.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf82.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf83.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf84.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf85.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf86.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf87.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf88.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf89.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf90.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf91.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf92.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf93.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf94.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf95.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf96.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf97.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf98.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf99.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf100.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf101.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf102.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf103.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf104.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf105.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf106.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf107.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf108.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf109.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf110.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf111.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf112.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf113.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf114.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf115.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf116.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf117.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf118.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf119.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf120.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf121.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf122.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf123.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf124.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf125.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf126.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf127.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf128.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf129.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf130.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf131.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf132.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf133.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf134.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf135.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf136.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf137.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf138.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf139.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf140.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf141.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf142.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf143.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf144.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf145.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf146.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf147.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf148.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf149.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf150.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf151.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf152.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf153.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf154.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf155.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf156.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf157.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf158.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf159.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf160.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf161.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf162.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf163.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf164.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf165.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf166.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf167.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf168.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf169.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf170.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf171.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf172.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf173.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf174.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf175.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf176.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf177.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf178.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf179.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf180.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf181.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf182.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf183.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf184.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf185.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf186.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf187.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf188.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf189.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf190.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf191.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf192.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf193.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf194.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf195.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf196.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf197.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf198.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf199.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is conf1/Conf200.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Error  in FullConvert
#   Cannot write to conf1/Conf201.orca
# 0 molecules converted
# Traceback (most recent call last):
#   File "/home/user/workfolder/g4dna_protocol_demo/poh/b.amber.drug_ff/2.Mdgx/2.1.GenConformers.py", line 30, in <module>
#     with open(f'conf1/Conf{i}.orca', 'r') as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'conf1/Conf201.orca'

# %% [markdown]
# ### 執行orca 以計算 zero-point energy

# %%
# %%writefile 2.2.Run_orca.slurm
# #!/bin/bash
# #SBATCH --partition=xeon                 # Define the partition on which the job shall run
# #SBATCH --job-name=spOrca                # Job name
# #SBATCH --ntasks=8                       # Total number of tasks
# #SBATCH --nodes=1                        # Number of nodes on which to run
# #SBATCH --cpus-per-task=1                # Threads per task
# #SBATCH --mem=8000                       # Memory per job in MB
# #SBATCH --output=spOrca.%J.out
# #SBATCH --error=spOrca.%J.out
# #SBATCH --array=1-360
#
# scratchFile="/scratch/chu_02/allen/amber_gaff2"
# confFilename=$(basename $(realpath .))
# currentConfFile=$(pwd)
# scratchConfFile="${scratchFile}/${confFilename}"
# orca="$HOME/opt/orca-5.0.4/orca"
#
# module load openmpi/gcc/64
#
# mkdir -p ${scratchConfFile}
# cp -r conf1/Conf${SLURM_ARRAY_TASK_ID}.orca ${scratchConfFile}
#
# ${orca} ${scratchConfFile}/Conf${SLURM_ARRAY_TASK_ID}.orca > ${scratchConfFile}/Conf${SLURM_ARRAY_TASK_ID}.oout
#
# cp ${scratchConfFile}/Conf${SLURM_ARRAY_TASK_ID}.oout ${currentConfFile}/conf1
# echo -e "# of primitive gaussian functions\n" >> ${currentConfFile} ## add mark to let 3.ExtractEnergies.mdgx can reconginze
# Out:
# Overwriting 2.2.Run_orca.slurm

# %%
# !sbatch 2.2.Run_orca.slurm

# %% [markdown]
# ### 彙整所有zero-point energy的數值

# %%
import re
import matplotlib.pyplot as plt

threshold = -2130.90 ## Eh

## Conf{i}.oout parse
energy_dict = {}
for i in range(1, 360+1):
    filename = f"conf1/Conf{i}.oout"
    with open(filename, "r") as file:
        for line in file:
            match = re.search(r"MP2 TOTAL ENERGY:\s+([-\d\.]+) Eh", line)
            if match:
                energy_dict[i] = float(match.group(1))
                break  # 找到後就跳出，避免不必要的讀取

plt.plot(energy_dict.keys(), energy_dict.values())
plt.axhline(threshold, c='r')
plt.axvspan( 45, 135, color='yellow', alpha=0.1)
plt.axvspan(225, 315, color='yellow', alpha=0.1)
plt.xlabel('dihedral angle C12-C11-C3-C4 (degree)')
plt.ylabel('single point energy (Eh)')
plt.show()

# %%
## 若重跑記得刪除原本output檔 concat.out, energies.dat, coords.cdf
# !rm iter1/concat.out iter1/energies.dat iter1/coords.cdf

# %%
# oout_data = ''.join([f'  data     conf1/Conf{i}.oout \n' for i in range(1, 360+1) if energy_dict[i]<threshold])
oout_data = ''.join([f'  data     conf1/Conf{i}.oout \n' for i in list(range(46,135))+list(range(226,315))])
mdgx_script = f'''\
&files
  -p      ../1.GenTopology/{drug}.prmtop
  -o      iter1/concat.out
  -d      iter1/energies.dat
  -x      iter1/coords.cdf
&end

&speval
{oout_data}
&end
'''

# !echo "{mdgx_script}" > 2.3.ExtractEnergies.mdgx
# !mdgx -i 2.3.ExtractEnergies.mdgx

# %% [markdown]
# concat.out   : log 檔，彙整有多少結構 <br>
# energies.dat : 彙整每個結構的單點能量數值 <br>
# coords.cdf   : 彙整每個結構並打包成Amber NetCDF軌跡檔， 可用VMD和Pymol開啟 <br>
# - open_coords.pml
# ```
# load ../../1.GenTopology/{drug}.mol2
# load_traj coords.cdf, format=nc
# ```

# %% [markdown]
# ### Fit 力場參數

# %%
## 若重跑記得刪除原本output檔 fit.out, {drug}.dat, report.m
# !rm iter1/fit.out iter1/{drug}.dat iter1/report.m

# %%
mdgx_script = f'''\
&files
  -parm   ../1.GenTopology/{drug}.all.modify.frcmod
  -d      iter1/{drug}.dat
  -o      iter1/fit.out
&end

&param
  System  ../1.GenTopology/{drug}.prmtop  iter1/coords.cdf  iter1/energies.dat
  ParmOutput frcmod
  eunits    hartree,
  accrep    iter1/report.m
  verbose    1,

  % Angle fitting input
  # %fita       C* C* HA
  # %FitAnglEq  1,
  # %arst       0.0002,
  # %arstcpl    1.0,

  % Torsion fitting input
  fith       CA CA CD CC
  hrst       0.0002,
&end
'''

# !echo "{mdgx_script}" > 2.4.FitParm.mdgx
# !mdgx -i 2.4.FitParm.mdgx
# Out:
# GetParamNamelist >> Warning.  Unrecognized restraint scaling method
# GetParamNamelist >> ���.  Valid methods are 'estimate' and 'spy.'
# GetParamNamelist >> See the manual for descriptions.  The default
# GetParamNamelist >> 'estimate' method remains in effect.
#
# mdgx >> Unique adjustable parameters enumerated.
# mdgx >>    178 conformations read.
# mdgx >> Parameter keys read.
# mdgx >> 2 adjustable terms mapped.
# mdgx >>    178 conformations' energies computed.
# mdgx >> High-energy conformations pruned.
# mdgx >> Energies normalized, conformations weighted.
# mdgx >> Accumulating and checking fitting matrix.
# mdgx >> Evaluating conformation       0 of     178
# mdgx >> Assigning restraints.
# mdgx >> Solving LLSP for column     3 of     3
# mdgx >> Matrix decomposition complete.
# mdgx >> Descriptions complete for all instances of    2 parameters.
# mdgx >> Parameters written to file iter1/POH.dat.
# mdgx >> Analysis written to file iter1/fit.out.

# %% [markdown]
# #### fitting 結果
# `iter1/repot.m` 檔在matlab執行可繪製fit圖 <br>
# 或是執行下方python code也可繪製相同fit圖 <br>
# ⚫ Original : 以原有的力場參數計算的Model Energy, 對上以zero-point energy計算的Target Energy <br>
# 🔴 Fitted   : 以fit過後的力場參數計算的Model Energy, 對上以zero-point energy計算的Target Energy, 兩能量數值越接近(x=y)代表fitted越好

# %%
import numpy as np
import matplotlib.pyplot as plt
import re

# 讀取 MATLAB .m 檔案
with open("iter1/report.m", "r", encoding="utf-8") as f:
    lines = f.readlines()

# 解析 data0 部分的數據
pattern = re.compile(r"[-+]?[0-9]*\.?[0-9]+(?:[eE][-+]?[0-9]+)?")
data = []

recording = False
for line in lines:
    if "data0 = [" in line:
        recording = True
        continue
    if "]" in line and recording:
        break
    if recording:
        numbers = pattern.findall(line)
        if len(numbers) >= 4:
            data.append(list(map(float, numbers[:4])))

# 轉換為 NumPy 陣列
if data:
    data = np.array(data)
else:
    raise ValueError("No valid data found in report.m")

# 提取數據列
target, original, fitted = data[:, 0], data[:, 1], data[:, 2]

# 繪圖
plt.figure(figsize=(8, 6))
plt.plot(target, original, 'k.', label='Original')
plt.plot(target, fitted, 'r.', label='Fitted')
plt.xlabel('Target energy (kcal/mol)')
plt.ylabel('Model energy (kcal/mol)')
plt.title(f'Model results for {drug}.prmtop')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Merge 兩個力場參數檔案 {drug}.all.modify.frcmod 以及 {drug}.dat

# %%
# !cp ../1.GenTopology/{drug}.all.modify.frcmod iter1/{drug}.all.mdgx.frcmod
## 刪除原本的 CA-CA-CD-CC, n=2
# !sed -i '70d' iter1/{drug}.all.mdgx.frcmod
## 刪除原本的 CA-CA-CD-CC, n=4
# !sed -i '69d' iter1/{drug}.all.mdgx.frcmod
## 增加{drug}.dat 的 CA-CA-CD-CC, n=2 (取小數點3位)
para = !sed -n '9p' iter1/POH.dat | awk '{$3 = sprintf("%.3f", $3); print}'
# !sed -i "68a {para[0]}" iter1/{drug}.all.mdgx.frcmod
## 增加{drug}.dat 的 CA-CA-CD-CC, n=4 (取小數點3位)
para = !sed -n '10p' iter1/POH.dat | awk '{$3 = sprintf("%.3f", $3); print}'
# !sed -i "69a {para[0]}" iter1/{drug}.all.mdgx.frcmod

# %% [markdown]
# ### 輸出 Amber 格式的座標檔案 (coordinate file, .rst7) 與參數檔案 (parameter file, .prmtop)

# %%
tleap_script = f'''\
{drug}=loadmol2 ../1.GenTopology/{drug}.mol2
loadamberparams iter1/{drug}.all.mdgx.frcmod
check ## just for check
saveamberparm {drug} iter1/{drug}.prmtop iter1/{drug}.rst7
quit
''' 

# !echo "{tleap_script}" > 2.5.GenNewTop.tleap
# !tleap -f 2.5.GenNewTop.tleap
# Out:
# -I: Adding /home/user/anaconda3/envs/AmberTools23/dat/leap/prep to search path.
# -I: Adding /home/user/anaconda3/envs/AmberTools23/dat/leap/lib to search path.
# -I: Adding /home/user/anaconda3/envs/AmberTools23/dat/leap/parm to search path.
# -I: Adding /home/user/anaconda3/envs/AmberTools23/dat/leap/cmd to search path.
# -f: Source 2.5.GenNewTop.tleap.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./2.5.GenNewTop.tleap
# Loading Mol2 file: ../1.GenTopology/POH.mol2
# Reading MOLECULE named POH
# Loading parameters: ./iter1/POH.all.mdgx.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# check: A maximum of two parameters are acceptable:
#      a UNIT and an (optional) PARMSET.
# Checking Unit.
#
# /home/user/anaconda3/envs/AmberTools23/bin/teLeap: Warning!
# The unperturbed charge of the unit (3.999998) is not zero.
#
# /home/user/anaconda3/envs/AmberTools23/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 46 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	POH	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 1; Notes = 1.

# %% [markdown]
# ### 匯出 Gromacs 格式的座標(.gro)、拓撲與參數檔案(.top)

# %%
# !acpype -p iter1/{drug}.prmtop -x iter1/{drug}.rst7
# Out:
# ============================================================================
# | ACPYPE: AnteChamber PYthon Parser interfacE v. 2023.10.27 (c) 2025 AWSdS |
# ============================================================================
# Converting Amber input files to Gromacs ...
# ==> Writing GROMACS files
#
# ==> Disambiguating lower and uppercase atomtypes in GMX top file, even if identical.
#
# ==> Writing GMX dihedrals for GMX 4.5 and higher.
#
# Total time of execution: less than a second
